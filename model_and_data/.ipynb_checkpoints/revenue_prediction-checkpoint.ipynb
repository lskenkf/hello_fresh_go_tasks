# %% [markdown]
# ## Dependencies

# %%
import re
import warnings

import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) # Let pandas print the entire dataframe
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
#todo: preprocessing like

# %% [markdown]
# ## Record Correct and Mismatched Data Type

# %%
# Set path of train, test data
data_train_path = r'D:\pythonProject\hello_fresh_go_tasks\model_and_data\b2b_data_train - b2b_data_train.csv'
data_test_path = r'D:\pythonProject\hello_fresh_go_tasks\model_and_data\b2b_data_test - b2b_data_test.csv'


# Load csv files into pandas dataframes
df_train = pd.read_csv(data_train_path)
df_test = pd.read_csv(data_test_path)


# Label column is the one absent from test data set.
global label_col_name
label_col_name = set(df_train.columns.values) - set(df_test.columns.values)

# %%
# We need to first identfy the type of each column for further processing.
# We have to copy and paste the column name from the index object rather than directly from the display. 

df_column_type = df_train.dtypes.to_frame(name = 'data_type')
df_data_sample = df_train.head(2).T 
df_data_sample = df_data_sample.rename(columns = {
                                                  0:'data_sample_0',
                                                  1:'data_sample_1'
                                                  })
df_check_data_type = df_column_type.join(df_data_sample)
display(df_check_data_type)
# Out:
#                                                 data_type      data_sample_0  \
# Fridge ID                                           int64               5370
# City                                               object             Berlin
# Location                                           object            Central
# Year Founded                                        int64               2011
# Maturity                                           object           immature
# Industry                                           object            Service
# IndustryNew                                        object         E-Commerce
# Company Type                                       object            Grownup
# Company Type*                                      object    Mature Start-Up
# Employee Type                                      object       White Collar
# Office Size                                         int64                300
# Innercompany Location                              object           Entrance
# Lead Source                                        object  Internal Referral
# Fridge Type                                        object      Double Fridge
# Service Fee                                        object              499 Û
# Subsidy                                            object                1 Û
# Revenue                                            object           Û 355.69
# Registered Users                                  float64             1124.0
# Active users (weekly average 2019 per terminal)   float64             293.85
# Basket size/User/Week                             float64               6.05
# Male/Female Ratio                                 float64               1.38
# # Newsletter subscriptions                        float64              389.0
# NL/User                                            object                35%
# # Fingerprints                                    float64              314.0
# FP/User                                            object                28%
# # Restaurants nearby                              float64               60.0
# Avg. NPS Score                                    float64                7.5
#
#                                                                            data_sample_1
# Fridge ID                                                                           5637
# City                                                                              Berlin
# Location                                                                          Fringe
# Year Founded                                                                        2016
# Maturity                                                                        immature
# Industry                                                                         Service
# IndustryNew                                      B2C Software, Apps and Digital Services
# Company Type                                                                     Startup
# Company Type*                                                           Growing Start-Up
# Employee Type                                                               White Collar
# Office Size                                                                           90
# Innercompany Location                                                            Kitchen
# Lead Source                                                            Internal Referral
# Fridge Type                                                                Double Fridge
# Service Fee                                                                        499 Û
# Subsidy                                                                              2 Û
# Revenue                                                                         Û 316.63
# Registered Users                                                                   339.0
# Active users (weekly average 2019 per terminal)                                   146.44
# Basket size/User/Week                                                              10.81
# Male/Female Ratio                                                                    0.8
# # Newsletter subscriptions                                                          42.0
# NL/User                                                                              12%
# # Fingerprints                                                                     108.0
# FP/User                                                                              32%
# # Restaurants nearby                                                                22.0
# Avg. NPS Score                                                                       7.8

# %%
# Now we pick up the columns which has the correct and wrong formats, then categorize them.  

clean_int_columns = [
    'Fridge ID',
    'Year Founded',
    'Office Size'  
] 

clean_str_columns = [
    'City',
    'Location',
    'Maturity',
    'Industry',
    'IndustryNew',
    'Company Type',
    'Company Type*', 
    'Employee Type',
    'Innercompany Location',
    'Lead Source',
    'Fridge Type'  
] 

clean_float_columns = [
    
    'Registered Users',
    'Active users (weekly average 2019 per terminal)',
    'Basket size/User/Week', 'Male/Female Ratio',
    '# Newsletter subscriptions',
    '# Fingerprints',
    '# Restaurants nearby',
    'Avg. NPS Score'  
]

# There is an unwanted 'Û' in these columns
global columns_remove_U_and_convert_str_to_float 
columns_remove_U_and_convert_str_to_float = [
    'Service Fee', 
    'Subsidy', 
    'Revenue'
]

# We have to convert the str type to float type
global columns_remove_percentage_and_convert_str_to_float
columns_remove_percentage_and_convert_str_to_float = [
    'NL/User', 
    'FP/User'
]


checked_columns = [
    clean_int_columns,
    clean_str_columns,
    clean_float_columns,
    columns_remove_U_and_convert_str_to_float,
    columns_remove_percentage_and_convert_str_to_float
]

# Verify whether we have checked all the columns
total_num_columns = len(df_train.columns) 
checked_columns = [x for xs in checked_columns for x in xs]
num_missed_column = total_num_columns - len(checked_columns)

try:
    0 == num_missed_column
    print(f'We have checked all {total_num_columns} columns')
    
except ValueError:
    raise ValueError(f"We have missed to check {num_missed_column} columns")
# Out:
# We have checked all 27 columns

# %% [markdown]
# ## Correct Mismatched Data Type

# %%
# We create a function to wrap ip the cleaning and encoding process and apply them to both train and test set.
# i.e., we need to creat several udf for pandas dataframe, although udf is slow applied to big dataframe. 

def func_remove_U_and_convert_str_to_float(cell):
    try:
        cell = re.sub('[^0-9.]', "", cell.replace(",","."))
        return float(cell)
    except:
        return np.nan   # missing value is casted to -1.
 
def func_remove_percentage_and_convert_str_to_float(cell):
    try:
        cell = cell.replace("%","")
        return float(cell)
    
    except:   
        return np.nan
    

def apply_udf(df,columns,func):
    for col in columns:
        df[col] = df.apply(lambda x: func(x[col]),axis = 1)
        
    return df


def clean_data(df,data_type):
   
    df = apply_udf(
        df,
        columns_remove_percentage_and_convert_str_to_float,
        func_remove_percentage_and_convert_str_to_float
    )
    
    if data_type == 'train':
        df = apply_udf(
            df,
            columns_remove_U_and_convert_str_to_float,
            func_remove_U_and_convert_str_to_float
        )
    elif data_type == 'test':
        df = apply_udf(
            df,
            set(columns_remove_U_and_convert_str_to_float) - label_col_name,
            func_remove_U_and_convert_str_to_float
        )
    else:
        raise ValueError("data_type input is wrong")
    
    return df

# %% [markdown]
# ## Check Missing Value and Fill String Valued Column

# %%
def get_missing_value_percentage(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({
        'percent_missing': percent_missing
    })
    missing_value_df.sort_values('percent_missing', inplace=True)
    
    return missing_value_df


df_train = clean_data(df_train,'train')
df_test = clean_data(df_test,'test')

global numeric_colunms
global str_columns
numeric_colunms = set(checked_columns)\
               - set(clean_str_columns)
str_columns = clean_str_columns

global str_column_fillna_value
str_column_fillna_value = 'Unknown'

# %%
# We fill 'unknown' in the string valued column if the value is missing.
# we fill with the average value if the value is missing in that column.
     
        
def fill_missing_value(df,numeric_features,str_features):
    
    df_str = df[str_features]
    df_numeric = df[numeric_features]
    
    df_numeric = df_numeric.fillna(value=df_numeric.mean())
    df_str = df_str.fillna(value=str_column_fillna_value)
    df = pd.concat([df_numeric, df_str],axis=1)
    return df

# %% [markdown]
# ## Check Correlation Between All Columns

# %%
# We use the whole training data to get the Heatmap matrix which gives us an overview of all pair correlations.
df_train = fill_missing_value(df_train, numeric_colunms,str_columns)   
df_test = fill_missing_value(df_test, numeric_colunms-label_col_name, str_columns) 
corr = df_train.corr()
display(corr)
# Out:
#                                                   Subsidy   FP/User   NL/User  \
# Subsidy                                          1.000000  0.123439  0.045030
# FP/User                                          0.123439  1.000000  0.261969
# NL/User                                          0.045030  0.261969  1.000000
# Revenue                                          0.273119  0.228317  0.001673
# # Newsletter subscriptions                      -0.067446  0.041817  0.127295
# Year Founded                                     0.049700 -0.051898 -0.202475
# Fridge ID                                       -0.062084 -0.187896  0.094979
# # Fingerprints                                  -0.004526  0.300165 -0.073070
# Basket size/User/Week                            0.195651  0.070158  0.121355
# Male/Female Ratio                                0.024339  0.052112 -0.134380
# # Restaurants nearby                            -0.033123 -0.166167 -0.133312
# Service Fee                                      0.088171 -0.003535  0.103900
# Office Size                                     -0.160370 -0.126899 -0.036241
# Registered Users                                -0.073152 -0.008235 -0.100766
# Active users (weekly average 2019 per terminal)  0.168224  0.201689  0.006375
# Avg. NPS Score                                   0.053320  0.069560  0.225991
#
#                                                   Revenue  \
# Subsidy                                          0.273119
# FP/User                                          0.228317
# NL/User                                          0.001673
# Revenue                                          1.000000
# # Newsletter subscriptions                       0.377834
# Year Founded                                     0.143770
# Fridge ID                                       -0.305169
# # Fingerprints                                   0.504865
# Basket size/User/Week                            0.132400
# Male/Female Ratio                               -0.076353
# # Restaurants nearby                            -0.116038
# Service Fee                                      0.025224
# Office Size                                      0.004965
# Registered Users                                 0.309066
# Active users (weekly average 2019 per terminal)  0.942982
# Avg. NPS Score                                   0.108391
#
#                                                  # Newsletter subscriptions  \
# Subsidy                                                           -0.067446
# FP/User                                                            0.041817
# NL/User                                                            0.127295
# Revenue                                                            0.377834
# # Newsletter subscriptions                                         1.000000
# Year Founded                                                       0.047212
# Fridge ID                                                         -0.325508
# # Fingerprints                                                     0.838215
# Basket size/User/Week                                             -0.274559
# Male/Female Ratio                                                 -0.108796
# # Restaurants nearby                                               0.038703
# Service Fee                                                        0.078897
# Office Size                                                        0.369071
# Registered Users                                                   0.931704
# Active users (weekly average 2019 per terminal)                    0.513393
# Avg. NPS Score                                                     0.147824
#
#                                                  Year Founded  Fridge ID  \
# Subsidy                                              0.049700  -0.062084
# FP/User                                             -0.051898  -0.187896
# NL/User                                             -0.202475   0.094979
# Revenue                                              0.143770  -0.305169
# # Newsletter subscriptions                           0.047212  -0.325508
# Year Founded                                         1.000000  -0.037812
# Fridge ID                                           -0.037812   1.000000
# # Fingerprints                                       0.119853  -0.383138
# Basket size/User/Week                               -0.061810   0.273732
# Male/Female Ratio                                   -0.157158   0.074107
# # Restaurants nearby                                 0.181424  -0.136249
# Service Fee                                          0.091055  -0.032501
# Office Size                                         -0.179148  -0.129286
# Registered Users                                     0.117776  -0.330997
# Active users (weekly average 2019 per terminal)      0.159023  -0.349677
# Avg. NPS Score                                      -0.169206   0.063821
#
#                                                  # Fingerprints  \
# Subsidy                                               -0.004526
# FP/User                                                0.300165
# NL/User                                               -0.073070
# Revenue                                                0.504865
# # Newsletter subscriptions                             0.838215
# Year Founded                                           0.119853
# Fridge ID                                             -0.383138
# # Fingerprints                                         1.000000
# Basket size/User/Week                                 -0.262434
# Male/Female Ratio                                     -0.058084
# # Restaurants nearby                                  -0.020948
# Service Fee                                            0.083479
# Office Size                                            0.248893
# Registered Users                                       0.808139
# Active users (weekly average 2019 per terminal)        0.619787
# Avg. NPS Score                                         0.139418
#
#                                                  Basket size/User/Week  \
# Subsidy                                                       0.195651
# FP/User                                                       0.070158
# NL/User                                                       0.121355
# Revenue                                                       0.132400
# # Newsletter subscriptions                                   -0.274559
# Year Founded                                                 -0.061810
# Fridge ID                                                     0.273732
# # Fingerprints                                               -0.262434
# Basket size/User/Week                                         1.000000
# Male/Female Ratio                                             0.071858
# # Restaurants nearby                                         -0.199906
# Service Fee                                                  -0.087758
# Office Size                                                  -0.156773
# Registered Users                                             -0.271734
# Active users (weekly average 2019 per terminal)              -0.122782
# Avg. NPS Score                                               -0.002213
#
#                                                  Male/Female Ratio  \
# Subsidy                                                   0.024339
# FP/User                                                   0.052112
# NL/User                                                  -0.134380
# Revenue                                                  -0.076353
# # Newsletter subscriptions                               -0.108796
# Year Founded                                             -0.157158
# Fridge ID                                                 0.074107
# # Fingerprints                                           -0.058084
# Basket size/User/Week                                     0.071858
# Male/Female Ratio                                         1.000000
# # Restaurants nearby                                     -0.041986
# Service Fee                                              -0.018165
# Office Size                                               0.130431
# Registered Users                                         -0.090666
# Active users (weekly average 2019 per terminal)          -0.095928
# Avg. NPS Score                                            0.000287
#
#                                                  # Restaurants nearby  \
# Subsidy                                                     -0.033123
# FP/User                                                     -0.166167
# NL/User                                                     -0.133312
# Revenue                                                     -0.116038
# # Newsletter subscriptions                                   0.038703
# Year Founded                                                 0.181424
# Fridge ID                                                   -0.136249
# # Fingerprints                                              -0.020948
# Basket size/User/Week                                       -0.199906
# Male/Female Ratio                                           -0.041986
# # Restaurants nearby                                         1.000000
# Service Fee                                                 -0.038732
# Office Size                                                  0.038403
# Registered Users                                             0.074876
# Active users (weekly average 2019 per terminal)             -0.038554
# Avg. NPS Score                                              -0.029451
#
#                                                  Service Fee  Office Size  \
# Subsidy                                             0.088171    -0.160370
# FP/User                                            -0.003535    -0.126899
# NL/User                                             0.103900    -0.036241
# Revenue                                             0.025224     0.004965
# # Newsletter subscriptions                          0.078897     0.369071
# Year Founded                                        0.091055    -0.179148
# Fridge ID                                          -0.032501    -0.129286
# # Fingerprints                                      0.083479     0.248893
# Basket size/User/Week                              -0.087758    -0.156773
# Male/Female Ratio                                  -0.018165     0.130431
# # Restaurants nearby                               -0.038732     0.038403
# Service Fee                                         1.000000     0.150296
# Office Size                                         0.150296     1.000000
# Registered Users                                    0.060204     0.324528
# Active users (weekly average 2019 per terminal)     0.042203     0.069749
# Avg. NPS Score                                      0.115390     0.231623
#
#                                                  Registered Users  \
# Subsidy                                                 -0.073152
# FP/User                                                 -0.008235
# NL/User                                                 -0.100766
# Revenue                                                  0.309066
# # Newsletter subscriptions                               0.931704
# Year Founded                                             0.117776
# Fridge ID                                               -0.330997
# # Fingerprints                                           0.808139
# Basket size/User/Week                                   -0.271734
# Male/Female Ratio                                       -0.090666
# # Restaurants nearby                                     0.074876
# Service Fee                                              0.060204
# Office Size                                              0.324528
# Registered Users                                         1.000000
# Active users (weekly average 2019 per terminal)          0.426166
# Avg. NPS Score                                           0.077985
#
#                                                  Active users (weekly average 2019 per terminal)  \
# Subsidy                                                                                 0.168224
# FP/User                                                                                 0.201689
# NL/User                                                                                 0.006375
# Revenue                                                                                 0.942982
# # Newsletter subscriptions                                                              0.513393
# Year Founded                                                                            0.159023
# Fridge ID                                                                              -0.349677
# # Fingerprints                                                                          0.619787
# Basket size/User/Week                                                                  -0.122782
# Male/Female Ratio                                                                      -0.095928
# # Restaurants nearby                                                                   -0.038554
# Service Fee                                                                             0.042203
# Office Size                                                                             0.069749
# Registered Users                                                                        0.426166
# Active users (weekly average 2019 per terminal)                                         1.000000
# Avg. NPS Score                                                                          0.104361
#
#                                                  Avg. NPS Score
# Subsidy                                                0.053320
# FP/User                                                0.069560
# NL/User                                                0.225991
# Revenue                                                0.108391
# # Newsletter subscriptions                             0.147824
# Year Founded                                          -0.169206
# Fridge ID                                              0.063821
# # Fingerprints                                         0.139418
# Basket size/User/Week                                 -0.002213
# Male/Female Ratio                                      0.000287
# # Restaurants nearby                                  -0.029451
# Service Fee                                            0.115390
# Office Size                                            0.231623
# Registered Users                                       0.077985
# Active users (weekly average 2019 per terminal)        0.104361
# Avg. NPS Score                                         1.000000

# %%
# For now, we care about the correlation between the features and the to be predicted value.
# The correlation between 'Active users (weekly average 2019 per terminal)' and 'Revenue' is around 94%. 
display(df_train[df_train.columns[1:]].corr()[label_col_name][:-1].sort_values(by='Revenue',ascending=False))
# Out:
#                                                   Revenue
# Revenue                                          1.000000
# Active users (weekly average 2019 per terminal)  0.942982
# # Fingerprints                                   0.504865
# # Newsletter subscriptions                       0.377834
# Registered Users                                 0.309066
# FP/User                                          0.228317
# Year Founded                                     0.143770
# Basket size/User/Week                            0.132400
# Service Fee                                      0.025224
# Office Size                                      0.004965
# NL/User                                          0.001673
# Male/Female Ratio                               -0.076353
# # Restaurants nearby                            -0.116038
# Fridge ID                                       -0.305169

# %%
# Visually, we see that their relation is highly linear.
# i.e. the more the 'Active users (weekly average 2019 per terminal)' the more 'Revenue' will become.
df_train.plot.scatter(x = label_col_name, y = 'Active users (weekly average 2019 per terminal)', s = 100)
# Out:
# <AxesSubplot:xlabel='{Revenue}', ylabel='Active users (weekly average 2019 per terminal)'>

# %% [markdown]
# ## Models: Linear Regression and XGB Regressor

# %%
# We see that the relation between these two columns is highly linear (correlation is ca.94%) 
# this suggests us to build a model using 'Active users (weekly average 2019 per terminal)' to predict 'Revenue'.
# In order to avoid data leakage, we will split the data into train, validation, test and process the data again.

data = pd.read_csv(data_train_path)
data = clean_data(data,'train')
(size_test_set,_) = pd.read_csv(data_test_path).shape
(size_train_set,_) = data.shape

# %%
# We choose str columns with number of unique value <=7, otherwise the resulted table is too sparse
display(data[str_columns].nunique().sort_values())
global str_columns_get_dummies
str_columns_get_dummies = [
    'Location',
    'Maturity',
    'Fridge Type',
    'City',    # we ignore the wired signs in the city names, since they do not bother us.
    'Employee Type' 
]
data_dummies = pd.get_dummies(data[str_columns_get_dummies])
dummies_columns = set(data_dummies.columns)
data = pd.concat([data, data_dummies],axis=1)
# Out:
# Location                  2
# Maturity                  2
# Fridge Type               2
# Company Type*             4
# City                      7
# Employee Type             7
# Lead Source              13
# IndustryNew              15
# Company Type             19
# Industry                 27
# Innercompany Location    28
# dtype: int64

# %%
def get_loss(model,numeric_features,str_features,data,train_index,test_index):
    
    features = numeric_features|str_features
    train_data = data.iloc[train_index]
    test_data  = data.iloc[test_index]
    train_data = fill_missing_value(train_data,numeric_features,str_features)
    test_data = fill_missing_value(test_data,numeric_features,str_features)

    X_train = train_data[features-label_col_name]
    y_train = train_data[label_col_name]
    X_test = test_data[features-label_col_name]
    y_test = test_data[label_col_name]
    
    model = model.fit(X_train, y_train)
    train_y_pred = model.predict(X_train)
    test_y_pred = model.predict(X_test)
    
    train_msr = mean_squared_error(y_train, train_y_pred)
    test_msr = mean_squared_error(y_test, test_y_pred)
    return (train_msr,test_msr)


random_state = 12883823
# we set the n_splits as following to make sure that the size of the hold out set is euqal to the size of test data 
rkf = RepeatedKFold(n_splits=int(size_train_set/size_test_set), n_repeats=10, random_state=random_state)
n = 1

train_lr_baseline_loss = 0
train_lr_positive_corr_loss = 0
train_lr_all_features_loss = 0
train_xgb_reg_loss = 0

test_lr_baseline_loss = 0
test_lr_positive_corr_loss = 0
test_lr_all_features_loss = 0
test_xgb_reg_loss = 0


for train_index, test_index in rkf.split(data):
    
    lr = LinearRegression()
    xgb_reg = XGBRegressor()
    
    lr_baseline_features = set(['Active users (weekly average 2019 per terminal)']) \
                         | label_col_name
    
    lr_positive_corr_features = set([
                                    'Active users (weekly average 2019 per terminal)',
                                    '# Fingerprints',
                                    '# Newsletter subscriptions',
                                    'Registered Users',
                                    'Subsidy',
                                    'FP/User',
                                    'Year Founded',
                                    'Basket size/User/Week'
                                 ])\
                               | label_col_name
                               
    
    
   
    (temp_train_lr_baseline_loss,temp_test_lr_baseline_loss) = get_loss(
        model=lr,
        numeric_features=lr_baseline_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    
    train_lr_baseline_loss+=temp_train_lr_baseline_loss
    test_lr_baseline_loss+=temp_test_lr_baseline_loss
    
    (temp_train_lr_positive_corr_loss,temp_test_lr_positive_corr_loss) = get_loss(
        model=lr,
        numeric_features=lr_positive_corr_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_positive_corr_loss+=temp_train_lr_positive_corr_loss
    test_lr_positive_corr_loss+=temp_test_lr_positive_corr_loss
    
    (temp_train_lr_all_features_loss,temp_test_lr_all_features_loss) = get_loss(
        model=lr,
        numeric_features=numeric_colunms,
        str_features = dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_all_features_loss+=temp_train_lr_all_features_loss
    test_lr_all_features_loss+=temp_test_lr_all_features_loss
    
    (temp_train_xgb_reg_loss,temp_test_xgb_reg_loss)= get_loss(
        model=xgb_reg,
        numeric_features=numeric_colunms,
        str_features = set([]),#dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_xgb_reg_loss+=temp_train_xgb_reg_loss
    test_xgb_reg_loss+=temp_test_xgb_reg_loss
    
    n +=1

    
print('Train:',
      '-lr base line: ',round(train_lr_baseline_loss/n), 
      '-lr more features:',round(train_lr_positive_corr_loss/n),
      '-lr all features: ', round(train_lr_all_features_loss/n),
      '-xgb reg: ', round(train_xgb_reg_loss/n)
      )

print('Test:',
      '-lr base line: ',round(test_lr_baseline_loss/n), 
      '-lr more features:',round(test_lr_positive_corr_loss/n),
      '-lr all features: ', round(test_lr_all_features_loss/n),
      '-xgb reg: ', round(test_xgb_reg_loss/n)
      )
# Out:
# Train: -lr base line:  314 -lr more features: 110 -lr all features:  87 -xgb reg:  0
# Test: -lr base line:  360 -lr more features: 181 -lr all features:  15549692040757088256 -xgb reg:  489

# %% [markdown]
# ## Remove Outlier in Target Value Set
# Because linear regression is sensitive to outliers, after remove them we have a better result.
# <br>
# We remove revenue > 300 data points

# %%
data = pd.read_csv(data_train_path)
data = clean_data(data,'train')
(size_test_set,_) = pd.read_csv(data_test_path).shape
(size_train_set,_) = data.shape
data = data[data.Revenue<300]

global str_columns_get_dummies
str_columns_get_dummies = [
    'Location',
    'Maturity',
    'Fridge Type',
    'City',    # we ignore the wired signs in the city names, since they do not bother us.
    'Employee Type' 
]
data_dummies = pd.get_dummies(data[str_columns_get_dummies])
dummies_columns = set(data_dummies.columns)
data = pd.concat([data, data_dummies],axis=1)


def get_loss(model,numeric_features,str_features,data,train_index,test_index):
    
    features = numeric_features|str_features
    train_data = data.iloc[train_index]
    test_data  = data.iloc[test_index]
    train_data = fill_missing_value(train_data,numeric_features,str_features)
    test_data = fill_missing_value(test_data,numeric_features,str_features)

    X_train = train_data[features-label_col_name]
    y_train = train_data[label_col_name]
    X_test = test_data[features-label_col_name]
    y_test = test_data[label_col_name]
    
    model = model.fit(X_train, y_train)
    train_y_pred = model.predict(X_train)
    test_y_pred = model.predict(X_test)
    
    train_msr = mean_squared_error(y_train, train_y_pred)
    test_msr = mean_squared_error(y_test, test_y_pred)
    return (train_msr,test_msr)


random_state = 12883823
# we set the n_splits as following to make sure that the size of the hold out set is euqal to the size of test data 
# todo: shows that 3 can give stable train, test evaluation loss
rkf = RepeatedKFold(n_splits=int(size_train_set/size_test_set), n_repeats=3, random_state=random_state)
n = 1

train_lr_baseline_loss = 0
train_lr_positive_corr_loss = 0
train_lr_all_features_loss = 0
train_xgb_reg_loss = 0

test_lr_baseline_loss = 0
test_lr_positive_corr_loss = 0
test_lr_all_features_loss = 0
test_xgb_reg_loss = 0


for train_index, test_index in rkf.split(data):
    
    lr = LinearRegression()
    xgb_reg = XGBRegressor()
    
    lr_baseline_features = set(['Active users (weekly average 2019 per terminal)']) \
                         | label_col_name
    
    lr_positive_corr_features = set([
                                    'Active users (weekly average 2019 per terminal)',
                                    '# Fingerprints',
                                    '# Newsletter subscriptions',
                                    'Registered Users',
                                    'Subsidy',
                                    'FP/User',
                                    'Year Founded',
                                    'Basket size/User/Week'
                                 ])\
                               | label_col_name
                               
    
    
   
    (temp_train_lr_baseline_loss,temp_test_lr_baseline_loss) = get_loss(
        model=lr,
        numeric_features=lr_baseline_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    
    train_lr_baseline_loss+=temp_train_lr_baseline_loss
    test_lr_baseline_loss+=temp_test_lr_baseline_loss
    
    (temp_train_lr_positive_corr_loss,temp_test_lr_positive_corr_loss) = get_loss(
        model=lr,
        numeric_features=lr_positive_corr_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_positive_corr_loss+=temp_train_lr_positive_corr_loss
    test_lr_positive_corr_loss+=temp_test_lr_positive_corr_loss
    
    (temp_train_lr_all_features_loss,temp_test_lr_all_features_loss) = get_loss(
        model=lr,
        numeric_features=numeric_colunms,
        str_features = dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_all_features_loss+=temp_train_lr_all_features_loss
    test_lr_all_features_loss+=temp_test_lr_all_features_loss
    
    (temp_train_xgb_reg_loss,temp_test_xgb_reg_loss)= get_loss(
        model=xgb_reg,
        numeric_features=numeric_colunms,
        str_features = set([]),#dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_xgb_reg_loss+=temp_train_xgb_reg_loss
    test_xgb_reg_loss+=temp_test_xgb_reg_loss
    
    n +=1

    
print('Train:',
      '-lr base line: ',round(train_lr_baseline_loss/n), 
      '-lr more features:',round(train_lr_positive_corr_loss/n),
      '-lr all features: ', round(train_lr_all_features_loss/n),
      '-xgb reg: ', round(train_xgb_reg_loss/n)
      )

print('Test:',
      '-lr base line: ',round(test_lr_baseline_loss/n), 
      '-lr more features:',round(test_lr_positive_corr_loss/n),
      '-lr all features: ', round(test_lr_all_features_loss/n),
      '-xgb reg: ', round(test_xgb_reg_loss/n)
      )
# Out:
# Train: -lr base line:  221 -lr more features: 61 -lr all features:  47 -xgb reg:  0
# Test: -lr base line:  232 -lr more features: 92 -lr all features:  11904794902809554944 -xgb reg:  119

# %% [markdown]
# ## Temporary Summary of Model Performance
# As we have seen that the performance before removing outlier is:
# <br>
# Test: -lr base line:  360 -lr more features: 181 -lr all features:  15549692040757088256 - xgb reg:  489
# <br>
# After removing outlier is:
# <br>
# Test: -lr base line:  232 -lr more features: 92 -lr all features:  11904794902809554944 - xgb reg:  119
# <br>
# xgb reg is 300% better than before, yet lr more features is still the best one.<br>
# prediction over train set of lr all features implies that we shall not use all features, but the one from the lr more features model.
# <br>
# We will give a try of autoML with autokeras (autosklearn does not support windows which is a os system.).
# <br>
# Useing the following commands to install.
# !pip install git+https://github.com/keras-team/keras-tuner.git
# !pip install autokeras

# %% [markdown]
# ## AutoMl vs. Best Model lr more feartures

# %%
from autokeras import StructuredDataRegressor

data = pd.read_csv(data_train_path)
data = clean_data(data,'train')
(size_test_set,_) = pd.read_csv(data_test_path).shape
(size_train_set,_) = data.shape
data = data[data.Revenue<300]

global str_columns_get_dummies
str_columns_get_dummies = [
    'Location',
    'Maturity',
    'Fridge Type',
    'City',    # we ignore the wired signs in the city names, since they do not bother us.
    'Employee Type' 
]
data_dummies = pd.get_dummies(data[str_columns_get_dummies])
dummies_columns = set(data_dummies.columns)
data = pd.concat([data, data_dummies],axis=1)


def prepare_train_test(numeric_features,str_features,data,train_index,test_index):
    
    features = numeric_features|str_features
    train_data = data.iloc[train_index]
    test_data  = data.iloc[test_index]
    train_data = fill_missing_value(train_data,numeric_features,str_features)
    test_data = fill_missing_value(test_data,numeric_features,str_features)

    X_train = train_data[features-label_col_name]
    y_train = train_data[label_col_name]
    X_test = test_data[features-label_col_name]
    y_test = test_data[label_col_name]
    

    return X_train,y_train,X_test,y_test


random_state = 12883823
# we set the n_splits as following to make sure that the size of the hold out set is euqal to the size of test data 
rkf = RepeatedKFold(n_splits=int(size_train_set/size_test_set), n_repeats=3, random_state=random_state)
n = 1

train_auto_ml_loss = 0
test_auto_ml_loss = 0
train_lr_positive_corr_loss = 0
test_lr_positive_corr_loss = 0


for train_index, test_index in rkf.split(data):
    
    
    lr = LinearRegression()
    
    
    lr_positive_corr_features = set([
                                    'Active users (weekly average 2019 per terminal)',
                                    '# Fingerprints',
                                    '# Newsletter subscriptions',
                                    'Registered Users',
                                    'Subsidy',
                                    'FP/User',
                                    'Year Founded',
                                    'Basket size/User/Week'
                                 ])\
                               | label_col_name
    
    (temp_train_lr_positive_corr_loss,temp_test_lr_positive_corr_loss) = get_loss(
        model=lr,
        numeric_features=lr_positive_corr_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    
    train_lr_positive_corr_loss+=temp_train_lr_positive_corr_loss
    test_lr_positive_corr_loss+=temp_test_lr_positive_corr_loss
    
    
    
    X_train,y_train,X_test,y_test = prepare_train_test(
        numeric_features=numeric_colunms,
        str_features=set([]),
        data=data,
        train_index=train_index,
        test_index=test_index)
    
    search = StructuredDataRegressor(max_trials=15, loss='mean_absolute_error')
    search.fit(x=X_train, y=y_train, verbose=0)
    temp_train_auto_ml_loss,_ = search.evaluate(X_train, y_train, verbose=0)
    temp_test_auto_ml_loss,_ = search.evaluate(X_test, y_test, verbose=0)
    train_auto_ml_loss+=temp_train_auto_ml_loss
    test_auto_ml_loss+=temp_test_auto_ml_loss
    n+=1
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/243
# 4/4 [==============================] - 2s 5ms/step - loss: 80.0503 - mean_squared_error: 8360.4053
# Epoch 2/243
# 4/4 [==============================] - 0s 6ms/step - loss: 79.9600 - mean_squared_error: 8350.3359
# Epoch 3/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.9258 - mean_squared_error: 8332.3066
# Epoch 4/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.8137 - mean_squared_error: 8322.0254
# Epoch 5/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.8471 - mean_squared_error: 8330.9053
# Epoch 6/243
# 4/4 [==============================] - 0s 6ms/step - loss: 79.6515 - mean_squared_error: 8295.8701
# Epoch 7/243
# 4/4 [==============================] - 0s 6ms/step - loss: 79.6329 - mean_squared_error: 8296.4424
# Epoch 8/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.6054 - mean_squared_error: 8294.8760
# Epoch 9/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.4954 - mean_squared_error: 8268.3838
# Epoch 10/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.4246 - mean_squared_error: 8253.2578
# Epoch 11/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.1900 - mean_squared_error: 8229.8408
# Epoch 12/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.1328 - mean_squared_error: 8220.2168
# Epoch 13/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.1986 - mean_squared_error: 8215.8076
# Epoch 14/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.0312 - mean_squared_error: 8201.1484
# Epoch 15/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.0164 - mean_squared_error: 8201.1904
# Epoch 16/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.8110 - mean_squared_error: 8158.3413
# Epoch 17/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.8664 - mean_squared_error: 8168.6460
# Epoch 18/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.7802 - mean_squared_error: 8158.3906
# Epoch 19/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.6746 - mean_squared_error: 8141.4990
# Epoch 20/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.6862 - mean_squared_error: 8138.5347
# Epoch 21/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.5527 - mean_squared_error: 8121.6909
# Epoch 22/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.4654 - mean_squared_error: 8099.3789
# Epoch 23/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.3795 - mean_squared_error: 8099.7153
# Epoch 24/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.2911 - mean_squared_error: 8071.9922
# Epoch 25/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.1337 - mean_squared_error: 8063.3203
# Epoch 26/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.1928 - mean_squared_error: 8070.5605
# Epoch 27/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.0093 - mean_squared_error: 8031.2725
# Epoch 28/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.9522 - mean_squared_error: 8025.9897
# Epoch 29/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.8137 - mean_squared_error: 8011.4590
# Epoch 30/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.7733 - mean_squared_error: 8002.7642
# Epoch 31/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.6604 - mean_squared_error: 7987.8174
# Epoch 32/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.5146 - mean_squared_error: 7959.2007
# Epoch 33/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.5017 - mean_squared_error: 7960.3203
# Epoch 34/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.4377 - mean_squared_error: 7951.3091
# Epoch 35/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.4807 - mean_squared_error: 7964.1074
# Epoch 36/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.2386 - mean_squared_error: 7928.9463
# Epoch 37/243
# 4/4 [==============================] - 0s 5ms/step - loss: 77.1523 - mean_squared_error: 7917.7344
# Epoch 38/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.9556 - mean_squared_error: 7887.6152
# Epoch 39/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.0190 - mean_squared_error: 7883.6934
# Epoch 40/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.7828 - mean_squared_error: 7862.7949
# Epoch 41/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.7867 - mean_squared_error: 7844.3525
# Epoch 42/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.7297 - mean_squared_error: 7842.7329
# Epoch 43/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.3169 - mean_squared_error: 7788.9780
# Epoch 44/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.5237 - mean_squared_error: 7817.0898
# Epoch 45/243
# 4/4 [==============================] - 0s 3ms/step - loss: 76.3211 - mean_squared_error: 7775.5688
# Epoch 46/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.2445 - mean_squared_error: 7774.2441
# Epoch 47/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.1617 - mean_squared_error: 7764.6558
# Epoch 48/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.0468 - mean_squared_error: 7739.1733
# Epoch 49/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.9078 - mean_squared_error: 7707.0742
# Epoch 50/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.8193 - mean_squared_error: 7713.9175
# Epoch 51/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.6105 - mean_squared_error: 7664.5732
# Epoch 52/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.6629 - mean_squared_error: 7693.8989
# Epoch 53/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.7270 - mean_squared_error: 7692.6470
# Epoch 54/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.4717 - mean_squared_error: 7660.9971
# Epoch 55/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.4140 - mean_squared_error: 7648.2388
# Epoch 56/243
# 4/4 [==============================] - 0s 3ms/step - loss: 75.1388 - mean_squared_error: 7609.8633
# Epoch 57/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.1055 - mean_squared_error: 7600.8193
# Epoch 58/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.1657 - mean_squared_error: 7609.4004
# Epoch 59/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.9562 - mean_squared_error: 7567.1709
# Epoch 60/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.7024 - mean_squared_error: 7550.2329
# Epoch 61/243
# 4/4 [==============================] - 0s 5ms/step - loss: 74.6625 - mean_squared_error: 7542.4521
# Epoch 62/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.4072 - mean_squared_error: 7501.2603
# Epoch 63/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.3874 - mean_squared_error: 7486.8149
# Epoch 64/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.2972 - mean_squared_error: 7481.9131
# Epoch 65/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.7959 - mean_squared_error: 7413.2764
# Epoch 66/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.9735 - mean_squared_error: 7436.4561
# Epoch 67/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.6732 - mean_squared_error: 7392.0400
# Epoch 68/243
# 4/4 [==============================] - 0s 3ms/step - loss: 73.7706 - mean_squared_error: 7390.6704
# Epoch 69/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.5983 - mean_squared_error: 7363.8774
# Epoch 70/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.3869 - mean_squared_error: 7342.4644
# Epoch 71/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.1032 - mean_squared_error: 7316.0166
# Epoch 72/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.2017 - mean_squared_error: 7329.1631
# Epoch 73/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.0165 - mean_squared_error: 7274.9243
# Epoch 74/243
# 4/4 [==============================] - 0s 5ms/step - loss: 72.7677 - mean_squared_error: 7245.1230
# Epoch 75/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.8038 - mean_squared_error: 7246.8945
# Epoch 76/243
# 4/4 [==============================] - 0s 5ms/step - loss: 72.5807 - mean_squared_error: 7241.9243
# Epoch 77/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.3502 - mean_squared_error: 7202.0615
# Epoch 78/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.3538 - mean_squared_error: 7210.5010
# Epoch 79/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.8489 - mean_squared_error: 7130.9937
# Epoch 80/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.8074 - mean_squared_error: 7119.0371
# Epoch 81/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.8605 - mean_squared_error: 7119.8687
# Epoch 82/243
# 4/4 [==============================] - 0s 5ms/step - loss: 71.5627 - mean_squared_error: 7108.3711
# Epoch 83/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.8261 - mean_squared_error: 7124.1914
# Epoch 84/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.1819 - mean_squared_error: 7020.3887
# Epoch 85/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.4421 - mean_squared_error: 7063.1675
# Epoch 86/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.0509 - mean_squared_error: 7013.0439
# Epoch 87/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.4600 - mean_squared_error: 6921.7075
# Epoch 88/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.8176 - mean_squared_error: 6967.6870
# Epoch 89/243
# 4/4 [==============================] - 0s 5ms/step - loss: 70.5735 - mean_squared_error: 6932.3359
# Epoch 90/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.3117 - mean_squared_error: 6897.9932
# Epoch 91/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.1442 - mean_squared_error: 6881.4976
# Epoch 92/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.7522 - mean_squared_error: 6827.7349
# Epoch 93/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.9762 - mean_squared_error: 6872.0752
# Epoch 94/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.7796 - mean_squared_error: 6856.0938
# Epoch 95/243
# 4/4 [==============================] - 0s 5ms/step - loss: 69.1205 - mean_squared_error: 6716.7388
# Epoch 96/243
# 4/4 [==============================] - 0s 5ms/step - loss: 69.3377 - mean_squared_error: 6765.4136
# Epoch 97/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.2435 - mean_squared_error: 6777.4634
# Epoch 98/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.5658 - mean_squared_error: 6645.7583
# Epoch 99/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.4112 - mean_squared_error: 6674.8950
# Epoch 100/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.6556 - mean_squared_error: 6691.7593
# Epoch 101/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.3660 - mean_squared_error: 6664.9751
# Epoch 102/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.2280 - mean_squared_error: 6642.8657
# Epoch 103/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.3420 - mean_squared_error: 6680.6675
# Epoch 104/243
# 4/4 [==============================] - 0s 4ms/step - loss: 67.5169 - mean_squared_error: 6561.9131
# Epoch 105/243
# 4/4 [==============================] - 0s 4ms/step - loss: 67.3850 - mean_squared_error: 6500.7124
# Epoch 106/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.9433 - mean_squared_error: 6451.3779
# Epoch 107/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.7467 - mean_squared_error: 6395.3877
# Epoch 108/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.6812 - mean_squared_error: 6406.5059
# Epoch 109/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.9244 - mean_squared_error: 6435.9121
# Epoch 110/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.3281 - mean_squared_error: 6375.4614
# Epoch 111/243
# 4/4 [==============================] - 0s 4ms/step - loss: 65.9890 - mean_squared_error: 6333.4927
# Epoch 112/243
# 4/4 [==============================] - 0s 3ms/step - loss: 66.3820 - mean_squared_error: 6401.7954
# Epoch 113/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.2788 - mean_squared_error: 6331.7080
# Epoch 114/243
# 4/4 [==============================] - 0s 3ms/step - loss: 65.0329 - mean_squared_error: 6195.7871
# Epoch 115/243
# 4/4 [==============================] - 0s 4ms/step - loss: 65.4110 - mean_squared_error: 6218.0615
# Epoch 116/243
# 4/4 [==============================] - 0s 4ms/step - loss: 65.0123 - mean_squared_error: 6158.4683
# Epoch 117/243
# 4/4 [==============================] - 0s 3ms/step - loss: 64.7750 - mean_squared_error: 6199.2715
# Epoch 118/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.4942 - mean_squared_error: 6103.7588
# Epoch 119/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.6351 - mean_squared_error: 6131.4097
# Epoch 120/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.0283 - mean_squared_error: 6052.2959
# Epoch 121/243
# 4/4 [==============================] - 0s 5ms/step - loss: 63.8651 - mean_squared_error: 6065.2866
# Epoch 122/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.4909 - mean_squared_error: 6001.4194
# Epoch 123/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.1703 - mean_squared_error: 5931.0649
# Epoch 124/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.5164 - mean_squared_error: 5999.4917
# Epoch 125/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.0177 - mean_squared_error: 5967.0122
# Epoch 126/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.2497 - mean_squared_error: 5932.4702
# Epoch 127/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.6039 - mean_squared_error: 5880.7783
# Epoch 128/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.6033 - mean_squared_error: 5909.9873
# Epoch 129/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.0125 - mean_squared_error: 5794.5996
# Epoch 130/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.6085 - mean_squared_error: 5737.5596
# Epoch 131/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.0283 - mean_squared_error: 5793.9995
# Epoch 132/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.1059 - mean_squared_error: 5839.3730
# Epoch 133/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.0048 - mean_squared_error: 5671.8931
# Epoch 134/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.6047 - mean_squared_error: 5786.7192
# Epoch 135/243
# 4/4 [==============================] - 0s 3ms/step - loss: 60.1120 - mean_squared_error: 5557.2642
# Epoch 136/243
# 4/4 [==============================] - 0s 3ms/step - loss: 60.7339 - mean_squared_error: 5627.8853
# Epoch 137/243
# 4/4 [==============================] - 0s 4ms/step - loss: 59.7444 - mean_squared_error: 5553.9409
# Epoch 138/243
# 4/4 [==============================] - 0s 4ms/step - loss: 59.6724 - mean_squared_error: 5476.3164
# Epoch 139/243
# 4/4 [==============================] - 0s 6ms/step - loss: 59.2383 - mean_squared_error: 5505.6426
# Epoch 140/243
# 4/4 [==============================] - 0s 3ms/step - loss: 59.2421 - mean_squared_error: 5451.3325
# Epoch 141/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.6536 - mean_squared_error: 5362.7456
# Epoch 142/243
# 4/4 [==============================] - 0s 5ms/step - loss: 58.6042 - mean_squared_error: 5377.0034
# Epoch 143/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.3841 - mean_squared_error: 5314.4497
# Epoch 144/243
# 4/4 [==============================] - 0s 5ms/step - loss: 58.3804 - mean_squared_error: 5369.5391
# Epoch 145/243
# 4/4 [==============================] - 0s 5ms/step - loss: 57.4616 - mean_squared_error: 5198.1909
# Epoch 146/243
# 4/4 [==============================] - 0s 5ms/step - loss: 57.5380 - mean_squared_error: 5293.0840
# Epoch 147/243
# 4/4 [==============================] - 0s 5ms/step - loss: 57.5453 - mean_squared_error: 5239.1313
# Epoch 148/243
# 4/4 [==============================] - 0s 5ms/step - loss: 56.7289 - mean_squared_error: 5104.6133
# Epoch 149/243
# 4/4 [==============================] - 0s 5ms/step - loss: 57.0831 - mean_squared_error: 5199.5562
# Epoch 150/243
# 4/4 [==============================] - 0s 5ms/step - loss: 56.8280 - mean_squared_error: 5082.3174
# Epoch 151/243
# 4/4 [==============================] - 0s 5ms/step - loss: 55.9932 - mean_squared_error: 5036.7822
# Epoch 152/243
# 4/4 [==============================] - 0s 4ms/step - loss: 56.2291 - mean_squared_error: 5111.7363
# Epoch 153/243
# 4/4 [==============================] - 0s 5ms/step - loss: 55.3679 - mean_squared_error: 4942.8247
# Epoch 154/243
# 4/4 [==============================] - 0s 5ms/step - loss: 55.4240 - mean_squared_error: 4996.9121
# Epoch 155/243
# 4/4 [==============================] - 0s 5ms/step - loss: 54.4948 - mean_squared_error: 4915.3501
# Epoch 156/243
# 4/4 [==============================] - 0s 5ms/step - loss: 55.2148 - mean_squared_error: 5006.4614
# Epoch 157/243
# 4/4 [==============================] - 0s 6ms/step - loss: 54.6541 - mean_squared_error: 4913.2886
# Epoch 158/243
# 4/4 [==============================] - 0s 5ms/step - loss: 54.2543 - mean_squared_error: 4876.1538
# Epoch 159/243
# 4/4 [==============================] - 0s 4ms/step - loss: 54.5127 - mean_squared_error: 4892.0742
# Epoch 160/243
# 4/4 [==============================] - 0s 5ms/step - loss: 54.2166 - mean_squared_error: 4805.0327
# Epoch 161/243
# 4/4 [==============================] - 0s 5ms/step - loss: 53.1721 - mean_squared_error: 4744.0571
# Epoch 162/243
# 4/4 [==============================] - 0s 5ms/step - loss: 53.2463 - mean_squared_error: 4724.6431
# Epoch 163/243
# 4/4 [==============================] - 0s 5ms/step - loss: 52.7807 - mean_squared_error: 4674.8730
# Epoch 164/243
# 4/4 [==============================] - 0s 5ms/step - loss: 52.9328 - mean_squared_error: 4671.5972
# Epoch 165/243
# 4/4 [==============================] - 0s 5ms/step - loss: 52.4150 - mean_squared_error: 4628.7729
# Epoch 166/243
# 4/4 [==============================] - 0s 5ms/step - loss: 52.2852 - mean_squared_error: 4569.6895
# Epoch 167/243
# 4/4 [==============================] - 0s 5ms/step - loss: 51.8909 - mean_squared_error: 4529.3916
# Epoch 168/243
# 4/4 [==============================] - 0s 5ms/step - loss: 51.0309 - mean_squared_error: 4393.2812
# Epoch 169/243
# 4/4 [==============================] - 0s 5ms/step - loss: 50.8872 - mean_squared_error: 4484.8491
# Epoch 170/243
# 4/4 [==============================] - 0s 6ms/step - loss: 51.0293 - mean_squared_error: 4452.8267
# Epoch 171/243
# 4/4 [==============================] - 0s 6ms/step - loss: 51.0550 - mean_squared_error: 4477.9341
# Epoch 172/243
# 4/4 [==============================] - 0s 3ms/step - loss: 51.3289 - mean_squared_error: 4391.1987
# Epoch 173/243
# 4/4 [==============================] - 0s 4ms/step - loss: 51.2348 - mean_squared_error: 4446.5112
# Epoch 174/243
# 4/4 [==============================] - 0s 4ms/step - loss: 50.4575 - mean_squared_error: 4422.1479
# Epoch 175/243
# 4/4 [==============================] - 0s 4ms/step - loss: 49.7179 - mean_squared_error: 4276.7388
# Epoch 176/243
# 4/4 [==============================] - 0s 3ms/step - loss: 49.0867 - mean_squared_error: 4212.0518
# Epoch 177/243
# 4/4 [==============================] - 0s 5ms/step - loss: 49.3854 - mean_squared_error: 4270.9277
# Epoch 178/243
# 4/4 [==============================] - 0s 5ms/step - loss: 49.1079 - mean_squared_error: 4238.1694
# Epoch 179/243
# 4/4 [==============================] - 0s 5ms/step - loss: 48.8402 - mean_squared_error: 4236.3853
# Epoch 180/243
# 4/4 [==============================] - 0s 5ms/step - loss: 48.7883 - mean_squared_error: 4230.6367
# Epoch 181/243
# 4/4 [==============================] - 0s 5ms/step - loss: 48.6231 - mean_squared_error: 4208.0991
# Epoch 182/243
# 4/4 [==============================] - 0s 5ms/step - loss: 49.0424 - mean_squared_error: 4122.7959
# Epoch 183/243
# 4/4 [==============================] - 0s 4ms/step - loss: 48.8390 - mean_squared_error: 4185.5034
# Epoch 184/243
# 4/4 [==============================] - 0s 4ms/step - loss: 47.5358 - mean_squared_error: 4010.5789
# Epoch 185/243
# 4/4 [==============================] - 0s 4ms/step - loss: 48.0826 - mean_squared_error: 4042.0369
# Epoch 186/243
# 4/4 [==============================] - 0s 4ms/step - loss: 47.0666 - mean_squared_error: 3997.6777
# Epoch 187/243
# 4/4 [==============================] - 0s 5ms/step - loss: 47.0272 - mean_squared_error: 3969.3318
# Epoch 188/243
# 4/4 [==============================] - 0s 5ms/step - loss: 47.0428 - mean_squared_error: 3967.4265
# Epoch 189/243
# 4/4 [==============================] - 0s 5ms/step - loss: 46.3613 - mean_squared_error: 3988.0803
# Epoch 190/243
# 4/4 [==============================] - 0s 5ms/step - loss: 46.1512 - mean_squared_error: 3829.6052
# Epoch 191/243
# 4/4 [==============================] - 0s 5ms/step - loss: 45.8319 - mean_squared_error: 3810.9583
# Epoch 192/243
# 4/4 [==============================] - 0s 5ms/step - loss: 45.7734 - mean_squared_error: 3791.3015
# Epoch 193/243
# 4/4 [==============================] - 0s 5ms/step - loss: 44.7431 - mean_squared_error: 3673.4761
# Epoch 194/243
# 4/4 [==============================] - 0s 5ms/step - loss: 44.8680 - mean_squared_error: 3788.8901
# Epoch 195/243
# 4/4 [==============================] - 0s 4ms/step - loss: 46.5144 - mean_squared_error: 3845.6409
# Epoch 196/243
# 4/4 [==============================] - 0s 4ms/step - loss: 45.1425 - mean_squared_error: 3684.1873
# Epoch 197/243
# 4/4 [==============================] - 0s 5ms/step - loss: 44.7664 - mean_squared_error: 3695.9958
# Epoch 198/243
# 4/4 [==============================] - 0s 5ms/step - loss: 44.7150 - mean_squared_error: 3643.0642
# Epoch 199/243
# 4/4 [==============================] - 0s 4ms/step - loss: 44.2483 - mean_squared_error: 3642.2087
# Epoch 200/243
# 4/4 [==============================] - 0s 4ms/step - loss: 44.0312 - mean_squared_error: 3676.7590
# Epoch 201/243
# 4/4 [==============================] - 0s 4ms/step - loss: 44.2295 - mean_squared_error: 3692.0796
# Epoch 202/243
# 4/4 [==============================] - 0s 4ms/step - loss: 43.6658 - mean_squared_error: 3528.9126
# Epoch 203/243
# 4/4 [==============================] - 0s 4ms/step - loss: 43.9893 - mean_squared_error: 3592.1145
# Epoch 204/243
# 4/4 [==============================] - 0s 3ms/step - loss: 44.3290 - mean_squared_error: 3595.1194
# Epoch 205/243
# 4/4 [==============================] - 0s 4ms/step - loss: 43.2593 - mean_squared_error: 3482.0508
# Epoch 206/243
# 4/4 [==============================] - 0s 4ms/step - loss: 43.9862 - mean_squared_error: 3557.4944
# Epoch 207/243
# 4/4 [==============================] - 0s 4ms/step - loss: 42.6095 - mean_squared_error: 3353.5947
# Epoch 208/243
# 4/4 [==============================] - 0s 4ms/step - loss: 43.2750 - mean_squared_error: 3373.2085
# Epoch 209/243
# 4/4 [==============================] - 0s 5ms/step - loss: 43.1873 - mean_squared_error: 3474.7473
# Epoch 210/243
# 4/4 [==============================] - 0s 3ms/step - loss: 42.1499 - mean_squared_error: 3355.9985
# Epoch 211/243
# 4/4 [==============================] - 0s 5ms/step - loss: 42.3642 - mean_squared_error: 3381.9954
# Epoch 212/243
# 4/4 [==============================] - 0s 4ms/step - loss: 41.6886 - mean_squared_error: 3256.5793
# Epoch 213/243
# 4/4 [==============================] - 0s 3ms/step - loss: 41.4700 - mean_squared_error: 3252.4863
# Epoch 214/243
# 4/4 [==============================] - 0s 4ms/step - loss: 41.5507 - mean_squared_error: 3251.5720
# Epoch 215/243
# 4/4 [==============================] - 0s 4ms/step - loss: 41.9674 - mean_squared_error: 3334.9780
# Epoch 216/243
# 4/4 [==============================] - 0s 5ms/step - loss: 41.1436 - mean_squared_error: 3205.7825
# Epoch 217/243
# 4/4 [==============================] - 0s 4ms/step - loss: 42.2992 - mean_squared_error: 3289.2214
# Epoch 218/243
# 4/4 [==============================] - 0s 4ms/step - loss: 40.9193 - mean_squared_error: 3233.6257
# Epoch 219/243
# 4/4 [==============================] - 0s 4ms/step - loss: 41.5742 - mean_squared_error: 3233.9131
# Epoch 220/243
# 4/4 [==============================] - 0s 5ms/step - loss: 40.8048 - mean_squared_error: 3092.0173
# Epoch 221/243
# 4/4 [==============================] - 0s 6ms/step - loss: 40.4650 - mean_squared_error: 3131.7178
# Epoch 222/243
# 4/4 [==============================] - 0s 6ms/step - loss: 41.7862 - mean_squared_error: 3337.6431
# Epoch 223/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.6063 - mean_squared_error: 3008.2993
# Epoch 224/243
# 4/4 [==============================] - 0s 5ms/step - loss: 40.4825 - mean_squared_error: 3103.1697
# Epoch 225/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.8099 - mean_squared_error: 3143.2358
# Epoch 226/243
# 4/4 [==============================] - 0s 6ms/step - loss: 40.2027 - mean_squared_error: 3174.2556
# Epoch 227/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.0831 - mean_squared_error: 2949.8435
# Epoch 228/243
# 4/4 [==============================] - 0s 4ms/step - loss: 40.1911 - mean_squared_error: 3132.3315
# Epoch 229/243
# 4/4 [==============================] - 0s 3ms/step - loss: 39.2490 - mean_squared_error: 2977.8684
# Epoch 230/243
# 4/4 [==============================] - 0s 4ms/step - loss: 38.9964 - mean_squared_error: 2948.9414
# Epoch 231/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.1824 - mean_squared_error: 2900.2888
# Epoch 232/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.9823 - mean_squared_error: 3033.6973
# Epoch 233/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.7360 - mean_squared_error: 2993.6667
# Epoch 234/243
# 4/4 [==============================] - 0s 4ms/step - loss: 38.3414 - mean_squared_error: 2905.0630
# Epoch 235/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.4290 - mean_squared_error: 2968.5579
# Epoch 236/243
# 4/4 [==============================] - 0s 5ms/step - loss: 39.2866 - mean_squared_error: 3056.8794
# Epoch 237/243
# 4/4 [==============================] - 0s 5ms/step - loss: 38.9743 - mean_squared_error: 2960.9619
# Epoch 238/243
# 4/4 [==============================] - 0s 5ms/step - loss: 38.8208 - mean_squared_error: 2944.1416
# Epoch 239/243
# 4/4 [==============================] - 0s 5ms/step - loss: 38.1224 - mean_squared_error: 2834.3574
# Epoch 240/243
# 4/4 [==============================] - 0s 5ms/step - loss: 36.9366 - mean_squared_error: 2778.1941
# Epoch 241/243
# 4/4 [==============================] - 0s 5ms/step - loss: 40.2654 - mean_squared_error: 3003.3923
# Epoch 242/243
# 4/4 [==============================] - 0s 5ms/step - loss: 36.9111 - mean_squared_error: 2752.9575
# Epoch 243/243
# 4/4 [==============================] - 0s 5ms/step - loss: 38.6422 - mean_squared_error: 2881.7505
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/243
# 4/4 [==============================] - 2s 5ms/step - loss: 81.1742 - mean_squared_error: 8835.6768
# Epoch 2/243
# 4/4 [==============================] - 0s 6ms/step - loss: 81.1379 - mean_squared_error: 8839.2412
# Epoch 3/243
# 4/4 [==============================] - 0s 4ms/step - loss: 81.0693 - mean_squared_error: 8831.4844
# Epoch 4/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.9685 - mean_squared_error: 8808.1973
# Epoch 5/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.8394 - mean_squared_error: 8767.6885
# Epoch 6/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.8742 - mean_squared_error: 8791.1191
# Epoch 7/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.6726 - mean_squared_error: 8749.0391
# Epoch 8/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.6079 - mean_squared_error: 8750.0098
# Epoch 9/243
# 4/4 [==============================] - 0s 5ms/step - loss: 80.4829 - mean_squared_error: 8740.4414
# Epoch 10/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.3726 - mean_squared_error: 8710.1602
# Epoch 11/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.3999 - mean_squared_error: 8714.8291
# Epoch 12/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.3028 - mean_squared_error: 8696.0908
# Epoch 13/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.1767 - mean_squared_error: 8677.8359
# Epoch 14/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.1435 - mean_squared_error: 8675.9766
# Epoch 15/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.0546 - mean_squared_error: 8662.3545
# Epoch 16/243
# 4/4 [==============================] - 0s 4ms/step - loss: 80.1082 - mean_squared_error: 8675.6973
# Epoch 17/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.8924 - mean_squared_error: 8636.6914
# Epoch 18/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.7133 - mean_squared_error: 8613.2295
# Epoch 19/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.6148 - mean_squared_error: 8603.6973
# Epoch 20/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.6897 - mean_squared_error: 8611.3369
# Epoch 21/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.5451 - mean_squared_error: 8573.1943
# Epoch 22/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.2982 - mean_squared_error: 8545.3613
# Epoch 23/243
# 4/4 [==============================] - 0s 3ms/step - loss: 79.2587 - mean_squared_error: 8537.9043
# Epoch 24/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.2628 - mean_squared_error: 8545.6758
# Epoch 25/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.2329 - mean_squared_error: 8546.7959
# Epoch 26/243
# 4/4 [==============================] - 0s 4ms/step - loss: 79.1259 - mean_squared_error: 8511.4180
# Epoch 27/243
# 4/4 [==============================] - 0s 5ms/step - loss: 79.0446 - mean_squared_error: 8493.9072
# Epoch 28/243
# 4/4 [==============================] - 0s 9ms/step - loss: 78.9825 - mean_squared_error: 8479.9551
# Epoch 29/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.7035 - mean_squared_error: 8452.3203
# Epoch 30/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.7033 - mean_squared_error: 8445.7402
# Epoch 31/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.4746 - mean_squared_error: 8417.1416
# Epoch 32/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.6460 - mean_squared_error: 8432.0811
# Epoch 33/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.3414 - mean_squared_error: 8387.6357
# Epoch 34/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.2960 - mean_squared_error: 8409.7803
# Epoch 35/243
# 4/4 [==============================] - 0s 4ms/step - loss: 78.1368 - mean_squared_error: 8354.1982
# Epoch 36/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.9282 - mean_squared_error: 8321.1113
# Epoch 37/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.9469 - mean_squared_error: 8339.9844
# Epoch 38/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.9000 - mean_squared_error: 8342.9668
# Epoch 39/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.8894 - mean_squared_error: 8332.3320
# Epoch 40/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.7405 - mean_squared_error: 8298.7246
# Epoch 41/243
# 4/4 [==============================] - 0s 3ms/step - loss: 77.5719 - mean_squared_error: 8259.6484
# Epoch 42/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.3609 - mean_squared_error: 8242.8125
# Epoch 43/243
# 4/4 [==============================] - 0s 3ms/step - loss: 77.3715 - mean_squared_error: 8218.7666
# Epoch 44/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.3842 - mean_squared_error: 8229.8535
# Epoch 45/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.1770 - mean_squared_error: 8206.0527
# Epoch 46/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.0230 - mean_squared_error: 8179.2412
# Epoch 47/243
# 4/4 [==============================] - 0s 4ms/step - loss: 77.0914 - mean_squared_error: 8202.9033
# Epoch 48/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.7983 - mean_squared_error: 8143.6880
# Epoch 49/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.7048 - mean_squared_error: 8134.0303
# Epoch 50/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.5693 - mean_squared_error: 8124.4360
# Epoch 51/243
# 4/4 [==============================] - 0s 3ms/step - loss: 76.4485 - mean_squared_error: 8096.4419
# Epoch 52/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.3735 - mean_squared_error: 8089.8760
# Epoch 53/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.0036 - mean_squared_error: 8024.0244
# Epoch 54/243
# 4/4 [==============================] - 0s 3ms/step - loss: 75.9870 - mean_squared_error: 8018.1763
# Epoch 55/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.0954 - mean_squared_error: 8057.7129
# Epoch 56/243
# 4/4 [==============================] - 0s 4ms/step - loss: 76.1187 - mean_squared_error: 8040.5015
# Epoch 57/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.6756 - mean_squared_error: 7969.7007
# Epoch 58/243
# 4/4 [==============================] - 0s 3ms/step - loss: 75.7195 - mean_squared_error: 7994.9575
# Epoch 59/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.4649 - mean_squared_error: 7923.2441
# Epoch 60/243
# 4/4 [==============================] - 0s 3ms/step - loss: 75.2013 - mean_squared_error: 7930.1333
# Epoch 61/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.0594 - mean_squared_error: 7917.4033
# Epoch 62/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.0178 - mean_squared_error: 7876.0195
# Epoch 63/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.8658 - mean_squared_error: 7856.7290
# Epoch 64/243
# 4/4 [==============================] - 0s 4ms/step - loss: 75.0122 - mean_squared_error: 7876.9878
# Epoch 65/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.6429 - mean_squared_error: 7849.6670
# Epoch 66/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.6684 - mean_squared_error: 7837.4692
# Epoch 67/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.3047 - mean_squared_error: 7783.6089
# Epoch 68/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.3640 - mean_squared_error: 7803.4150
# Epoch 69/243
# 4/4 [==============================] - 0s 4ms/step - loss: 74.1582 - mean_squared_error: 7771.8218
# Epoch 70/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.6867 - mean_squared_error: 7686.1597
# Epoch 71/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.7125 - mean_squared_error: 7688.4194
# Epoch 72/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.6695 - mean_squared_error: 7714.7222
# Epoch 73/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.4663 - mean_squared_error: 7656.6060
# Epoch 74/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.3402 - mean_squared_error: 7609.5713
# Epoch 75/243
# 4/4 [==============================] - 0s 5ms/step - loss: 73.0821 - mean_squared_error: 7606.0303
# Epoch 76/243
# 4/4 [==============================] - 0s 4ms/step - loss: 73.2108 - mean_squared_error: 7584.9346
# Epoch 77/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.7222 - mean_squared_error: 7546.5503
# Epoch 78/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.7433 - mean_squared_error: 7539.7271
# Epoch 79/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.7065 - mean_squared_error: 7526.1382
# Epoch 80/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.6011 - mean_squared_error: 7536.0059
# Epoch 81/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.0218 - mean_squared_error: 7459.0137
# Epoch 82/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.8344 - mean_squared_error: 7416.8516
# Epoch 83/243
# 4/4 [==============================] - 0s 4ms/step - loss: 72.1866 - mean_squared_error: 7482.3691
# Epoch 84/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.7770 - mean_squared_error: 7421.7583
# Epoch 85/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.4075 - mean_squared_error: 7361.8213
# Epoch 86/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.3945 - mean_squared_error: 7357.3164
# Epoch 87/243
# 4/4 [==============================] - 0s 4ms/step - loss: 71.2812 - mean_squared_error: 7360.6406
# Epoch 88/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.8664 - mean_squared_error: 7254.7446
# Epoch 89/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.8276 - mean_squared_error: 7281.6309
# Epoch 90/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.8203 - mean_squared_error: 7264.9775
# Epoch 91/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.3518 - mean_squared_error: 7229.3662
# Epoch 92/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.4463 - mean_squared_error: 7219.1172
# Epoch 93/243
# 4/4 [==============================] - 0s 4ms/step - loss: 70.2547 - mean_squared_error: 7156.7764
# Epoch 94/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.8656 - mean_squared_error: 7156.0874
# Epoch 95/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.8756 - mean_squared_error: 7157.3149
# Epoch 96/243
# 4/4 [==============================] - 0s 3ms/step - loss: 69.3187 - mean_squared_error: 7079.3237
# Epoch 97/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.8807 - mean_squared_error: 7002.3354
# Epoch 98/243
# 4/4 [==============================] - 0s 4ms/step - loss: 69.2392 - mean_squared_error: 7051.9131
# Epoch 99/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.9517 - mean_squared_error: 7014.8638
# Epoch 100/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.5454 - mean_squared_error: 6918.7759
# Epoch 101/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.3774 - mean_squared_error: 6925.6255
# Epoch 102/243
# 4/4 [==============================] - 0s 4ms/step - loss: 68.3586 - mean_squared_error: 6932.1504
# Epoch 103/243
# 4/4 [==============================] - 0s 3ms/step - loss: 67.9461 - mean_squared_error: 6887.0718
# Epoch 104/243
# 4/4 [==============================] - 0s 4ms/step - loss: 67.9762 - mean_squared_error: 6874.1387
# Epoch 105/243
# 4/4 [==============================] - 0s 4ms/step - loss: 67.2831 - mean_squared_error: 6767.7168
# Epoch 106/243
# 4/4 [==============================] - 0s 4ms/step - loss: 67.2159 - mean_squared_error: 6782.6362
# Epoch 107/243
# 4/4 [==============================] - 0s 4ms/step - loss: 67.3990 - mean_squared_error: 6770.5405
# Epoch 108/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.9979 - mean_squared_error: 6769.6377
# Epoch 109/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.9621 - mean_squared_error: 6751.2456
# Epoch 110/243
# 4/4 [==============================] - 0s 3ms/step - loss: 66.6493 - mean_squared_error: 6737.6602
# Epoch 111/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.4838 - mean_squared_error: 6657.3955
# Epoch 112/243
# 4/4 [==============================] - 0s 4ms/step - loss: 66.4826 - mean_squared_error: 6669.6494
# Epoch 113/243
# 4/4 [==============================] - 0s 5ms/step - loss: 65.8763 - mean_squared_error: 6622.2671
# Epoch 114/243
# 4/4 [==============================] - 0s 5ms/step - loss: 65.7182 - mean_squared_error: 6579.5859
# Epoch 115/243
# 4/4 [==============================] - 0s 4ms/step - loss: 65.2439 - mean_squared_error: 6464.3413
# Epoch 116/243
# 4/4 [==============================] - 0s 4ms/step - loss: 65.2451 - mean_squared_error: 6515.3916
# Epoch 117/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.5421 - mean_squared_error: 6424.4570
# Epoch 118/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.5051 - mean_squared_error: 6401.8579
# Epoch 119/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.5521 - mean_squared_error: 6423.1235
# Epoch 120/243
# 4/4 [==============================] - 0s 4ms/step - loss: 64.0317 - mean_squared_error: 6375.8311
# Epoch 121/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.9789 - mean_squared_error: 6389.4282
# Epoch 122/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.8396 - mean_squared_error: 6370.9902
# Epoch 123/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.3163 - mean_squared_error: 6327.7144
# Epoch 124/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.3161 - mean_squared_error: 6237.3701
# Epoch 125/243
# 4/4 [==============================] - 0s 3ms/step - loss: 63.0990 - mean_squared_error: 6279.9565
# Epoch 126/243
# 4/4 [==============================] - 0s 4ms/step - loss: 63.0266 - mean_squared_error: 6240.1226
# Epoch 127/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.9309 - mean_squared_error: 6198.3179
# Epoch 128/243
# 4/4 [==============================] - 0s 4ms/step - loss: 62.0400 - mean_squared_error: 6083.5151
# Epoch 129/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.7593 - mean_squared_error: 6068.0054
# Epoch 130/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.8606 - mean_squared_error: 6149.4429
# Epoch 131/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.3173 - mean_squared_error: 5994.7837
# Epoch 132/243
# 4/4 [==============================] - 0s 4ms/step - loss: 60.7249 - mean_squared_error: 5939.8223
# Epoch 133/243
# 4/4 [==============================] - 0s 4ms/step - loss: 61.1833 - mean_squared_error: 5965.3066
# Epoch 134/243
# 4/4 [==============================] - 0s 3ms/step - loss: 60.7218 - mean_squared_error: 5859.1382
# Epoch 135/243
# 4/4 [==============================] - 0s 4ms/step - loss: 60.9554 - mean_squared_error: 5947.1152
# Epoch 136/243
# 4/4 [==============================] - 0s 4ms/step - loss: 60.3514 - mean_squared_error: 5827.6597
# Epoch 137/243
# 4/4 [==============================] - 0s 4ms/step - loss: 60.7917 - mean_squared_error: 5891.4307
# Epoch 138/243
# 4/4 [==============================] - 0s 4ms/step - loss: 60.5132 - mean_squared_error: 5912.5293
# Epoch 139/243
# 4/4 [==============================] - 0s 4ms/step - loss: 60.0439 - mean_squared_error: 5837.0938
# Epoch 140/243
# 4/4 [==============================] - 0s 5ms/step - loss: 59.8233 - mean_squared_error: 5830.8892
# Epoch 141/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.8435 - mean_squared_error: 5680.0532
# Epoch 142/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.5399 - mean_squared_error: 5619.6846
# Epoch 143/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.7135 - mean_squared_error: 5620.9331
# Epoch 144/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.3747 - mean_squared_error: 5626.7358
# Epoch 145/243
# 4/4 [==============================] - 0s 4ms/step - loss: 58.2165 - mean_squared_error: 5587.8071
# Epoch 146/243
# 4/4 [==============================] - 0s 4ms/step - loss: 57.3749 - mean_squared_error: 5535.0703
# Epoch 147/243
# 4/4 [==============================] - 0s 4ms/step - loss: 57.8921 - mean_squared_error: 5574.1743
# Epoch 148/243
# 4/4 [==============================] - 0s 4ms/step - loss: 57.2599 - mean_squared_error: 5513.4580
# Epoch 149/243
# 4/4 [==============================] - 0s 4ms/step - loss: 57.1396 - mean_squared_error: 5467.2261
# Epoch 150/243
# 4/4 [==============================] - 0s 5ms/step - loss: 56.9319 - mean_squared_error: 5451.0264
# Epoch 151/243
# 4/4 [==============================] - 0s 4ms/step - loss: 56.1990 - mean_squared_error: 5440.2651
# Epoch 152/243
# 4/4 [==============================] - 0s 4ms/step - loss: 56.3114 - mean_squared_error: 5389.7666
# Epoch 153/243
# 4/4 [==============================] - 0s 4ms/step - loss: 56.0888 - mean_squared_error: 5343.4844
# Epoch 154/243
# 4/4 [==============================] - 0s 4ms/step - loss: 56.8741 - mean_squared_error: 5330.6201
# Epoch 155/243
# 4/4 [==============================] - 0s 4ms/step - loss: 56.2017 - mean_squared_error: 5309.8208
# Epoch 156/243
# 4/4 [==============================] - 0s 4ms/step - loss: 54.7205 - mean_squared_error: 5134.6479
# Epoch 157/243
# 4/4 [==============================] - 0s 4ms/step - loss: 55.4193 - mean_squared_error: 5197.2705
# Epoch 158/243
# 4/4 [==============================] - 0s 4ms/step - loss: 54.2376 - mean_squared_error: 5132.9932
# Epoch 159/243
# 4/4 [==============================] - 0s 4ms/step - loss: 54.6948 - mean_squared_error: 5106.0830
# Epoch 160/243
# 4/4 [==============================] - 0s 4ms/step - loss: 55.0024 - mean_squared_error: 5170.9316
# Epoch 161/243
# 4/4 [==============================] - 0s 4ms/step - loss: 54.1226 - mean_squared_error: 5028.1045
# Epoch 162/243
# 4/4 [==============================] - 0s 4ms/step - loss: 53.8005 - mean_squared_error: 5086.2192
# Epoch 163/243
# 4/4 [==============================] - 0s 4ms/step - loss: 53.7046 - mean_squared_error: 5090.6416
# Epoch 164/243
# 4/4 [==============================] - 0s 4ms/step - loss: 53.9548 - mean_squared_error: 5034.2246
# Epoch 165/243
# 4/4 [==============================] - 0s 4ms/step - loss: 52.8440 - mean_squared_error: 4899.3267
# Epoch 166/243
# 4/4 [==============================] - 0s 4ms/step - loss: 52.5216 - mean_squared_error: 4968.6685
# Epoch 167/243
# 4/4 [==============================] - 0s 4ms/step - loss: 52.3800 - mean_squared_error: 4931.8169
# Epoch 168/243
# 4/4 [==============================] - 0s 4ms/step - loss: 53.0790 - mean_squared_error: 4995.2939
# Epoch 169/243
# 4/4 [==============================] - 0s 3ms/step - loss: 51.6729 - mean_squared_error: 4744.3335
# Epoch 170/243
# 4/4 [==============================] - 0s 4ms/step - loss: 52.4276 - mean_squared_error: 4858.6084
# Epoch 171/243
# 4/4 [==============================] - 0s 4ms/step - loss: 51.3430 - mean_squared_error: 4786.7988
# Epoch 172/243
# 4/4 [==============================] - 0s 4ms/step - loss: 51.2662 - mean_squared_error: 4681.3110
# Epoch 173/243
# 4/4 [==============================] - 0s 3ms/step - loss: 51.9574 - mean_squared_error: 4733.3398
# Epoch 174/243
# 4/4 [==============================] - 0s 3ms/step - loss: 51.0622 - mean_squared_error: 4744.1143
# Epoch 175/243
# 4/4 [==============================] - 0s 4ms/step - loss: 50.3859 - mean_squared_error: 4608.7246
# Epoch 176/243
# 4/4 [==============================] - 0s 4ms/step - loss: 50.6345 - mean_squared_error: 4672.7246
# Epoch 177/243
# 4/4 [==============================] - 0s 4ms/step - loss: 50.9554 - mean_squared_error: 4640.6768
# Epoch 178/243
# 4/4 [==============================] - 0s 4ms/step - loss: 50.4127 - mean_squared_error: 4629.3032
# Epoch 179/243
# 4/4 [==============================] - 0s 4ms/step - loss: 50.9835 - mean_squared_error: 4623.4868
# Epoch 180/243
# ...
# 5/5 [==============================] - 0s 4ms/step - loss: 62.0412 - mean_squared_error: 5819.2896
# Epoch 104/243
# 5/5 [==============================] - 0s 5ms/step - loss: 62.1144 - mean_squared_error: 5816.4858
# Epoch 105/243
# 5/5 [==============================] - 0s 4ms/step - loss: 61.9041 - mean_squared_error: 5792.8638
# Epoch 106/243
# 5/5 [==============================] - 0s 4ms/step - loss: 61.5761 - mean_squared_error: 5731.7139
# Epoch 107/243
# 5/5 [==============================] - 0s 4ms/step - loss: 61.6766 - mean_squared_error: 5751.5972
# Epoch 108/243
# 5/5 [==============================] - 0s 3ms/step - loss: 60.5742 - mean_squared_error: 5586.9722
# Epoch 109/243
# 5/5 [==============================] - 0s 3ms/step - loss: 60.5278 - mean_squared_error: 5559.7617
# Epoch 110/243
# 5/5 [==============================] - 0s 3ms/step - loss: 60.3580 - mean_squared_error: 5552.6758
# Epoch 111/243
# 5/5 [==============================] - 0s 4ms/step - loss: 60.2296 - mean_squared_error: 5528.6826
# Epoch 112/243
# 5/5 [==============================] - 0s 4ms/step - loss: 60.1990 - mean_squared_error: 5571.8164
# Epoch 113/243
# 5/5 [==============================] - 0s 4ms/step - loss: 59.3741 - mean_squared_error: 5445.9199
# Epoch 114/243
# 5/5 [==============================] - 0s 4ms/step - loss: 59.0825 - mean_squared_error: 5365.2266
# Epoch 115/243
# 5/5 [==============================] - 0s 4ms/step - loss: 59.0681 - mean_squared_error: 5395.8672
# Epoch 116/243
# 5/5 [==============================] - 0s 5ms/step - loss: 59.4059 - mean_squared_error: 5439.3989
# Epoch 117/243
# 5/5 [==============================] - 0s 4ms/step - loss: 59.3589 - mean_squared_error: 5447.3032
# Epoch 118/243
# 5/5 [==============================] - 0s 5ms/step - loss: 58.3601 - mean_squared_error: 5307.4805
# Epoch 119/243
# 5/5 [==============================] - 0s 4ms/step - loss: 57.4637 - mean_squared_error: 5236.3662
# Epoch 120/243
# 5/5 [==============================] - 0s 3ms/step - loss: 57.6656 - mean_squared_error: 5182.8794
# Epoch 121/243
# 5/5 [==============================] - 0s 3ms/step - loss: 57.7557 - mean_squared_error: 5228.6685
# Epoch 122/243
# 5/5 [==============================] - 0s 3ms/step - loss: 57.9088 - mean_squared_error: 5250.4653
# Epoch 123/243
# 5/5 [==============================] - 0s 3ms/step - loss: 57.4561 - mean_squared_error: 5223.5029
# Epoch 124/243
# 5/5 [==============================] - 0s 4ms/step - loss: 57.2294 - mean_squared_error: 5134.6187
# Epoch 125/243
# 5/5 [==============================] - 0s 3ms/step - loss: 56.9116 - mean_squared_error: 5180.6035
# Epoch 126/243
# 5/5 [==============================] - 0s 4ms/step - loss: 57.3966 - mean_squared_error: 5175.2446
# Epoch 127/243
# 5/5 [==============================] - 0s 4ms/step - loss: 56.8677 - mean_squared_error: 5170.7476
# Epoch 128/243
# 5/5 [==============================] - 0s 4ms/step - loss: 56.0138 - mean_squared_error: 4989.7876
# Epoch 129/243
# 5/5 [==============================] - 0s 4ms/step - loss: 55.1419 - mean_squared_error: 4986.1074
# Epoch 130/243
# 5/5 [==============================] - 0s 4ms/step - loss: 55.7152 - mean_squared_error: 5058.8799
# Epoch 131/243
# 5/5 [==============================] - 0s 3ms/step - loss: 55.4421 - mean_squared_error: 5018.4355
# Epoch 132/243
# 5/5 [==============================] - 0s 3ms/step - loss: 55.8347 - mean_squared_error: 5068.3682
# Epoch 133/243
# 5/5 [==============================] - 0s 4ms/step - loss: 55.0124 - mean_squared_error: 4874.5117
# Epoch 134/243
# 5/5 [==============================] - 0s 4ms/step - loss: 55.1342 - mean_squared_error: 4890.1787
# Epoch 135/243
# 5/5 [==============================] - 0s 3ms/step - loss: 54.5718 - mean_squared_error: 4880.5308
# Epoch 136/243
# 5/5 [==============================] - 0s 4ms/step - loss: 54.1198 - mean_squared_error: 4768.6279
# Epoch 137/243
# 5/5 [==============================] - 0s 4ms/step - loss: 54.6344 - mean_squared_error: 4913.9092
# Epoch 138/243
# 5/5 [==============================] - 0s 4ms/step - loss: 54.0768 - mean_squared_error: 4839.8633
# Epoch 139/243
# 5/5 [==============================] - 0s 4ms/step - loss: 53.9833 - mean_squared_error: 4818.6372
# Epoch 140/243
# 5/5 [==============================] - 0s 4ms/step - loss: 53.5826 - mean_squared_error: 4777.8325
# Epoch 141/243
# 5/5 [==============================] - 0s 4ms/step - loss: 52.6792 - mean_squared_error: 4665.2754
# Epoch 142/243
# 5/5 [==============================] - 0s 4ms/step - loss: 53.1538 - mean_squared_error: 4677.7031
# Epoch 143/243
# 5/5 [==============================] - 0s 3ms/step - loss: 52.6678 - mean_squared_error: 4603.7646
# Epoch 144/243
# 5/5 [==============================] - 0s 3ms/step - loss: 52.0019 - mean_squared_error: 4569.6289
# Epoch 145/243
# 5/5 [==============================] - 0s 4ms/step - loss: 52.3391 - mean_squared_error: 4567.3716
# Epoch 146/243
# 5/5 [==============================] - 0s 3ms/step - loss: 51.9685 - mean_squared_error: 4547.8960
# Epoch 147/243
# 5/5 [==============================] - 0s 4ms/step - loss: 51.8612 - mean_squared_error: 4570.5156
# Epoch 148/243
# 5/5 [==============================] - 0s 4ms/step - loss: 51.8911 - mean_squared_error: 4632.2871
# Epoch 149/243
# 5/5 [==============================] - 0s 4ms/step - loss: 51.5362 - mean_squared_error: 4513.5024
# Epoch 150/243
# 5/5 [==============================] - 0s 4ms/step - loss: 51.3941 - mean_squared_error: 4511.1074
# Epoch 151/243
# 5/5 [==============================] - 0s 4ms/step - loss: 50.5415 - mean_squared_error: 4422.1694
# Epoch 152/243
# 5/5 [==============================] - 0s 3ms/step - loss: 50.5711 - mean_squared_error: 4411.6562
# Epoch 153/243
# 5/5 [==============================] - 0s 4ms/step - loss: 50.9481 - mean_squared_error: 4417.5918
# Epoch 154/243
# 5/5 [==============================] - 0s 4ms/step - loss: 50.4009 - mean_squared_error: 4405.5210
# Epoch 155/243
# 5/5 [==============================] - 0s 3ms/step - loss: 50.0072 - mean_squared_error: 4307.8232
# Epoch 156/243
# 5/5 [==============================] - 0s 3ms/step - loss: 49.8803 - mean_squared_error: 4282.1323
# Epoch 157/243
# 5/5 [==============================] - 0s 4ms/step - loss: 50.1843 - mean_squared_error: 4340.5312
# Epoch 158/243
# 5/5 [==============================] - 0s 5ms/step - loss: 48.7060 - mean_squared_error: 4157.3003
# Epoch 159/243
# 5/5 [==============================] - 0s 4ms/step - loss: 49.1914 - mean_squared_error: 4223.4351
# Epoch 160/243
# 5/5 [==============================] - 0s 4ms/step - loss: 49.3301 - mean_squared_error: 4300.4775
# Epoch 161/243
# 5/5 [==============================] - 0s 4ms/step - loss: 48.9242 - mean_squared_error: 4193.0107
# Epoch 162/243
# 5/5 [==============================] - 0s 4ms/step - loss: 48.4538 - mean_squared_error: 4162.4321
# Epoch 163/243
# 5/5 [==============================] - 0s 4ms/step - loss: 48.4267 - mean_squared_error: 4172.0571
# Epoch 164/243
# 5/5 [==============================] - 0s 5ms/step - loss: 48.2825 - mean_squared_error: 4131.0518
# Epoch 165/243
# 5/5 [==============================] - 0s 5ms/step - loss: 48.6748 - mean_squared_error: 4123.8115
# Epoch 166/243
# 5/5 [==============================] - 0s 5ms/step - loss: 48.5761 - mean_squared_error: 4204.8438
# Epoch 167/243
# 5/5 [==============================] - 0s 4ms/step - loss: 48.1861 - mean_squared_error: 4136.6616
# Epoch 168/243
# 5/5 [==============================] - 0s 4ms/step - loss: 47.9718 - mean_squared_error: 4055.2905
# Epoch 169/243
# 5/5 [==============================] - 0s 4ms/step - loss: 47.9606 - mean_squared_error: 4081.5552
# Epoch 170/243
# 5/5 [==============================] - 0s 5ms/step - loss: 47.2549 - mean_squared_error: 3969.3162
# Epoch 171/243
# 5/5 [==============================] - 0s 5ms/step - loss: 47.0649 - mean_squared_error: 4062.2898
# Epoch 172/243
# 5/5 [==============================] - 0s 4ms/step - loss: 46.8818 - mean_squared_error: 3891.8333
# Epoch 173/243
# 5/5 [==============================] - 0s 3ms/step - loss: 47.0804 - mean_squared_error: 4016.5059
# Epoch 174/243
# 5/5 [==============================] - 0s 3ms/step - loss: 47.0804 - mean_squared_error: 3966.9922
# Epoch 175/243
# 5/5 [==============================] - 0s 4ms/step - loss: 46.5515 - mean_squared_error: 3877.5630
# Epoch 176/243
# 5/5 [==============================] - 0s 3ms/step - loss: 48.0001 - mean_squared_error: 4100.0908
# Epoch 177/243
# 5/5 [==============================] - 0s 4ms/step - loss: 46.5240 - mean_squared_error: 3925.6479
# Epoch 178/243
# 5/5 [==============================] - 0s 3ms/step - loss: 47.0664 - mean_squared_error: 3951.6282
# Epoch 179/243
# 5/5 [==============================] - 0s 3ms/step - loss: 45.6559 - mean_squared_error: 3860.6213
# Epoch 180/243
# 5/5 [==============================] - 0s 3ms/step - loss: 46.1047 - mean_squared_error: 3905.3718
# Epoch 181/243
# 5/5 [==============================] - 0s 4ms/step - loss: 45.6854 - mean_squared_error: 3739.0361
# Epoch 182/243
# 5/5 [==============================] - 0s 4ms/step - loss: 45.7606 - mean_squared_error: 3731.5823
# Epoch 183/243
# 5/5 [==============================] - 0s 4ms/step - loss: 44.5352 - mean_squared_error: 3732.7676
# Epoch 184/243
# 5/5 [==============================] - 0s 4ms/step - loss: 45.4457 - mean_squared_error: 3732.5569
# Epoch 185/243
# 5/5 [==============================] - 0s 3ms/step - loss: 44.4678 - mean_squared_error: 3660.2786
# Epoch 186/243
# 5/5 [==============================] - 0s 4ms/step - loss: 45.7212 - mean_squared_error: 3830.3635
# Epoch 187/243
# 5/5 [==============================] - 0s 5ms/step - loss: 45.0895 - mean_squared_error: 3815.7959
# Epoch 188/243
# 5/5 [==============================] - 0s 4ms/step - loss: 44.9709 - mean_squared_error: 3757.0996
# Epoch 189/243
# 5/5 [==============================] - 0s 4ms/step - loss: 44.2566 - mean_squared_error: 3685.1316
# Epoch 190/243
# 5/5 [==============================] - 0s 4ms/step - loss: 44.6009 - mean_squared_error: 3660.6458
# Epoch 191/243
# 5/5 [==============================] - 0s 4ms/step - loss: 44.2098 - mean_squared_error: 3789.5115
# Epoch 192/243
# 5/5 [==============================] - 0s 3ms/step - loss: 43.3803 - mean_squared_error: 3524.2046
# Epoch 193/243
# 5/5 [==============================] - 0s 3ms/step - loss: 43.6778 - mean_squared_error: 3615.8640
# Epoch 194/243
# 5/5 [==============================] - 0s 4ms/step - loss: 44.2702 - mean_squared_error: 3636.4099
# Epoch 195/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.6666 - mean_squared_error: 3544.6689
# Epoch 196/243
# 5/5 [==============================] - 0s 4ms/step - loss: 43.4007 - mean_squared_error: 3540.4536
# Epoch 197/243
# 5/5 [==============================] - 0s 4ms/step - loss: 43.2265 - mean_squared_error: 3434.8611
# Epoch 198/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.6711 - mean_squared_error: 3451.3264
# Epoch 199/243
# 5/5 [==============================] - 0s 3ms/step - loss: 42.9594 - mean_squared_error: 3416.0305
# Epoch 200/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.6971 - mean_squared_error: 3363.3823
# Epoch 201/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.7680 - mean_squared_error: 3485.5000
# Epoch 202/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.7136 - mean_squared_error: 3448.9697
# Epoch 203/243
# 5/5 [==============================] - 0s 5ms/step - loss: 42.0583 - mean_squared_error: 3409.4597
# Epoch 204/243
# 5/5 [==============================] - 0s 4ms/step - loss: 43.0424 - mean_squared_error: 3425.4631
# Epoch 205/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.8748 - mean_squared_error: 3420.9897
# Epoch 206/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.5263 - mean_squared_error: 3483.6868
# Epoch 207/243
# 5/5 [==============================] - 0s 4ms/step - loss: 41.8134 - mean_squared_error: 3281.0481
# Epoch 208/243
# 5/5 [==============================] - 0s 5ms/step - loss: 42.0255 - mean_squared_error: 3339.4150
# Epoch 209/243
# 5/5 [==============================] - 0s 4ms/step - loss: 41.9711 - mean_squared_error: 3340.5447
# Epoch 210/243
# 5/5 [==============================] - 0s 5ms/step - loss: 42.3307 - mean_squared_error: 3355.9700
# Epoch 211/243
# 5/5 [==============================] - 0s 4ms/step - loss: 42.3641 - mean_squared_error: 3328.3479
# Epoch 212/243
# 5/5 [==============================] - 0s 4ms/step - loss: 41.3219 - mean_squared_error: 3305.7642
# Epoch 213/243
# 5/5 [==============================] - 0s 4ms/step - loss: 41.3474 - mean_squared_error: 3319.6575
# Epoch 214/243
# 5/5 [==============================] - 0s 3ms/step - loss: 41.8706 - mean_squared_error: 3276.4485
# Epoch 215/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.3472 - mean_squared_error: 3153.1697
# Epoch 216/243
# 5/5 [==============================] - 0s 4ms/step - loss: 41.1098 - mean_squared_error: 3295.2781
# Epoch 217/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.4511 - mean_squared_error: 3205.5374
# Epoch 218/243
# 5/5 [==============================] - 0s 4ms/step - loss: 41.3994 - mean_squared_error: 3263.1858
# Epoch 219/243
# 5/5 [==============================] - 0s 3ms/step - loss: 41.4946 - mean_squared_error: 3242.0413
# Epoch 220/243
# 5/5 [==============================] - 0s 3ms/step - loss: 41.1239 - mean_squared_error: 3172.8333
# Epoch 221/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.2703 - mean_squared_error: 3226.0542
# Epoch 222/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.8155 - mean_squared_error: 3166.6147
# Epoch 223/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.9870 - mean_squared_error: 3227.4888
# Epoch 224/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.5093 - mean_squared_error: 3134.7810
# Epoch 225/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.7804 - mean_squared_error: 3225.4666
# Epoch 226/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.4431 - mean_squared_error: 3217.5015
# Epoch 227/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.2766 - mean_squared_error: 3103.4895
# Epoch 228/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.1907 - mean_squared_error: 3086.3193
# Epoch 229/243
# 5/5 [==============================] - 0s 4ms/step - loss: 39.3048 - mean_squared_error: 3031.1521
# Epoch 230/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.5115 - mean_squared_error: 3109.9771
# Epoch 231/243
# 5/5 [==============================] - 0s 4ms/step - loss: 39.5953 - mean_squared_error: 3082.8625
# Epoch 232/243
# 5/5 [==============================] - 0s 3ms/step - loss: 40.6282 - mean_squared_error: 3104.2456
# Epoch 233/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.7496 - mean_squared_error: 3131.9053
# Epoch 234/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.6347 - mean_squared_error: 3110.6123
# Epoch 235/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.1356 - mean_squared_error: 3053.6140
# Epoch 236/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.0701 - mean_squared_error: 3080.5732
# Epoch 237/243
# 5/5 [==============================] - 0s 4ms/step - loss: 40.5175 - mean_squared_error: 3137.2031
# Epoch 238/243
# 5/5 [==============================] - 0s 4ms/step - loss: 39.4472 - mean_squared_error: 2979.2727
# Epoch 239/243
# 5/5 [==============================] - 0s 4ms/step - loss: 38.9774 - mean_squared_error: 2994.5706
# Epoch 240/243
# 5/5 [==============================] - 0s 4ms/step - loss: 38.3635 - mean_squared_error: 2942.2527
# Epoch 241/243
# 5/5 [==============================] - 0s 4ms/step - loss: 38.9099 - mean_squared_error: 2973.2290
# Epoch 242/243
# 5/5 [==============================] - 0s 4ms/step - loss: 39.8119 - mean_squared_error: 3062.9553
# Epoch 243/243
# 5/5 [==============================] - 0s 3ms/step - loss: 38.0718 - mean_squared_error: 2878.4280
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets

# %%
print('Train:',
      '-lr more features:',round(train_lr_positive_corr_loss/n),
      '-auto ml: ', round(train_auto_ml_loss/n)
      )

print('Test:',
      '-lr more features:',round(test_lr_positive_corr_loss/n),
      '-auto ml: ', round(test_auto_ml_loss/n)
      )
# Out:
# Train: -lr more features: 59 -auto ml:  38
# Test: -lr more features: 90 -auto ml:  39

# %% [markdown]
# ## Conclusion
# -auto ml performs consistenty, i.e., similiar performance across both test and train data and no overfitting.
# <br>
# moreover it is 130% better than -lr more features model
