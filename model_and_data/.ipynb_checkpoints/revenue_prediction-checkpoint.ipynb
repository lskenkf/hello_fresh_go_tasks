# %% [markdown]
# ## Dependencies

# %%
import re
import warnings

import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) # Let pandas print the entire dataframe
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Record Correct and Mismatched Data Type

# %%
# Set path of train, test data
data_train_path = r'D:\pythonProject\hello_fresh_go_tasks\model_and_data\b2b_data_train - b2b_data_train.csv'
data_test_path = r'D:\pythonProject\hello_fresh_go_tasks\model_and_data\b2b_data_test - b2b_data_test.csv'


# Load csv files into pandas dataframes
df_train = pd.read_csv(data_train_path)
df_test = pd.read_csv(data_test_path)


# Label column is the one absent from test data set.
global label_col_name
label_col_name = set(df_train.columns.values) - set(df_test.columns.values)

# %%
# We need to first identfy the type of each column for further processing.
# We have to copy and paste the column name from the index object rather than directly from the display. 

df_column_type = df_train.dtypes.to_frame(name = 'data_type')
df_data_sample = df_train.head(2).T 
df_data_sample = df_data_sample.rename(columns = {
                                                  0:'data_sample_0',
                                                  1:'data_sample_1'
                                                  })
df_check_data_type = df_column_type.join(df_data_sample)
display(df_check_data_type)
# Out:
#                                                 data_type      data_sample_0  \
# Fridge ID                                           int64               5370
# City                                               object             Berlin
# Location                                           object            Central
# Year Founded                                        int64               2011
# Maturity                                           object           immature
# Industry                                           object            Service
# IndustryNew                                        object         E-Commerce
# Company Type                                       object            Grownup
# Company Type*                                      object    Mature Start-Up
# Employee Type                                      object       White Collar
# Office Size                                         int64                300
# Innercompany Location                              object           Entrance
# Lead Source                                        object  Internal Referral
# Fridge Type                                        object      Double Fridge
# Service Fee                                        object              499 Û
# Subsidy                                            object                1 Û
# Revenue                                            object           Û 355.69
# Registered Users                                  float64             1124.0
# Active users (weekly average 2019 per terminal)   float64             293.85
# Basket size/User/Week                             float64               6.05
# Male/Female Ratio                                 float64               1.38
# # Newsletter subscriptions                        float64              389.0
# NL/User                                            object                35%
# # Fingerprints                                    float64              314.0
# FP/User                                            object                28%
# # Restaurants nearby                              float64               60.0
# Avg. NPS Score                                    float64                7.5
#
#                                                                            data_sample_1
# Fridge ID                                                                           5637
# City                                                                              Berlin
# Location                                                                          Fringe
# Year Founded                                                                        2016
# Maturity                                                                        immature
# Industry                                                                         Service
# IndustryNew                                      B2C Software, Apps and Digital Services
# Company Type                                                                     Startup
# Company Type*                                                           Growing Start-Up
# Employee Type                                                               White Collar
# Office Size                                                                           90
# Innercompany Location                                                            Kitchen
# Lead Source                                                            Internal Referral
# Fridge Type                                                                Double Fridge
# Service Fee                                                                        499 Û
# Subsidy                                                                              2 Û
# Revenue                                                                         Û 316.63
# Registered Users                                                                   339.0
# Active users (weekly average 2019 per terminal)                                   146.44
# Basket size/User/Week                                                              10.81
# Male/Female Ratio                                                                    0.8
# # Newsletter subscriptions                                                          42.0
# NL/User                                                                              12%
# # Fingerprints                                                                     108.0
# FP/User                                                                              32%
# # Restaurants nearby                                                                22.0
# Avg. NPS Score                                                                       7.8

# %%
# Now we pick up the columns which has the correct and wrong formats, then categorize them.  

clean_int_columns = [
    'Fridge ID',
    'Year Founded',
    'Office Size'  
] 

clean_str_columns = [
    'City',
    'Location',
    'Maturity',
    'Industry',
    'IndustryNew',
    'Company Type',
    'Company Type*', 
    'Employee Type',
    'Innercompany Location',
    'Lead Source',
    'Fridge Type'  
] 

clean_float_columns = [
    
    'Registered Users',
    'Active users (weekly average 2019 per terminal)',
    'Basket size/User/Week', 'Male/Female Ratio',
    '# Newsletter subscriptions',
    '# Fingerprints',
    '# Restaurants nearby',
    'Avg. NPS Score'  
]

# There is an unwanted 'Û' in these columns
global columns_remove_U_and_convert_str_to_float 
columns_remove_U_and_convert_str_to_float = [
    'Service Fee', 
    'Subsidy', 
    'Revenue'
]

# We have to convert the str type to float type
global columns_remove_percentage_and_convert_str_to_float
columns_remove_percentage_and_convert_str_to_float = [
    'NL/User', 
    'FP/User'
]


checked_columns = [
    clean_int_columns,
    clean_str_columns,
    clean_float_columns,
    columns_remove_U_and_convert_str_to_float,
    columns_remove_percentage_and_convert_str_to_float
]

# Verify whether we have checked all the columns
total_num_columns = len(df_train.columns) 
checked_columns = [x for xs in checked_columns for x in xs]
num_missed_column = total_num_columns - len(checked_columns)

try:
    0 == num_missed_column
    print(f'We have checked all {total_num_columns} columns')
    
except ValueError:
    raise ValueError(f"We have missed to check {num_missed_column} columns")
# Out:
# We have checked all 27 columns

# %% [markdown]
# ## Correct Mismatched Data Type

# %%
# We create a function to wrap ip the cleaning and encoding process and apply them to both train and test set.
# i.e., we need to creat several udf for pandas dataframe, although udf is slow applied to big dataframe. 

def func_remove_U_and_convert_str_to_float(cell):
    try:
        cell = re.sub('[^0-9.]', "", cell.replace(",","."))
        return float(cell)
    except:
        return np.nan   # missing value is casted to -1.
 
def func_remove_percentage_and_convert_str_to_float(cell):
    try:
        cell = cell.replace("%","")
        return float(cell)
    
    except:   
        return np.nan
    

def apply_udf(df,columns,func):
    for col in columns:
        df[col] = df.apply(lambda x: func(x[col]),axis = 1)
        
    return df


def clean_data(df,data_type):
   
    df = apply_udf(
        df,
        columns_remove_percentage_and_convert_str_to_float,
        func_remove_percentage_and_convert_str_to_float
    )
    
    if data_type == 'train':
        df = apply_udf(
            df,
            columns_remove_U_and_convert_str_to_float,
            func_remove_U_and_convert_str_to_float
        )
    elif data_type == 'test':
        df = apply_udf(
            df,
            set(columns_remove_U_and_convert_str_to_float) - label_col_name,
            func_remove_U_and_convert_str_to_float
        )
    else:
        raise ValueError("data_type input is wrong")
    
    return df

# %% [markdown]
# ## Check Missing Value and Fill String Valued Column

# %%
def get_missing_value_percentage(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({
        'percent_missing': percent_missing
    })
    missing_value_df.sort_values('percent_missing', inplace=True)
    
    return missing_value_df


df_train = clean_data(df_train,'train')
df_test = clean_data(df_test,'test')

global numeric_colunms
global str_columns
numeric_colunms = set(checked_columns)\
               - set(clean_str_columns)
str_columns = clean_str_columns

global str_column_fillna_value
str_column_fillna_value = 'Unknown'

# %%
# We fill 'unknown' in the string valued column if the value is missing.
# we fill with the average value if the value is missing in that column.
     
        
def fill_missing_value(df,data_type):
    df_str = df[str_columns]
    df_str = df_str.fillna(value=str_column_fillna_value)
    
    if data_type == 'train':
        df_numeric = df[numeric_colunms]
        df_numeric = df_numeric.fillna(value=df_numeric.mean())
        
    elif data_type == 'test':
        df_numeric = df[numeric_colunms-label_col_name]
        df_numeric = df_numeric.fillna(value=df_numeric.mean())
        
    else:
        raise ValueError("data_type input is wrong")
        
    df = pd.concat([df_numeric, df_str],axis=1)
    return df

# %% [markdown]
# ## Check Correlation Between All Columns

# %%
# We use the whole training data to get the Heatmap matrix which gives us an overview of all pair correlations.
df_train = fill_missing_value(df_train, 'train')   
df_test = fill_missing_value(df_test, 'test') 
corr = df_train.corr()
display(corr)
# Out:
#                                                  # Restaurants nearby  \
# # Restaurants nearby                                         1.000000
# Male/Female Ratio                                           -0.041986
# # Fingerprints                                              -0.020948
# Subsidy                                                     -0.033123
# # Newsletter subscriptions                                   0.038703
# Active users (weekly average 2019 per terminal)             -0.038554
# NL/User                                                     -0.133312
# Revenue                                                     -0.116038
# Registered Users                                             0.074876
# FP/User                                                     -0.166167
# Fridge ID                                                   -0.136249
# Basket size/User/Week                                       -0.199906
# Service Fee                                                 -0.038732
# Year Founded                                                 0.181424
# Office Size                                                  0.038403
# Avg. NPS Score                                              -0.029451
#
#                                                  Male/Female Ratio  \
# # Restaurants nearby                                     -0.041986
# Male/Female Ratio                                         1.000000
# # Fingerprints                                           -0.058084
# Subsidy                                                   0.024339
# # Newsletter subscriptions                               -0.108796
# Active users (weekly average 2019 per terminal)          -0.095928
# NL/User                                                  -0.134380
# Revenue                                                  -0.076353
# Registered Users                                         -0.090666
# FP/User                                                   0.052112
# Fridge ID                                                 0.074107
# Basket size/User/Week                                     0.071858
# Service Fee                                              -0.018165
# Year Founded                                             -0.157158
# Office Size                                               0.130431
# Avg. NPS Score                                            0.000287
#
#                                                  # Fingerprints   Subsidy  \
# # Restaurants nearby                                  -0.020948 -0.033123
# Male/Female Ratio                                     -0.058084  0.024339
# # Fingerprints                                         1.000000 -0.004526
# Subsidy                                               -0.004526  1.000000
# # Newsletter subscriptions                             0.838215 -0.067446
# Active users (weekly average 2019 per terminal)        0.619787  0.168224
# NL/User                                               -0.073070  0.045030
# Revenue                                                0.504865  0.273119
# Registered Users                                       0.808139 -0.073152
# FP/User                                                0.300165  0.123439
# Fridge ID                                             -0.383138 -0.062084
# Basket size/User/Week                                 -0.262434  0.195651
# Service Fee                                            0.083479  0.088171
# Year Founded                                           0.119853  0.049700
# Office Size                                            0.248893 -0.160370
# Avg. NPS Score                                         0.139418  0.053320
#
#                                                  # Newsletter subscriptions  \
# # Restaurants nearby                                               0.038703
# Male/Female Ratio                                                 -0.108796
# # Fingerprints                                                     0.838215
# Subsidy                                                           -0.067446
# # Newsletter subscriptions                                         1.000000
# Active users (weekly average 2019 per terminal)                    0.513393
# NL/User                                                            0.127295
# Revenue                                                            0.377834
# Registered Users                                                   0.931704
# FP/User                                                            0.041817
# Fridge ID                                                         -0.325508
# Basket size/User/Week                                             -0.274559
# Service Fee                                                        0.078897
# Year Founded                                                       0.047212
# Office Size                                                        0.369071
# Avg. NPS Score                                                     0.147824
#
#                                                  Active users (weekly average 2019 per terminal)  \
# # Restaurants nearby                                                                   -0.038554
# Male/Female Ratio                                                                      -0.095928
# # Fingerprints                                                                          0.619787
# Subsidy                                                                                 0.168224
# # Newsletter subscriptions                                                              0.513393
# Active users (weekly average 2019 per terminal)                                         1.000000
# NL/User                                                                                 0.006375
# Revenue                                                                                 0.942982
# Registered Users                                                                        0.426166
# FP/User                                                                                 0.201689
# Fridge ID                                                                              -0.349677
# Basket size/User/Week                                                                  -0.122782
# Service Fee                                                                             0.042203
# Year Founded                                                                            0.159023
# Office Size                                                                             0.069749
# Avg. NPS Score                                                                          0.104361
#
#                                                   NL/User   Revenue  \
# # Restaurants nearby                            -0.133312 -0.116038
# Male/Female Ratio                               -0.134380 -0.076353
# # Fingerprints                                  -0.073070  0.504865
# Subsidy                                          0.045030  0.273119
# # Newsletter subscriptions                       0.127295  0.377834
# Active users (weekly average 2019 per terminal)  0.006375  0.942982
# NL/User                                          1.000000  0.001673
# Revenue                                          0.001673  1.000000
# Registered Users                                -0.100766  0.309066
# FP/User                                          0.261969  0.228317
# Fridge ID                                        0.094979 -0.305169
# Basket size/User/Week                            0.121355  0.132400
# Service Fee                                      0.103900  0.025224
# Year Founded                                    -0.202475  0.143770
# Office Size                                     -0.036241  0.004965
# Avg. NPS Score                                   0.225991  0.108391
#
#                                                  Registered Users   FP/User  \
# # Restaurants nearby                                     0.074876 -0.166167
# Male/Female Ratio                                       -0.090666  0.052112
# # Fingerprints                                           0.808139  0.300165
# Subsidy                                                 -0.073152  0.123439
# # Newsletter subscriptions                               0.931704  0.041817
# Active users (weekly average 2019 per terminal)          0.426166  0.201689
# NL/User                                                 -0.100766  0.261969
# Revenue                                                  0.309066  0.228317
# Registered Users                                         1.000000 -0.008235
# FP/User                                                 -0.008235  1.000000
# Fridge ID                                               -0.330997 -0.187896
# Basket size/User/Week                                   -0.271734  0.070158
# Service Fee                                              0.060204 -0.003535
# Year Founded                                             0.117776 -0.051898
# Office Size                                              0.324528 -0.126899
# Avg. NPS Score                                           0.077985  0.069560
#
#                                                  Fridge ID  \
# # Restaurants nearby                             -0.136249
# Male/Female Ratio                                 0.074107
# # Fingerprints                                   -0.383138
# Subsidy                                          -0.062084
# # Newsletter subscriptions                       -0.325508
# Active users (weekly average 2019 per terminal)  -0.349677
# NL/User                                           0.094979
# Revenue                                          -0.305169
# Registered Users                                 -0.330997
# FP/User                                          -0.187896
# Fridge ID                                         1.000000
# Basket size/User/Week                             0.273732
# Service Fee                                      -0.032501
# Year Founded                                     -0.037812
# Office Size                                      -0.129286
# Avg. NPS Score                                    0.063821
#
#                                                  Basket size/User/Week  \
# # Restaurants nearby                                         -0.199906
# Male/Female Ratio                                             0.071858
# # Fingerprints                                               -0.262434
# Subsidy                                                       0.195651
# # Newsletter subscriptions                                   -0.274559
# Active users (weekly average 2019 per terminal)              -0.122782
# NL/User                                                       0.121355
# Revenue                                                       0.132400
# Registered Users                                             -0.271734
# FP/User                                                       0.070158
# Fridge ID                                                     0.273732
# Basket size/User/Week                                         1.000000
# Service Fee                                                  -0.087758
# Year Founded                                                 -0.061810
# Office Size                                                  -0.156773
# Avg. NPS Score                                               -0.002213
#
#                                                  Service Fee  Year Founded  \
# # Restaurants nearby                               -0.038732      0.181424
# Male/Female Ratio                                  -0.018165     -0.157158
# # Fingerprints                                      0.083479      0.119853
# Subsidy                                             0.088171      0.049700
# # Newsletter subscriptions                          0.078897      0.047212
# Active users (weekly average 2019 per terminal)     0.042203      0.159023
# NL/User                                             0.103900     -0.202475
# Revenue                                             0.025224      0.143770
# Registered Users                                    0.060204      0.117776
# FP/User                                            -0.003535     -0.051898
# Fridge ID                                          -0.032501     -0.037812
# Basket size/User/Week                              -0.087758     -0.061810
# Service Fee                                         1.000000      0.091055
# Year Founded                                        0.091055      1.000000
# Office Size                                         0.150296     -0.179148
# Avg. NPS Score                                      0.115390     -0.169206
#
#                                                  Office Size  Avg. NPS Score
# # Restaurants nearby                                0.038403       -0.029451
# Male/Female Ratio                                   0.130431        0.000287
# # Fingerprints                                      0.248893        0.139418
# Subsidy                                            -0.160370        0.053320
# # Newsletter subscriptions                          0.369071        0.147824
# Active users (weekly average 2019 per terminal)     0.069749        0.104361
# NL/User                                            -0.036241        0.225991
# Revenue                                             0.004965        0.108391
# Registered Users                                    0.324528        0.077985
# FP/User                                            -0.126899        0.069560
# Fridge ID                                          -0.129286        0.063821
# Basket size/User/Week                              -0.156773       -0.002213
# Service Fee                                         0.150296        0.115390
# Year Founded                                       -0.179148       -0.169206
# Office Size                                         1.000000        0.231623
# Avg. NPS Score                                      0.231623        1.000000

# %%
# For now, we care about the correlation between the features and the to be predicted value.
# The correlation between 'Active users (weekly average 2019 per terminal)' and 'Revenue' is around 94%. 
display(df_train[df_train.columns[1:]].corr()[label_col_name][:-1].sort_values(by='Revenue',ascending=False))
# Out:
#                                                   Revenue
# Revenue                                          1.000000
# Active users (weekly average 2019 per terminal)  0.942982
# # Fingerprints                                   0.504865
# # Newsletter subscriptions                       0.377834
# Registered Users                                 0.309066
# Subsidy                                          0.273119
# FP/User                                          0.228317
# Year Founded                                     0.143770
# Basket size/User/Week                            0.132400
# Service Fee                                      0.025224
# Office Size                                      0.004965
# NL/User                                          0.001673
# Male/Female Ratio                               -0.076353
# Fridge ID                                       -0.305169

# %%
# Visually, we see that their relation is highly linear.
# i.e. the more the 'Active users (weekly average 2019 per terminal)' the more 'Revenue' will become.
df_train.plot.scatter(x = label_col_name, y = 'Active users (weekly average 2019 per terminal)', s = 100)
# Out:
# <AxesSubplot:xlabel='{Revenue}', ylabel='Active users (weekly average 2019 per terminal)'>

# %% [markdown]
# ## Baseline Model: Linear Regression

# %%
# We see that the relation between these two columns is highly linear (correlation is ca.94%) 
# this suggests us to build a model using 'Active users (weekly average 2019 per terminal)' to predict 'Revenue'.
# In order to avoid data leakage, we will split the data into train, validation, test and process the data again.

data = pd.read_csv(data_train_path)
(size_test_set,_) = pd.read_csv(data_test_path).shape

# %%
import numpy as np
from sklearn.model_selection import RepeatedKFold
X = data_lr
random_state = 12883823
rkf = RepeatedKFold(n_splits=2, n_repeats=2, random_state=random_state)
for train, test in rkf.split(X):
    print(data_lr.iloc[train].shape,data_lr.iloc[test].shape)
# Out:
# (75, 27) (75, 27)
# (75, 27) (75, 27)
# (75, 27) (75, 27)
# (75, 27) (75, 27)

# %%
def get_lr_lossdel,X_train,y_train,X_test,y_test):
    
    lr_model = lr().fit(X_train, y_train)
    y_pred = lr_model.predict(X_test)
    msr = mean_squared_error(y_true, y_pred)
    
    return msr

# %%
import numpy as np
from sklearn.linear_model import LinearRegression as lr
X = np.array([[1, 1], [1, 2], [2, 2], [2, 3]])
y = np.dot(X, np.array([1, 2])) + 3
reg = lr().fit(X, y)
reg.score(X, y)

reg.coef_

reg.intercept_

reg.predict(np.array([[3, 5]]))
# Out:
# array([16.])

# %%
from sklearn.metrics import mean_squared_error
y_true = [3, -0.5, 2, 7]
y_pred = [2.5, 0.0, 2, 8]
mean_squared_error(y_true, y_pred)
# Out:
#     Fridge ID         City Location  Year Founded  Maturity       Industry  \
# 0        5370       Berlin  Central          2011  immature        Service
# 1        5637       Berlin   Fringe          2016  immature        Service
# 2        5661       Berlin   Fringe          2012  immature        Digital
# 3        5699     MÃ¼nchen   Fringe          1995    mature   Broadcasting
# 4       10003     MÃ¼nchen  Central          1999    mature        Finance
# 5       20018       Berlin  Central          2000    mature        Service
# 6        5484       Berlin  Central          2011  immature        Service
# 7       10012    Frankfurt   Fringe          1835    mature        Service
# 8        5702    Frankfurt   Fringe          2015  immature        Product
# 9       10010     MÃ¼nchen  Central          2011  immature        Digital
# 10       5476       Berlin  Central          2008    mature        Digital
# 11       5621       Berlin  Central          1999    mature        Product
# 12       5722    Frankfurt   Fringe          1992    mature        Service
# 13       5475       Berlin  Central          2011  immature        Service
# 14       5552       Berlin  Central          1997    mature        Digital
# 15       5726  DÃ¼sseldorf   Fringe          1985    mature        Service
# 16       5371       Berlin  Central          2017  immature        Digital
# 17      10018    Frankfurt  Central          2013  immature        Service
# 18      30011        KÃ¶ln  Central          1990    mature        Service
# 19      30034     MÃ¼nchen  Central          2001    mature        Digital
# 20       5695       Berlin  Central          1977    mature    Call Center
# 21       5554       Berlin   Fringe          2008    mature        Service
# 22       5690     MÃ¼nchen  Central          2006    mature        Digital
# 23       5655       Berlin   Fringe          1994    mature      Logistics
# 24       5658       Berlin   Fringe          1983    mature     Consulting
# 25      10006      Hamburg  Central          2007    mature        Digital
# 26      30068       Berlin  Central          1987    mature     Consulting
# 27       5671       Berlin  Central          2010  immature            Law
# 28      20013     MÃ¼nchen   Fringe          1998    mature           Tech
# 29       5620       Berlin  Central          1988    mature     Consulting
# 30       5686       Berlin   Fringe          1990    mature        Finance
# 31       5622       Berlin   Fringe          2012  immature        Digital
# 32      10023       Berlin  Central          1847    mature  Manufacturing
# 33       5703      Hamburg  Central          1990    mature     Consulting
# 34      10014      Hamburg  Central          1999    mature        Digital
# 35       5725     MÃ¼nchen  Central          1950    mature            Law
# 36       5479       Berlin  Central          2011  immature        Service
# 37      30045     MÃ¼nchen  Central          1967    mature        Service
# 38       5551       Berlin  Central          2011  immature        Service
# 39      30065     MÃ¼nchen   Fringe          1992    mature   Broadcasting
# 40      10024      Hamburg   Fringe          1984    mature        Service
# 41       5474       Berlin  Central          2009    mature        Digital
# 42      20026  DÃ¼sseldorf   Fringe          1987    mature     Consulting
# 43       5480       Berlin  Central          2010  immature        Digital
# 44      30025      Hamburg   Fringe          1995    mature        Digital
# 45       5724    Frankfurt   Fringe          1898    mature        Product
# 46       5687       Berlin  Central          2011  immature        Digital
# 47       5632       Berlin  Central          1955    mature        Service
# 48      30055        KÃ¶ln   Fringe          2000    mature        Digital
# 49      30015       Berlin   Fringe          2000    mature       Hospital
# 50      20019        KÃ¶ln  Central          1957    mature        Digital
# 51       5711     MÃ¼nchen   Fringe          1869    mature        Service
# 52       5698      Hamburg   Fringe          1906    mature        Product
# 53      10025      Hamburg  Central          2014  immature        Service
# 54       5634        KÃ¶ln  Central          1923    mature        Finance
# 55      10035    Frankfurt  Central          1972    mature        Finance
# 56       5709    Frankfurt  Central          1994    mature        Finance
# 57      30047       Berlin   Fringe          1899    mature        Product
# 58      30008        KÃ¶ln   Fringe          1964    mature        Service
# 59       5688        KÃ¶ln  Central          1990    mature        Digital
# 60       5429       Berlin  Central          2012  immature        Service
# 61      10031       Berlin  Central          1847    mature  Manufacturing
# 62      10008       Berlin  Central          1989    mature     Consulting
# 63      30012       Berlin  Central          2002    mature        Digital
# 64      30022       Berlin   Fringe          1835    mature        Service
# 65      30059       Berlin  Central          1998    mature        Digital
# 66      30069       Berlin   Fringe          2008    mature    Health Care
# 67      20001     MÃ¼nchen   Fringe          1990    mature     Consulting
# 68      30048       Berlin  Central          1997    mature        Digital
# 69       5625       Berlin  Central          2009    mature        Digital
# 70       5714       Berlin  Central          1886    mature        Product
# 71      10040       Berlin   Fringe          2011  immature        Digital
# 72       5685    Frankfurt   Fringe          1973    mature        Digital
# 73      10009       Berlin  Central          2000    mature        Service
# 74      30009       Berlin   Fringe          1912    mature        Service
#
#                                           IndustryNew    Company Type  \
# 0                                          E-Commerce         Grownup
# 1             B2C Software, Apps and Digital Services         Startup
# 2                      B2B Software, Data & Equipment       Corporate
# 63                     B2B Software, Data & Equipment         Startup
# 64                Real Estate and Facility Management         Grownup
# 65  Media, Entertainment, Creative Agencies & Adve...         Startup
# 66                 Manufacturing, Production & Energy         Grownup
# 67  Media, Entertainment, Creative Agencies & Adve...      Consulting
# 68                                         E-Commerce         Grownup
# 69                                         E-Commerce         Startup
# 70                 Manufacturing, Production & Energy       Corporate
# 71                                         E-Commerce         Startup
# 72  Media, Entertainment, Creative Agencies & Adve...         Startup
# 73  IT Services, Outsourcing & Engineering Consulting       Corporate
# 74           Transport, Logistics & Delivery Services         Grownup
#
#        Company Type*  Employee Type  Office Size  Innercompany Location  \
# 0    Mature Start-Up   White Collar          300               Entrance
# 1   Growing Start-Up   White Collar           90                Kitchen
# 2   Growing Start-Up   White Collar          230            Common Room
# 3          Corporate          Mixed          350                Hallway
# 4          Corporate   White Collar          400                Hallway
# 5                SME   White Collar          190                Kitchen
# 6   Growing Start-Up  Customer Care          120               Entrance
# 7                SME          Mixed          150               Entrance
# 8   Growing Start-Up   White Collar          100            Common Room
# 9    Mature Start-Up   White Collar          450                Kitchen
# 10         Corporate   White Collar          400            Common Room
# 11         Corporate   White Collar          800                Hallway
# 12               SME   White Collar          250            Common Room
# 13   Mature Start-Up   White Collar         1000            Common Room
# 14               SME   White Collar          250                Kitchen
# 15               SME   White Collar          205                Kitchen
# 16   Mature Start-Up   White Collar          350               Entrance
# 17  Growing Start-Up   White Collar          205                Kitchen
# 18         Corporate   White Collar          450           Project area
# 19         Corporate   White Collar          560               Entrance
# 20         Corporate          Mixed          650               Entrance
# 21         Corporate   White Collar          254            Common Room
# 22               SME   White Collar          230                Kitchen
# 23               SME          Mixed          120                Kitchen
# 24         Corporate   White Collar          456            Common Room
# 25         Corporate   White Collar          400            Common Room
# 26         Corporate   White Collar         1200                Kitchen
# 27  Growing Start-Up   White Collar          100              Top floor
# 28               SME   White Collar          200                Kitchen
# 29         Corporate          Suits          800               Entrance
# 30         Corporate   White Collar          700               Entrance
# 31  Growing Start-Up   White Collar          180            Common Room
# 32         Corporate    Blue Collar         3500                Kitchen
# 33         Corporate   White Collar          500                    NaN
# 34               SME   White Collar          100            Common Room
# 35         Corporate          Suits          420              Cafeteria
# 36   Mature Start-Up  Customer Care          600            Common Room
# 37         Corporate   White Collar          300            Common Room
# 38  Growing Start-Up   White Collar           80               Entrance
# 39               SME          Mixed          240            Common Room
# 40               SME   White Collar          180            Common Room
# 41               SME   White Collar          250            Common Room
# 42         Corporate   White Collar         1200            Common Room
# 43  Growing Start-Up   White Collar          120          Hallway/Niche
# 44               SME   White Collar          100                Kitchen
# 45               SME   White Collar          240            Common Room
# 46   Mature Start-Up   White Collar          300            Common Room
# 47         Corporate  Customer Care          500            Common Room
# 48               SME   White Collar          170            Common Room
# 49         Corporate   White Collar          400          Winter garden
# 50         Corporate   White Collar          600               Entrance
# 51               SME   White Collar          250            Common Room
# 52         Corporate          Mixed          800                Hallway
# 8                    9.25               0.47                        26.0
# 9                    6.40               0.39                       115.0
# 10                   7.46               0.32                        61.0
# 11                   7.37               0.56                        96.0
# 12                   8.55               2.82                        55.0
# 13                   6.31               1.11                       271.0
# 14                   7.63               2.10                        60.0
# 15                   8.45               0.80                         2.0
# 16                   7.70               1.03                        56.0
# 17                   7.82               0.96                        66.0
# 18                   7.77               0.39                        89.0
# 19                   6.83               0.87                        94.0
# 20                   8.68               1.59                        73.0
# 21                   7.99               1.67                        37.0
# 22                   6.95               0.20                        25.0
# 23                  12.34               0.95                        25.0
# 24                   9.24               1.36                        77.0
# 25                   7.07               0.80                        92.0
# 26                   7.35               0.82                        77.0
# 27                   7.63               0.75                        22.0
# 28                   8.78               1.91                        29.0
# 29                   6.01               0.92                       177.0
# 30                   7.58               0.61                       132.0
# 31                   8.99               1.68                        34.0
# 32                   7.38               2.00                       248.0
# 33                   6.82               1.08                        68.0
# 34                   6.60               0.72                        78.0
# 35                   8.81               0.44                        32.0
# 36                   6.30               1.40                       117.0
# 37                   8.30               0.84                        43.0
# 38                   8.28               2.71                        27.0
# 39                   7.56               0.72                        35.0
# 40                   7.00               1.81                        46.0
# 41                   7.20               1.36                        58.0
# 42                   6.93               0.83                        61.0
# 43                   8.59               0.59                        37.0
# 44                   9.76               1.12                        79.0
# 45                   7.49               0.89                        62.0
# 46                   9.37               1.17                        42.0
# 47                   6.52               0.53                        92.0
# 48                   8.25               0.89                        36.0
# 49                  11.73               0.36                        28.0
# 50                   7.00               0.77                        56.0
# 51                   8.84               1.02                        32.0
# 52                   6.52               0.91                        22.0
# 53                   6.75               0.79                        73.0
# 54                   7.85               1.30                        92.0
# 55                   9.21               0.75                        37.0
# 56                   6.80               1.49                        83.0
# 57                   7.96               4.68                        34.0
# 58                   8.28               0.56                        52.0
# 59                   6.74               0.47                        48.0
# 60                   6.96               0.54                        55.0
# 61                   7.77               4.20                         6.0
# 62                   6.32               0.83                       100.0
# 63                   7.75               2.13                        33.0
# 64                   7.35               1.01                        47.0
# 65                  14.59               0.72                        10.0
# 66                   8.58               0.39                        28.0
# 67                   7.76               1.00                        10.0
# 68                   9.17               1.41                        24.0
# 69                   6.52               1.19                        78.0
# 70                   6.00               0.38                       179.0
# 71                   6.39               0.40                        51.0
# 72                   6.88               1.06                        48.0
# 73                   6.65               1.69                        28.0
# 74                   8.53               1.10                        46.0
#
#    NL/User  # Fingerprints FP/User  # Restaurants nearby  Avg. NPS Score
# 0      35%           314.0     28%                  60.0             7.5
# 1      12%           108.0     32%                  22.0             7.8
# 2      38%            39.0     20%                  21.0             8.2
# 3      32%           217.0     27%                   0.0             8.0
# 4      24%           315.0     46%                   9.0             8.7
# 5      28%            42.0     26%                   1.0             7.6
# 6      47%             5.0     29%                  60.0             NaN
# 7      34%            75.0     41%                   7.0             8.6
# 8      15%            83.0     49%                  21.0             7.0
# 9      20%           145.0     26%                   3.0             7.3
# 10     26%            46.0     20%                  60.0             NaN
# 11     24%            88.0     22%                  60.0             8.1
# 12     26%           102.0     49%                   9.0             8.8
# 13     20%           169.0     13%                  60.0             7.2
# 14     15%           102.0     26%                  39.0             7.7
# 15     22%             NaN      0%                  11.0             NaN
# 16     19%            40.0     13%                  60.0             7.4
# 17     29%            67.0     29%                  60.0             8.8
# 18     32%            58.0     21%                   7.0             NaN
# 19     32%            74.0     25%                  22.0             NaN
# 20     33%            32.0     15%                  60.0             7.7
# 21     19%            43.0     22%                   4.0             5.9
# 22     24%            36.0     35%                   8.0             7.2
# 23     30%             6.0      7%                  24.0             8.0
# 24     25%            45.0     15%                   6.0             6.5
# 25     26%            60.0     17%                  60.0             7.4
# 26     22%            37.0     11%                  18.0             NaN
# 27     16%            22.0     16%                  60.0             6.3
# 28     21%            80.0     58%                   4.0             6.9
# 29     19%           217.0     23%                  42.0             8.3
# 30     42%            68.0     22%                  16.0             8.3
# 31     20%            42.0     24%                   4.0             6.1
# 32     37%           170.0     25%                   7.0             8.6
# 33     39%            75.0     43%                  60.0             7.7
# 34     29%            86.0     32%                  29.0             6.6
# 35     19%            26.0     15%                  51.0             7.2
# 36     19%           169.0     28%                  60.0             8.4
# 37     19%            55.0     25%                   4.0             NaN
# 38     11%            86.0     36%                  60.0             6.4
# 39     19%            37.0     20%                   4.0             NaN
# 40     34%            34.0     25%                   4.0             9.0
# 41     23%            28.0     11%                   0.0             5.5
# 42     22%            36.0     13%                  22.0             NaN
# 43     20%            64.0     34%                  60.0             7.5
# 44     50%            16.0     10%                  31.0             NaN
# 45     42%            74.0     50%                   9.0             NaN
# 46     17%            34.0     14%                  60.0             8.2
# 47     29%            62.0     19%                  37.0             8.1
# 48     30%            34.0     29%                   3.0             NaN
# 49     22%            18.0     14%                  14.0             NaN
# 50     23%            45.0     19%                  26.0             8.2
# 51     24%            40.0     31%                   2.0             7.3
# 52      7%            66.0     22%                  12.0             6.8
# 53     24%            58.0     19%                  60.0             7.6
# 54     32%            59.0     20%                  22.0             7.5
# 55     35%            41.0     38%                  17.0             9.0
# 56     25%            77.0     23%                  60.0             8.2
# 57     21%             9.0      6%                  36.0             NaN
# 58     35%            37.0     25%                   4.0             NaN
# 59     21%            50.0     22%                  57.0             7.2
# 60     17%            69.0     21%                  60.0             7.4
# 61     23%             3.0     12%                  17.0             NaN
# 62     20%            92.0     18%                  12.0             8.9
# 63     20%            40.0     25%                  35.0             NaN
# 64     34%            44.0     32%                   2.0             NaN
# 65     15%             6.0      9%                  60.0             NaN
# 66     21%            19.0     14%                   2.0             NaN
# 67     38%            13.0     50%                  25.0             9.2
# 68     34%            13.0     19%                  60.0             NaN
# 69     29%            53.0     20%                  18.0             7.8
# 70     40%            40.0      9%                  53.0             8.1
# 71     23%            50.0     22%                  60.0             7.9
# 72     27%            22.0     12%                   2.0             8.1
# 73     14%            27.0     13%                  53.0             NaN
# 74     37%            37.0     29%                  29.0             NaN
