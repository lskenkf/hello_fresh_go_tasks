# %% [markdown]
# ## Dependencies

# %%
import re
import os
import warnings

import pandas as pd
import numpy as np
import seaborn as sns

from sklearn.model_selection import RepeatedKFold
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from xgboost import XGBRegressor
from autokeras import StructuredDataRegressor

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None) # Let pandas print the entire dataframe
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Record Correct and Mismatched Data Type

# %%
# Set path of train, test data
data_train_path = r'D:\pythonProject\hello_fresh_go_tasks\model_and_data\b2b_data_train - b2b_data_train.csv'
data_test_path = r'D:\pythonProject\hello_fresh_go_tasks\model_and_data\b2b_data_test - b2b_data_test.csv'


# Load csv files into pandas dataframes
df_train = pd.read_csv(data_train_path)
df_test = pd.read_csv(data_test_path)


# Label column is the one absent from test data set.
global label_col_name
label_col_name = set(df_train.columns.values) - set(df_test.columns.values)

# %%
# We need to first identfy the type of each column for further processing.
# We have to copy and paste the column name from the index object rather than directly from the display. 

df_column_type = df_train.dtypes.to_frame(name = 'data_type')
df_data_sample = df_train.head(2).T 
df_data_sample = df_data_sample.rename(columns = {
                                                  0:'data_sample_0',
                                                  1:'data_sample_1'
                                                  })
df_check_data_type = df_column_type.join(df_data_sample)
display(df_check_data_type)
# Out:
#                                                 data_type      data_sample_0  \
# Fridge ID                                           int64               5370
# City                                               object             Berlin
# Location                                           object            Central
# Year Founded                                        int64               2011
# Maturity                                           object           immature
# Industry                                           object            Service
# IndustryNew                                        object         E-Commerce
# Company Type                                       object            Grownup
# Company Type*                                      object    Mature Start-Up
# Employee Type                                      object       White Collar
# Office Size                                         int64                300
# Innercompany Location                              object           Entrance
# Lead Source                                        object  Internal Referral
# Fridge Type                                        object      Double Fridge
# Service Fee                                        object              499 Û
# Subsidy                                            object                1 Û
# Revenue                                            object           Û 355.69
# Registered Users                                  float64             1124.0
# Active users (weekly average 2019 per terminal)   float64             293.85
# Basket size/User/Week                             float64               6.05
# Male/Female Ratio                                 float64               1.38
# # Newsletter subscriptions                        float64              389.0
# NL/User                                            object                35%
# # Fingerprints                                    float64              314.0
# FP/User                                            object                28%
# # Restaurants nearby                              float64               60.0
# Avg. NPS Score                                    float64                7.5
#
#                                                                            data_sample_1
# Fridge ID                                                                           5637
# City                                                                              Berlin
# Location                                                                          Fringe
# Year Founded                                                                        2016
# Maturity                                                                        immature
# Industry                                                                         Service
# IndustryNew                                      B2C Software, Apps and Digital Services
# Company Type                                                                     Startup
# Company Type*                                                           Growing Start-Up
# Employee Type                                                               White Collar
# Office Size                                                                           90
# Innercompany Location                                                            Kitchen
# Lead Source                                                            Internal Referral
# Fridge Type                                                                Double Fridge
# Service Fee                                                                        499 Û
# Subsidy                                                                              2 Û
# Revenue                                                                         Û 316.63
# Registered Users                                                                   339.0
# Active users (weekly average 2019 per terminal)                                   146.44
# Basket size/User/Week                                                              10.81
# Male/Female Ratio                                                                    0.8
# # Newsletter subscriptions                                                          42.0
# NL/User                                                                              12%
# # Fingerprints                                                                     108.0
# FP/User                                                                              32%
# # Restaurants nearby                                                                22.0
# Avg. NPS Score                                                                       7.8

# %%
# Now we pick up the columns which has the correct and wrong formats, then categorize them.  

clean_int_columns = [
    'Fridge ID',
    'Year Founded',
    'Office Size'  
] 

clean_str_columns = [
    'City',
    'Location',
    'Maturity',
    'Industry',
    'IndustryNew',
    'Company Type',
    'Company Type*', 
    'Employee Type',
    'Innercompany Location',
    'Lead Source',
    'Fridge Type'  
] 

clean_float_columns = [
    
    'Registered Users',
    'Active users (weekly average 2019 per terminal)',
    'Basket size/User/Week', 'Male/Female Ratio',
    '# Newsletter subscriptions',
    '# Fingerprints',
    '# Restaurants nearby',
    'Avg. NPS Score'  
]

# There is an unwanted 'Û' in these columns
global columns_remove_U_and_convert_str_to_float 
columns_remove_U_and_convert_str_to_float = [
    'Service Fee', 
    'Subsidy', 
    'Revenue'
]

# We have to convert the str type to float type
global columns_remove_percentage_and_convert_str_to_float
columns_remove_percentage_and_convert_str_to_float = [
    'NL/User', 
    'FP/User'
]


checked_columns = [
    clean_int_columns,
    clean_str_columns,
    clean_float_columns,
    columns_remove_U_and_convert_str_to_float,
    columns_remove_percentage_and_convert_str_to_float
]

# Verify whether we have checked all the columns
total_num_columns = len(df_train.columns) 
checked_columns = [x for xs in checked_columns for x in xs]
num_missed_column = total_num_columns - len(checked_columns)

try:
    0 == num_missed_column
    print(f'We have checked all {total_num_columns} columns')
    
except ValueError:
    raise ValueError(f"We have missed to check {num_missed_column} columns")
# Out:
# We have checked all 27 columns

# %% [markdown]
# ## Correct Mismatched Data Type

# %%
# We create a function to wrap ip the cleaning and encoding process and apply them to both train and test set.
# i.e., we need to creat several udf for pandas dataframe, although udf is slow applied to big dataframe. 

def func_remove_U_and_convert_str_to_float(cell):
    try:
        cell = re.sub('[^0-9.]', "", cell.replace(",","."))
        return float(cell)
    except:
        return np.nan   # missing value is casted to -1.
 
def func_remove_percentage_and_convert_str_to_float(cell):
    try:
        cell = cell.replace("%","")
        return float(cell)
    
    except:   
        return np.nan
    

def apply_udf(df,columns,func):
    for col in columns:
        df[col] = df.apply(lambda x: func(x[col]),axis = 1)
        
    return df


def clean_data(df,data_type):
   
    df = apply_udf(
        df,
        columns_remove_percentage_and_convert_str_to_float,
        func_remove_percentage_and_convert_str_to_float
    )
    
    if data_type == 'train':
        df = apply_udf(
            df,
            columns_remove_U_and_convert_str_to_float,
            func_remove_U_and_convert_str_to_float
        )
    elif data_type == 'test':
        df = apply_udf(
            df,
            set(columns_remove_U_and_convert_str_to_float) - label_col_name,
            func_remove_U_and_convert_str_to_float
        )
    else:
        raise ValueError("data_type input is wrong")
    
    return df

# %% [markdown]
# ## Check Missing Value and Fill String Valued Column

# %%
def get_missing_value_percentage(df):
    percent_missing = df.isnull().sum() * 100 / len(df)
    missing_value_df = pd.DataFrame({
        'percent_missing': percent_missing
    })
    missing_value_df.sort_values('percent_missing', inplace=True)
    
    return missing_value_df


df_train = clean_data(df_train,'train')
df_test = clean_data(df_test,'test')

global numeric_colunms
global str_columns
numeric_colunms = set(checked_columns)\
               - set(clean_str_columns)
str_columns = clean_str_columns

global str_column_fillna_value
str_column_fillna_value = 'Unknown'

# %%
# We fill 'unknown' in the string valued column if the value is missing.
# we fill with the average value if the value is missing in that column.
     
        
def fill_missing_value(df,numeric_features,str_features):
    
    df_str = df[str_features]
    df_numeric = df[numeric_features]
    
    df_numeric = df_numeric.fillna(value=df_numeric.mean())
    df_str = df_str.fillna(value=str_column_fillna_value)
    df = pd.concat([df_numeric, df_str],axis=1)
    return df

# %% [markdown]
# ## Check Correlation Between All Columns

# %%
# We use the whole training data to get the Heatmap matrix which gives us an overview of all pair correlations.
df_train = fill_missing_value(df_train, numeric_colunms,str_columns)   
df_test = fill_missing_value(df_test, numeric_colunms-label_col_name, str_columns) 
corr = df_train.corr()
display(corr)
# Out:
#                                                   Subsidy   FP/User   NL/User  \
# Subsidy                                          1.000000  0.123439  0.045030
# FP/User                                          0.123439  1.000000  0.261969
# NL/User                                          0.045030  0.261969  1.000000
# Revenue                                          0.273119  0.228317  0.001673
# # Newsletter subscriptions                      -0.067446  0.041817  0.127295
# Year Founded                                     0.049700 -0.051898 -0.202475
# Fridge ID                                       -0.062084 -0.187896  0.094979
# # Fingerprints                                  -0.004526  0.300165 -0.073070
# Basket size/User/Week                            0.195651  0.070158  0.121355
# Male/Female Ratio                                0.024339  0.052112 -0.134380
# # Restaurants nearby                            -0.033123 -0.166167 -0.133312
# Service Fee                                      0.088171 -0.003535  0.103900
# Office Size                                     -0.160370 -0.126899 -0.036241
# Registered Users                                -0.073152 -0.008235 -0.100766
# Active users (weekly average 2019 per terminal)  0.168224  0.201689  0.006375
# Avg. NPS Score                                   0.053320  0.069560  0.225991
#
#                                                   Revenue  \
# Subsidy                                          0.273119
# FP/User                                          0.228317
# NL/User                                          0.001673
# Revenue                                          1.000000
# # Newsletter subscriptions                       0.377834
# Year Founded                                     0.143770
# Fridge ID                                       -0.305169
# # Fingerprints                                   0.504865
# Basket size/User/Week                            0.132400
# Male/Female Ratio                               -0.076353
# # Restaurants nearby                            -0.116038
# Service Fee                                      0.025224
# Office Size                                      0.004965
# Registered Users                                 0.309066
# Active users (weekly average 2019 per terminal)  0.942982
# Avg. NPS Score                                   0.108391
#
#                                                  # Newsletter subscriptions  \
# Subsidy                                                           -0.067446
# FP/User                                                            0.041817
# NL/User                                                            0.127295
# Revenue                                                            0.377834
# # Newsletter subscriptions                                         1.000000
# Year Founded                                                       0.047212
# Fridge ID                                                         -0.325508
# # Fingerprints                                                     0.838215
# Basket size/User/Week                                             -0.274559
# Male/Female Ratio                                                 -0.108796
# # Restaurants nearby                                               0.038703
# Service Fee                                                        0.078897
# Office Size                                                        0.369071
# Registered Users                                                   0.931704
# Active users (weekly average 2019 per terminal)                    0.513393
# Avg. NPS Score                                                     0.147824
#
#                                                  Year Founded  Fridge ID  \
# Subsidy                                              0.049700  -0.062084
# FP/User                                             -0.051898  -0.187896
# NL/User                                             -0.202475   0.094979
# Revenue                                              0.143770  -0.305169
# # Newsletter subscriptions                           0.047212  -0.325508
# Year Founded                                         1.000000  -0.037812
# Fridge ID                                           -0.037812   1.000000
# # Fingerprints                                       0.119853  -0.383138
# Basket size/User/Week                               -0.061810   0.273732
# Male/Female Ratio                                   -0.157158   0.074107
# # Restaurants nearby                                 0.181424  -0.136249
# Service Fee                                          0.091055  -0.032501
# Office Size                                         -0.179148  -0.129286
# Registered Users                                     0.117776  -0.330997
# Active users (weekly average 2019 per terminal)      0.159023  -0.349677
# Avg. NPS Score                                      -0.169206   0.063821
#
#                                                  # Fingerprints  \
# Subsidy                                               -0.004526
# FP/User                                                0.300165
# NL/User                                               -0.073070
# Revenue                                                0.504865
# # Newsletter subscriptions                             0.838215
# Year Founded                                           0.119853
# Fridge ID                                             -0.383138
# # Fingerprints                                         1.000000
# Basket size/User/Week                                 -0.262434
# Male/Female Ratio                                     -0.058084
# # Restaurants nearby                                  -0.020948
# Service Fee                                            0.083479
# Office Size                                            0.248893
# Registered Users                                       0.808139
# Active users (weekly average 2019 per terminal)        0.619787
# Avg. NPS Score                                         0.139418
#
#                                                  Basket size/User/Week  \
# Subsidy                                                       0.195651
# FP/User                                                       0.070158
# NL/User                                                       0.121355
# Revenue                                                       0.132400
# # Newsletter subscriptions                                   -0.274559
# Year Founded                                                 -0.061810
# Fridge ID                                                     0.273732
# # Fingerprints                                               -0.262434
# Basket size/User/Week                                         1.000000
# Male/Female Ratio                                             0.071858
# # Restaurants nearby                                         -0.199906
# Service Fee                                                  -0.087758
# Office Size                                                  -0.156773
# Registered Users                                             -0.271734
# Active users (weekly average 2019 per terminal)              -0.122782
# Avg. NPS Score                                               -0.002213
#
#                                                  Male/Female Ratio  \
# Subsidy                                                   0.024339
# FP/User                                                   0.052112
# NL/User                                                  -0.134380
# Revenue                                                  -0.076353
# # Newsletter subscriptions                               -0.108796
# Year Founded                                             -0.157158
# Fridge ID                                                 0.074107
# # Fingerprints                                           -0.058084
# Basket size/User/Week                                     0.071858
# Male/Female Ratio                                         1.000000
# # Restaurants nearby                                     -0.041986
# Service Fee                                              -0.018165
# Office Size                                               0.130431
# Registered Users                                         -0.090666
# Active users (weekly average 2019 per terminal)          -0.095928
# Avg. NPS Score                                            0.000287
#
#                                                  # Restaurants nearby  \
# Subsidy                                                     -0.033123
# FP/User                                                     -0.166167
# NL/User                                                     -0.133312
# Revenue                                                     -0.116038
# # Newsletter subscriptions                                   0.038703
# Year Founded                                                 0.181424
# Fridge ID                                                   -0.136249
# # Fingerprints                                              -0.020948
# Basket size/User/Week                                       -0.199906
# Male/Female Ratio                                           -0.041986
# # Restaurants nearby                                         1.000000
# Service Fee                                                 -0.038732
# Office Size                                                  0.038403
# Registered Users                                             0.074876
# Active users (weekly average 2019 per terminal)             -0.038554
# Avg. NPS Score                                              -0.029451
#
#                                                  Service Fee  Office Size  \
# Subsidy                                             0.088171    -0.160370
# FP/User                                            -0.003535    -0.126899
# NL/User                                             0.103900    -0.036241
# Revenue                                             0.025224     0.004965
# # Newsletter subscriptions                          0.078897     0.369071
# Year Founded                                        0.091055    -0.179148
# Fridge ID                                          -0.032501    -0.129286
# # Fingerprints                                      0.083479     0.248893
# Basket size/User/Week                              -0.087758    -0.156773
# Male/Female Ratio                                  -0.018165     0.130431
# # Restaurants nearby                               -0.038732     0.038403
# Service Fee                                         1.000000     0.150296
# Office Size                                         0.150296     1.000000
# Registered Users                                    0.060204     0.324528
# Active users (weekly average 2019 per terminal)     0.042203     0.069749
# Avg. NPS Score                                      0.115390     0.231623
#
#                                                  Registered Users  \
# Subsidy                                                 -0.073152
# FP/User                                                 -0.008235
# NL/User                                                 -0.100766
# Revenue                                                  0.309066
# # Newsletter subscriptions                               0.931704
# Year Founded                                             0.117776
# Fridge ID                                               -0.330997
# # Fingerprints                                           0.808139
# Basket size/User/Week                                   -0.271734
# Male/Female Ratio                                       -0.090666
# # Restaurants nearby                                     0.074876
# Service Fee                                              0.060204
# Office Size                                              0.324528
# Registered Users                                         1.000000
# Active users (weekly average 2019 per terminal)          0.426166
# Avg. NPS Score                                           0.077985
#
#                                                  Active users (weekly average 2019 per terminal)  \
# Subsidy                                                                                 0.168224
# FP/User                                                                                 0.201689
# NL/User                                                                                 0.006375
# Revenue                                                                                 0.942982
# # Newsletter subscriptions                                                              0.513393
# Year Founded                                                                            0.159023
# Fridge ID                                                                              -0.349677
# # Fingerprints                                                                          0.619787
# Basket size/User/Week                                                                  -0.122782
# Male/Female Ratio                                                                      -0.095928
# # Restaurants nearby                                                                   -0.038554
# Service Fee                                                                             0.042203
# Office Size                                                                             0.069749
# Registered Users                                                                        0.426166
# Active users (weekly average 2019 per terminal)                                         1.000000
# Avg. NPS Score                                                                          0.104361
#
#                                                  Avg. NPS Score
# Subsidy                                                0.053320
# FP/User                                                0.069560
# NL/User                                                0.225991
# Revenue                                                0.108391
# # Newsletter subscriptions                             0.147824
# Year Founded                                          -0.169206
# Fridge ID                                              0.063821
# # Fingerprints                                         0.139418
# Basket size/User/Week                                 -0.002213
# Male/Female Ratio                                      0.000287
# # Restaurants nearby                                  -0.029451
# Service Fee                                            0.115390
# Office Size                                            0.231623
# Registered Users                                       0.077985
# Active users (weekly average 2019 per terminal)        0.104361
# Avg. NPS Score                                         1.000000

# %%
# For now, we care about the correlation between the features and the to be predicted value.
# The correlation between 'Active users (weekly average 2019 per terminal)' and 'Revenue' is around 94%. 
display(df_train[df_train.columns[1:]].corr()[label_col_name][:-1].sort_values(by='Revenue',ascending=False))
# Out:
#                                                   Revenue
# Revenue                                          1.000000
# Active users (weekly average 2019 per terminal)  0.942982
# # Fingerprints                                   0.504865
# # Newsletter subscriptions                       0.377834
# Registered Users                                 0.309066
# FP/User                                          0.228317
# Year Founded                                     0.143770
# Basket size/User/Week                            0.132400
# Service Fee                                      0.025224
# Office Size                                      0.004965
# NL/User                                          0.001673
# Male/Female Ratio                               -0.076353
# # Restaurants nearby                            -0.116038
# Fridge ID                                       -0.305169

# %%
# Visually, we see that their relation is highly linear.
# i.e. the more the 'Active users (weekly average 2019 per terminal)' the more 'Revenue' will become.
df_train.plot.scatter(x = label_col_name, y = 'Active users (weekly average 2019 per terminal)', s = 100)
# Out:
# <AxesSubplot:xlabel='{Revenue}', ylabel='Active users (weekly average 2019 per terminal)'>

# %% [markdown]
# ## Models: Linear Regression and XGB Regressor

# %%
# We see that the relation between these two columns is highly linear (correlation is ca.94%) 
# this suggests us to build a model using 'Active users (weekly average 2019 per terminal)' to predict 'Revenue'.
# In order to avoid data leakage, we will split the data into train, validation, test and process the data again.

data = pd.read_csv(data_train_path)
data = clean_data(data,'train')
(size_test_set,_) = pd.read_csv(data_test_path).shape
(size_train_set,_) = data.shape

# %%
# We choose str columns with number of unique value <=7, otherwise the resulted table is too sparse
display(data[str_columns].nunique().sort_values())
global str_columns_get_dummies
str_columns_get_dummies = [
    'Location',
    'Maturity',
    'Fridge Type',
    'City',    # we ignore the wired signs in the city names, since they do not bother us.
    'Employee Type' 
]
data_dummies = pd.get_dummies(data[str_columns_get_dummies])
dummies_columns = set(data_dummies.columns)
data = pd.concat([data, data_dummies],axis=1)
# Out:
# Location                  2
# Maturity                  2
# Fridge Type               2
# Company Type*             4
# City                      7
# Employee Type             7
# Lead Source              13
# IndustryNew              15
# Company Type             19
# Industry                 27
# Innercompany Location    28
# dtype: int64

# %%
def get_loss(model,numeric_features,str_features,data,train_index,test_index):
    
    features = numeric_features|str_features
    train_data = data.iloc[train_index]
    test_data  = data.iloc[test_index]
    train_data = fill_missing_value(train_data,numeric_features,str_features)
    test_data = fill_missing_value(test_data,numeric_features,str_features)

    X_train = train_data[features-label_col_name]
    y_train = train_data[label_col_name]
    X_test = test_data[features-label_col_name]
    y_test = test_data[label_col_name]
    
    model = model.fit(X_train, y_train)
    train_y_pred = model.predict(X_train)
    test_y_pred = model.predict(X_test)
    
    train_msr = mean_squared_error(y_train, train_y_pred)
    test_msr = mean_squared_error(y_test, test_y_pred)
    return (train_msr,test_msr)


random_state = 12883823
# we set the n_splits as following to make sure that the size of the hold out set is euqal to the size of test data 
rkf = RepeatedKFold(n_splits=int(size_train_set/size_test_set), n_repeats=10, random_state=random_state)
n = 1

train_lr_baseline_loss = 0
train_lr_positive_corr_loss = 0
train_lr_all_features_loss = 0
train_xgb_reg_loss = 0

test_lr_baseline_loss = 0
test_lr_positive_corr_loss = 0
test_lr_all_features_loss = 0
test_xgb_reg_loss = 0


for train_index, test_index in rkf.split(data):
    
    lr = LinearRegression()
    xgb_reg = XGBRegressor()
    
    lr_baseline_features = set(['Active users (weekly average 2019 per terminal)']) \
                         | label_col_name
    
    lr_positive_corr_features = set([
                                    'Active users (weekly average 2019 per terminal)',
                                    '# Fingerprints',
                                    '# Newsletter subscriptions',
                                    'Registered Users',
                                    'Subsidy',
                                    'FP/User',
                                    'Year Founded',
                                    'Basket size/User/Week'
                                 ])\
                               | label_col_name
                               
    
    
   
    (temp_train_lr_baseline_loss,temp_test_lr_baseline_loss) = get_loss(
        model=lr,
        numeric_features=lr_baseline_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    
    train_lr_baseline_loss+=temp_train_lr_baseline_loss
    test_lr_baseline_loss+=temp_test_lr_baseline_loss
    
    (temp_train_lr_positive_corr_loss,temp_test_lr_positive_corr_loss) = get_loss(
        model=lr,
        numeric_features=lr_positive_corr_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_positive_corr_loss+=temp_train_lr_positive_corr_loss
    test_lr_positive_corr_loss+=temp_test_lr_positive_corr_loss
    
    (temp_train_lr_all_features_loss,temp_test_lr_all_features_loss) = get_loss(
        model=lr,
        numeric_features=numeric_colunms,
        str_features = dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_all_features_loss+=temp_train_lr_all_features_loss
    test_lr_all_features_loss+=temp_test_lr_all_features_loss
    
    (temp_train_xgb_reg_loss,temp_test_xgb_reg_loss)= get_loss(
        model=xgb_reg,
        numeric_features=numeric_colunms,
        str_features = set([]),#dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_xgb_reg_loss+=temp_train_xgb_reg_loss
    test_xgb_reg_loss+=temp_test_xgb_reg_loss
    
    n +=1

    
print('Train:',
      '-lr base line: ',round(train_lr_baseline_loss/n), 
      '-lr more features:',round(train_lr_positive_corr_loss/n),
      '-lr all features: ', round(train_lr_all_features_loss/n),
      '-xgb reg: ', round(train_xgb_reg_loss/n)
      )

print('Test:',
      '-lr base line: ',round(test_lr_baseline_loss/n), 
      '-lr more features:',round(test_lr_positive_corr_loss/n),
      '-lr all features: ', round(test_lr_all_features_loss/n),
      '-xgb reg: ', round(test_xgb_reg_loss/n)
      )
# Out:
# Train: -lr base line:  314 -lr more features: 110 -lr all features:  87 -xgb reg:  0
# Test: -lr base line:  360 -lr more features: 181 -lr all features:  15549692040757088256 -xgb reg:  489

# %% [markdown]
# ## Remove Outlier in Target Value Set
# Because linear regression is sensitive to outliers, after remove them we have a better result.
# <br>
# We remove revenue > 300 data points

# %%
data = pd.read_csv(data_train_path)
data = clean_data(data,'train')
(size_test_set,_) = pd.read_csv(data_test_path).shape
(size_train_set,_) = data.shape
data = data[data.Revenue<300]

global str_columns_get_dummies
str_columns_get_dummies = [
    'Location',
    'Maturity',
    'Fridge Type',
    'City',    # we ignore the wired signs in the city names, since they do not bother us.
    'Employee Type' 
]
data_dummies = pd.get_dummies(data[str_columns_get_dummies])
dummies_columns = set(data_dummies.columns)
data = pd.concat([data, data_dummies],axis=1)


def get_loss(model,numeric_features,str_features,data,train_index,test_index):
    
    features = numeric_features|str_features
    train_data = data.iloc[train_index]
    test_data  = data.iloc[test_index]
    train_data = fill_missing_value(train_data,numeric_features,str_features)
    test_data = fill_missing_value(test_data,numeric_features,str_features)

    X_train = train_data[features-label_col_name]
    y_train = train_data[label_col_name]
    X_test = test_data[features-label_col_name]
    y_test = test_data[label_col_name]
    
    model = model.fit(X_train, y_train)
    train_y_pred = model.predict(X_train)
    test_y_pred = model.predict(X_test)
    
    train_msr = mean_squared_error(y_train, train_y_pred)
    test_msr = mean_squared_error(y_test, test_y_pred)
    return (train_msr,test_msr)


random_state = 12883823
# we set the n_splits as following to make sure that the size of the hold out set is euqal to the size of test data 
# todo: shows that 3 can give stable train, test evaluation loss
rkf = RepeatedKFold(n_splits=int(size_train_set/size_test_set), n_repeats=3, random_state=random_state)
n = 1

train_lr_baseline_loss = 0
train_lr_positive_corr_loss = 0
train_lr_all_features_loss = 0
train_xgb_reg_loss = 0

test_lr_baseline_loss = 0
test_lr_positive_corr_loss = 0
test_lr_all_features_loss = 0
test_xgb_reg_loss = 0


for train_index, test_index in rkf.split(data):
    
    lr = LinearRegression()
    xgb_reg = XGBRegressor()
    
    lr_baseline_features = set(['Active users (weekly average 2019 per terminal)']) \
                         | label_col_name
    
    lr_positive_corr_features = set([
                                    'Active users (weekly average 2019 per terminal)',
                                    '# Fingerprints',
                                    '# Newsletter subscriptions',
                                    'Registered Users',
                                    'Subsidy',
                                    'FP/User',
                                    'Year Founded',
                                    'Basket size/User/Week'
                                 ])\
                               | label_col_name
                               
    
    
   
    (temp_train_lr_baseline_loss,temp_test_lr_baseline_loss) = get_loss(
        model=lr,
        numeric_features=lr_baseline_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    
    train_lr_baseline_loss+=temp_train_lr_baseline_loss
    test_lr_baseline_loss+=temp_test_lr_baseline_loss
    
    (temp_train_lr_positive_corr_loss,temp_test_lr_positive_corr_loss) = get_loss(
        model=lr,
        numeric_features=lr_positive_corr_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_positive_corr_loss+=temp_train_lr_positive_corr_loss
    test_lr_positive_corr_loss+=temp_test_lr_positive_corr_loss
    
    (temp_train_lr_all_features_loss,temp_test_lr_all_features_loss) = get_loss(
        model=lr,
        numeric_features=numeric_colunms,
        str_features = dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_lr_all_features_loss+=temp_train_lr_all_features_loss
    test_lr_all_features_loss+=temp_test_lr_all_features_loss
    
    (temp_train_xgb_reg_loss,temp_test_xgb_reg_loss)= get_loss(
        model=xgb_reg,
        numeric_features=numeric_colunms,
        str_features = set([]),#dummies_columns,
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    train_xgb_reg_loss+=temp_train_xgb_reg_loss
    test_xgb_reg_loss+=temp_test_xgb_reg_loss
    
    n +=1

    
print('Train:',
      '-lr base line: ',round(train_lr_baseline_loss/n), 
      '-lr more features:',round(train_lr_positive_corr_loss/n),
      '-lr all features: ', round(train_lr_all_features_loss/n),
      '-xgb reg: ', round(train_xgb_reg_loss/n)
      )

print('Test:',
      '-lr base line: ',round(test_lr_baseline_loss/n), 
      '-lr more features:',round(test_lr_positive_corr_loss/n),
      '-lr all features: ', round(test_lr_all_features_loss/n),
      '-xgb reg: ', round(test_xgb_reg_loss/n)
      )
# Out:
# Train: -lr base line:  215 -lr more features: 59 -lr all features:  45 -xgb reg:  0
# Test: -lr base line:  227 -lr more features: 90 -lr all features:  10137293478358372352 -xgb reg:  120

# %% [markdown]
# ## Temporary Summary of Model Performance
# As we have seen that the performance before removing outlier is:
# <br>
# Test: -lr base line:  360 -lr more features: 181 -lr all features:  15549692040757088256 - xgb reg:  489
# <br>
# After removing outlier is:
# <br>
# Test: -lr base line:  232 -lr more features: 92 -lr all features:  11904794902809554944 - xgb reg:  119
# <br>
# xgb reg is 300% better than before, yet lr more features is still the best one.<br>
# prediction over train set of lr all features implies that we shall not use all features, but the one from the lr more features model.
# <br>
# We will give a try of autoML with autokeras (autosklearn does not support windows which is a os system.).
# <br>
# Useing the following commands to install.
# !pip install git+https://github.com/keras-team/keras-tuner.git
# !pip install autokeras

# %% [markdown]
# ## AutoMl vs. Best Model lr more feartures

# %%
data = pd.read_csv(data_train_path)
data = clean_data(data,'train')
(size_test_set,_) = pd.read_csv(data_test_path).shape
(size_train_set,_) = data.shape
data = data[data.Revenue<300]

global str_columns_get_dummies
str_columns_get_dummies = [
    'Location',
    'Maturity',
    'Fridge Type',
    'City',    # we ignore the wired signs in the city names, since they do not bother us.
    'Employee Type' 
]
data_dummies = pd.get_dummies(data[str_columns_get_dummies])
dummies_columns = set(data_dummies.columns)
data = pd.concat([data, data_dummies],axis=1)


def prepare_train_test(numeric_features,str_features,data,train_index,test_index):
    
    features = numeric_features|str_features
    train_data = data.iloc[train_index]
    test_data  = data.iloc[test_index]
    train_data = fill_missing_value(train_data,numeric_features,str_features)
    test_data = fill_missing_value(test_data,numeric_features,str_features)

    X_train = train_data[features-label_col_name]
    y_train = train_data[label_col_name]
    X_test = test_data[features-label_col_name]
    y_test = test_data[label_col_name]
    

    return X_train,y_train,X_test,y_test


random_state = 12883823
# we set the n_splits as following to make sure that the size of the hold out set is euqal to the size of test data 
rkf = RepeatedKFold(n_splits=int(size_train_set/size_test_set), n_repeats=3, random_state=random_state)
n = 1

train_auto_ml_loss = 0
test_auto_ml_loss = 0
train_lr_positive_corr_loss = 0
test_lr_positive_corr_loss = 0


for train_index, test_index in rkf.split(data):
    
    
    lr = LinearRegression()
    
    
    lr_positive_corr_features = set([
                                    'Active users (weekly average 2019 per terminal)',
                                    '# Fingerprints',
                                    '# Newsletter subscriptions',
                                    'Registered Users',
                                    'Subsidy',
                                    'FP/User',
                                    'Year Founded',
                                    'Basket size/User/Week'
                                 ])\
                               | label_col_name
    
    (temp_train_lr_positive_corr_loss,temp_test_lr_positive_corr_loss) = get_loss(
        model=lr,
        numeric_features=lr_positive_corr_features,
        str_features = set([]),
        data=data,
        train_index=train_index,
        test_index=test_index
    )
    
    train_lr_positive_corr_loss+=temp_train_lr_positive_corr_loss
    test_lr_positive_corr_loss+=temp_test_lr_positive_corr_loss
    
    
    
    X_train,y_train,X_test,y_test = prepare_train_test(
        numeric_features=numeric_colunms,
        str_features=set([]),
        data=data,
        train_index=train_index,
        test_index=test_index)
    
    search = StructuredDataRegressor(max_trials=15, loss='mean_absolute_error')
    search.fit(x=X_train, y=y_train, verbose=0)
    temp_train_auto_ml_loss,_ = search.evaluate(X_train, y_train, verbose=0)
    temp_test_auto_ml_loss,_ = search.evaluate(X_test, y_test, verbose=0)
    train_auto_ml_loss+=temp_train_auto_ml_loss
    test_auto_ml_loss+=temp_test_auto_ml_loss
    n+=1
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 4/4 [==============================] - 1s 3ms/step - loss: 79.5221 - mean_squared_error: 8267.6953
# Epoch 2/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.3314 - mean_squared_error: 8224.8086
# Epoch 3/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.0873 - mean_squared_error: 8213.7393
# Epoch 4/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.8203 - mean_squared_error: 8152.1382
# Epoch 5/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.5543 - mean_squared_error: 8114.2275
# Epoch 6/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.2491 - mean_squared_error: 8063.6572
# Epoch 7/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.0743 - mean_squared_error: 8039.4604
# Epoch 8/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.9719 - mean_squared_error: 8021.4331
# Epoch 9/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.5942 - mean_squared_error: 7979.8755
# Epoch 10/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.4462 - mean_squared_error: 7954.4390
# Epoch 11/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.1316 - mean_squared_error: 7896.8286
# Epoch 12/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.0756 - mean_squared_error: 7878.1074
# Epoch 13/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.6061 - mean_squared_error: 7807.0649
# Epoch 14/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.4501 - mean_squared_error: 7789.4268
# Epoch 15/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.1606 - mean_squared_error: 7743.6118
# Epoch 16/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.9328 - mean_squared_error: 7733.5684
# Epoch 17/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.5333 - mean_squared_error: 7644.3496
# Epoch 18/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.4541 - mean_squared_error: 7631.1377
# Epoch 19/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.2193 - mean_squared_error: 7622.5229
# Epoch 20/88
# 4/4 [==============================] - 0s 2ms/step - loss: 74.6806 - mean_squared_error: 7503.9839
# Epoch 21/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.5172 - mean_squared_error: 7486.8276
# Epoch 22/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.3486 - mean_squared_error: 7452.3960
# Epoch 23/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.1535 - mean_squared_error: 7440.3960
# Epoch 24/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.6675 - mean_squared_error: 7370.8408
# Epoch 25/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.5540 - mean_squared_error: 7359.5088
# Epoch 26/88
# 4/4 [==============================] - 0s 2ms/step - loss: 72.9222 - mean_squared_error: 7272.3843
# Epoch 27/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.0364 - mean_squared_error: 7277.9712
# Epoch 28/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.5164 - mean_squared_error: 7194.4243
# Epoch 29/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.2583 - mean_squared_error: 7167.1431
# Epoch 30/88
# 4/4 [==============================] - 0s 2ms/step - loss: 71.9748 - mean_squared_error: 7130.3521
# Epoch 31/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.7570 - mean_squared_error: 7099.9277
# Epoch 32/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.0170 - mean_squared_error: 6979.6191
# Epoch 33/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.9427 - mean_squared_error: 6960.1025
# Epoch 34/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.7496 - mean_squared_error: 6947.5337
# Epoch 35/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.0669 - mean_squared_error: 6837.7139
# Epoch 36/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.9180 - mean_squared_error: 6846.8164
# Epoch 37/88
# 4/4 [==============================] - 0s 2ms/step - loss: 69.4925 - mean_squared_error: 6765.8970
# Epoch 38/88
# 4/4 [==============================] - 0s 2ms/step - loss: 69.1414 - mean_squared_error: 6729.6289
# Epoch 39/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.3287 - mean_squared_error: 6757.0518
# Epoch 40/88
# 4/4 [==============================] - 0s 3ms/step - loss: 68.5808 - mean_squared_error: 6670.3774
# Epoch 41/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.8645 - mean_squared_error: 6546.2417
# Epoch 42/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.6255 - mean_squared_error: 6500.2480
# Epoch 43/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.2928 - mean_squared_error: 6461.6846
# Epoch 44/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.8500 - mean_squared_error: 6393.9517
# Epoch 45/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.5638 - mean_squared_error: 6382.9346
# Epoch 46/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.0530 - mean_squared_error: 6302.5942
# Epoch 47/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.6987 - mean_squared_error: 6275.2627
# Epoch 48/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.2179 - mean_squared_error: 6211.4707
# Epoch 49/88
# 4/4 [==============================] - 0s 2ms/step - loss: 64.7177 - mean_squared_error: 6117.6538
# Epoch 50/88
# 4/4 [==============================] - 0s 3ms/step - loss: 64.3385 - mean_squared_error: 6097.3237
# Epoch 51/88
# 4/4 [==============================] - 0s 3ms/step - loss: 64.0244 - mean_squared_error: 6066.1719
# Epoch 52/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.5093 - mean_squared_error: 5991.8247
# Epoch 53/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.0107 - mean_squared_error: 5974.0430
# Epoch 54/88
# 4/4 [==============================] - 0s 3ms/step - loss: 62.9328 - mean_squared_error: 5902.4360
# Epoch 55/88
# 4/4 [==============================] - 0s 3ms/step - loss: 61.7960 - mean_squared_error: 5749.7983
# Epoch 56/88
# 4/4 [==============================] - 0s 2ms/step - loss: 62.1024 - mean_squared_error: 5815.5869
# Epoch 57/88
# 4/4 [==============================] - 0s 3ms/step - loss: 61.3443 - mean_squared_error: 5640.8564
# Epoch 58/88
# 4/4 [==============================] - 0s 3ms/step - loss: 61.0149 - mean_squared_error: 5681.8921
# Epoch 59/88
# 4/4 [==============================] - 0s 3ms/step - loss: 59.8664 - mean_squared_error: 5491.9087
# Epoch 60/88
# 4/4 [==============================] - 0s 3ms/step - loss: 59.7701 - mean_squared_error: 5515.2295
# Epoch 61/88
# 4/4 [==============================] - 0s 2ms/step - loss: 59.2680 - mean_squared_error: 5421.9058
# Epoch 62/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.2909 - mean_squared_error: 5315.8003
# Epoch 63/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.3575 - mean_squared_error: 5323.6294
# Epoch 64/88
# 4/4 [==============================] - 0s 3ms/step - loss: 57.6981 - mean_squared_error: 5249.6001
# Epoch 65/88
# 4/4 [==============================] - 0s 3ms/step - loss: 57.2938 - mean_squared_error: 5206.6699
# Epoch 66/88
# 4/4 [==============================] - 0s 3ms/step - loss: 56.4212 - mean_squared_error: 5144.2021
# Epoch 67/88
# 4/4 [==============================] - 0s 3ms/step - loss: 57.0319 - mean_squared_error: 5141.3169
# Epoch 68/88
# 4/4 [==============================] - 0s 2ms/step - loss: 56.0767 - mean_squared_error: 5105.6196
# Epoch 69/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.9797 - mean_squared_error: 4933.0532
# Epoch 70/88
# 4/4 [==============================] - 0s 2ms/step - loss: 54.8174 - mean_squared_error: 4854.8735
# Epoch 71/88
# 4/4 [==============================] - 0s 2ms/step - loss: 54.8417 - mean_squared_error: 4826.7397
# Epoch 72/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.9235 - mean_squared_error: 4862.3560
# Epoch 73/88
# 4/4 [==============================] - 0s 3ms/step - loss: 53.1653 - mean_squared_error: 4653.7661
# Epoch 74/88
# 4/4 [==============================] - 0s 3ms/step - loss: 53.1170 - mean_squared_error: 4668.8320
# Epoch 75/88
# 4/4 [==============================] - 0s 2ms/step - loss: 51.5310 - mean_squared_error: 4513.8203
# Epoch 76/88
# 4/4 [==============================] - 0s 3ms/step - loss: 52.7983 - mean_squared_error: 4622.9077
# Epoch 77/88
# 4/4 [==============================] - 0s 3ms/step - loss: 51.8178 - mean_squared_error: 4509.9126
# Epoch 78/88
# 4/4 [==============================] - 0s 3ms/step - loss: 51.1604 - mean_squared_error: 4471.1543
# Epoch 79/88
# 4/4 [==============================] - 0s 3ms/step - loss: 50.7913 - mean_squared_error: 4440.0444
# Epoch 80/88
# 4/4 [==============================] - 0s 3ms/step - loss: 50.0809 - mean_squared_error: 4255.7261
# Epoch 81/88
# 4/4 [==============================] - 0s 3ms/step - loss: 49.8679 - mean_squared_error: 4224.1934
# Epoch 82/88
# 4/4 [==============================] - 0s 3ms/step - loss: 48.8751 - mean_squared_error: 4144.9116
# Epoch 83/88
# 4/4 [==============================] - 0s 3ms/step - loss: 48.9517 - mean_squared_error: 4132.8276
# Epoch 84/88
# 4/4 [==============================] - 0s 3ms/step - loss: 47.6914 - mean_squared_error: 4031.9102
# Epoch 85/88
# 4/4 [==============================] - 0s 3ms/step - loss: 47.9647 - mean_squared_error: 4007.4832
# Epoch 86/88
# 4/4 [==============================] - 0s 3ms/step - loss: 47.3373 - mean_squared_error: 3927.2358
# Epoch 87/88
# 4/4 [==============================] - 0s 3ms/step - loss: 47.3770 - mean_squared_error: 3969.6553
# Epoch 88/88
# 4/4 [==============================] - 0s 3ms/step - loss: 46.4112 - mean_squared_error: 3862.7319
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 4/4 [==============================] - 1s 3ms/step - loss: 81.9558 - mean_squared_error: 8973.3008
# Epoch 2/88
# 4/4 [==============================] - 0s 3ms/step - loss: 81.7209 - mean_squared_error: 8945.9141
# Epoch 3/88
# 4/4 [==============================] - 0s 3ms/step - loss: 81.3516 - mean_squared_error: 8885.9004
# Epoch 4/88
# 4/4 [==============================] - 0s 3ms/step - loss: 81.3046 - mean_squared_error: 8862.3672
# Epoch 5/88
# 4/4 [==============================] - 0s 3ms/step - loss: 80.9154 - mean_squared_error: 8819.1689
# Epoch 6/88
# 4/4 [==============================] - 0s 3ms/step - loss: 80.7838 - mean_squared_error: 8782.4736
# Epoch 7/88
# 4/4 [==============================] - 0s 3ms/step - loss: 80.5672 - mean_squared_error: 8745.7246
# Epoch 8/88
# 4/4 [==============================] - 0s 3ms/step - loss: 80.1685 - mean_squared_error: 8686.6357
# Epoch 9/88
# 4/4 [==============================] - 0s 3ms/step - loss: 80.2011 - mean_squared_error: 8692.5010
# Epoch 10/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.7256 - mean_squared_error: 8617.7090
# Epoch 11/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.4906 - mean_squared_error: 8561.4609
# Epoch 12/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.3867 - mean_squared_error: 8555.9053
# Epoch 13/88
# 4/4 [==============================] - 0s 2ms/step - loss: 79.1158 - mean_squared_error: 8515.6445
# Epoch 14/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.7146 - mean_squared_error: 8439.3857
# Epoch 15/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.6787 - mean_squared_error: 8435.8105
# Epoch 16/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.3653 - mean_squared_error: 8414.9326
# Epoch 17/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.9229 - mean_squared_error: 8325.0283
# Epoch 18/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.5600 - mean_squared_error: 8277.7627
# Epoch 19/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.3877 - mean_squared_error: 8261.0879
# Epoch 20/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.3267 - mean_squared_error: 8239.0049
# Epoch 21/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.7892 - mean_squared_error: 8163.2178
# Epoch 22/88
# 4/4 [==============================] - 0s 2ms/step - loss: 76.7408 - mean_squared_error: 8135.5088
# Epoch 23/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.5173 - mean_squared_error: 8128.7041
# Epoch 24/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.1656 - mean_squared_error: 8057.7969
# Epoch 25/88
# 4/4 [==============================] - 0s 2ms/step - loss: 75.8474 - mean_squared_error: 8041.6538
# Epoch 26/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.6403 - mean_squared_error: 7975.4165
# Epoch 27/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.1212 - mean_squared_error: 7918.1738
# Epoch 28/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.8203 - mean_squared_error: 7885.2197
# Epoch 29/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.7867 - mean_squared_error: 7871.2363
# Epoch 30/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.1110 - mean_squared_error: 7763.8076
# Epoch 31/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.0404 - mean_squared_error: 7774.3335
# Epoch 32/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.5552 - mean_squared_error: 7721.2827
# Epoch 33/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.3558 - mean_squared_error: 7612.8638
# Epoch 34/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.0888 - mean_squared_error: 7585.4619
# Epoch 35/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.8513 - mean_squared_error: 7587.8560
# Epoch 36/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.5080 - mean_squared_error: 7535.8374
# Epoch 37/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.2193 - mean_squared_error: 7425.3408
# Epoch 38/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.8337 - mean_squared_error: 7416.7500
# Epoch 39/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.1114 - mean_squared_error: 7304.5083
# Epoch 40/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.3537 - mean_squared_error: 7392.9829
# Epoch 41/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.0051 - mean_squared_error: 7333.3799
# Epoch 42/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.2267 - mean_squared_error: 7226.0488
# Epoch 43/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.8653 - mean_squared_error: 7194.7627
# Epoch 44/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.6207 - mean_squared_error: 7096.3989
# Epoch 45/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.4137 - mean_squared_error: 7067.0786
# Epoch 46/88
# 4/4 [==============================] - 0s 3ms/step - loss: 68.9420 - mean_squared_error: 7028.5288
# Epoch 47/88
# 4/4 [==============================] - 0s 3ms/step - loss: 68.1474 - mean_squared_error: 6959.9414
# Epoch 48/88
# 4/4 [==============================] - 0s 3ms/step - loss: 68.4190 - mean_squared_error: 6908.4019
# Epoch 49/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.8445 - mean_squared_error: 6912.2632
# Epoch 50/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.4300 - mean_squared_error: 6832.5283
# Epoch 51/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.6156 - mean_squared_error: 6706.6216
# Epoch 52/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.2854 - mean_squared_error: 6690.4531
# Epoch 53/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.4997 - mean_squared_error: 6530.7832
# Epoch 54/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.2417 - mean_squared_error: 6548.0864
# Epoch 55/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.1891 - mean_squared_error: 6521.2583
# Epoch 56/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.0374 - mean_squared_error: 6491.9131
# Epoch 57/88
# 4/4 [==============================] - 0s 3ms/step - loss: 64.3169 - mean_squared_error: 6483.0986
# Epoch 58/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.8372 - mean_squared_error: 6346.7173
# Epoch 59/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.3735 - mean_squared_error: 6280.3730
# Epoch 60/88
# 4/4 [==============================] - 0s 3ms/step - loss: 62.9640 - mean_squared_error: 6191.3560
# Epoch 61/88
# 4/4 [==============================] - 0s 3ms/step - loss: 62.2223 - mean_squared_error: 6072.8633
# Epoch 62/88
# 4/4 [==============================] - 0s 3ms/step - loss: 62.6375 - mean_squared_error: 6177.0942
# Epoch 63/88
# 4/4 [==============================] - 0s 3ms/step - loss: 61.9147 - mean_squared_error: 6049.5908
# Epoch 64/88
# 4/4 [==============================] - 0s 2ms/step - loss: 60.7703 - mean_squared_error: 5907.7124
# Epoch 65/88
# 4/4 [==============================] - 0s 3ms/step - loss: 60.2025 - mean_squared_error: 5848.7607
# Epoch 66/88
# 4/4 [==============================] - 0s 3ms/step - loss: 59.6900 - mean_squared_error: 5769.5205
# Epoch 67/88
# 4/4 [==============================] - 0s 3ms/step - loss: 59.6269 - mean_squared_error: 5772.7251
# Epoch 68/88
# 4/4 [==============================] - 0s 3ms/step - loss: 59.2865 - mean_squared_error: 5718.4360
# Epoch 69/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.8252 - mean_squared_error: 5659.2710
# Epoch 70/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.1768 - mean_squared_error: 5568.2173
# Epoch 71/88
# 4/4 [==============================] - 0s 3ms/step - loss: 57.3734 - mean_squared_error: 5514.7471
# Epoch 72/88
# 4/4 [==============================] - 0s 3ms/step - loss: 56.7536 - mean_squared_error: 5392.8442
# Epoch 73/88
# 4/4 [==============================] - 0s 3ms/step - loss: 56.3089 - mean_squared_error: 5401.8188
# Epoch 74/88
# 4/4 [==============================] - 0s 3ms/step - loss: 56.5593 - mean_squared_error: 5350.6953
# Epoch 75/88
# 4/4 [==============================] - 0s 3ms/step - loss: 56.0287 - mean_squared_error: 5310.4160
# Epoch 76/88
# 4/4 [==============================] - 0s 3ms/step - loss: 55.4115 - mean_squared_error: 5256.6235
# Epoch 77/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.2618 - mean_squared_error: 5103.8071
# Epoch 78/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.8224 - mean_squared_error: 5171.7788
# Epoch 79/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.3234 - mean_squared_error: 5122.6343
# Epoch 80/88
# 4/4 [==============================] - 0s 2ms/step - loss: 53.5972 - mean_squared_error: 4973.1211
# Epoch 81/88
# 4/4 [==============================] - 0s 3ms/step - loss: 53.4468 - mean_squared_error: 4983.0820
# Epoch 82/88
# 4/4 [==============================] - 0s 3ms/step - loss: 52.4537 - mean_squared_error: 4933.3423
# Epoch 83/88
# 4/4 [==============================] - 0s 3ms/step - loss: 51.5227 - mean_squared_error: 4721.0278
# Epoch 84/88
# 4/4 [==============================] - 0s 3ms/step - loss: 52.0461 - mean_squared_error: 4875.2388
# Epoch 85/88
# 4/4 [==============================] - 0s 3ms/step - loss: 50.8663 - mean_squared_error: 4666.0757
# Epoch 86/88
# 4/4 [==============================] - 0s 3ms/step - loss: 51.0946 - mean_squared_error: 4682.3218
# Epoch 87/88
# 4/4 [==============================] - 0s 3ms/step - loss: 50.0139 - mean_squared_error: 4593.2651
# Epoch 88/88
# 4/4 [==============================] - 0s 3ms/step - loss: 49.7794 - mean_squared_error: 4521.6792
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 4/4 [==============================] - 1s 3ms/step - loss: 79.9687 - mean_squared_error: 8497.7979
# Epoch 2/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.8445 - mean_squared_error: 8465.9482
# Epoch 3/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.8335 - mean_squared_error: 8470.5537
# Epoch 4/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.5061 - mean_squared_error: 8416.1562
# Epoch 5/88
# 4/4 [==============================] - 0s 3ms/step - loss: 79.1637 - mean_squared_error: 8364.0264
# Epoch 6/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.9569 - mean_squared_error: 8338.0684
# Epoch 7/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.8771 - mean_squared_error: 8350.1494
# Epoch 8/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.5036 - mean_squared_error: 8261.0361
# Epoch 9/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.2697 - mean_squared_error: 8218.5654
# Epoch 10/88
# 4/4 [==============================] - 0s 3ms/step - loss: 78.0080 - mean_squared_error: 8209.6914
# Epoch 11/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.8403 - mean_squared_error: 8171.5288
# Epoch 12/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.5107 - mean_squared_error: 8121.8892
# Epoch 13/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.4190 - mean_squared_error: 8112.2446
# Epoch 14/88
# 4/4 [==============================] - 0s 3ms/step - loss: 77.2267 - mean_squared_error: 8091.1074
# Epoch 15/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.9718 - mean_squared_error: 8037.1567
# Epoch 16/88
# 4/4 [==============================] - 0s 2ms/step - loss: 76.6430 - mean_squared_error: 7986.0469
# Epoch 17/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.3287 - mean_squared_error: 7929.5737
# Epoch 18/88
# 4/4 [==============================] - 0s 3ms/step - loss: 76.1472 - mean_squared_error: 7912.1553
# Epoch 19/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.9576 - mean_squared_error: 7885.3989
# Epoch 20/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.6915 - mean_squared_error: 7843.4868
# Epoch 21/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.3600 - mean_squared_error: 7797.3428
# Epoch 22/88
# 4/4 [==============================] - 0s 3ms/step - loss: 75.0568 - mean_squared_error: 7734.6030
# Epoch 23/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.8782 - mean_squared_error: 7736.9463
# Epoch 24/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.6258 - mean_squared_error: 7686.1128
# Epoch 25/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.2993 - mean_squared_error: 7608.9692
# Epoch 26/88
# 4/4 [==============================] - 0s 3ms/step - loss: 74.0711 - mean_squared_error: 7598.9043
# Epoch 27/88
# 4/4 [==============================] - 0s 2ms/step - loss: 73.4711 - mean_squared_error: 7506.7329
# Epoch 28/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.3653 - mean_squared_error: 7507.5317
# Epoch 29/88
# 4/4 [==============================] - 0s 3ms/step - loss: 73.2671 - mean_squared_error: 7485.9897
# Epoch 30/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.9426 - mean_squared_error: 7431.7993
# Epoch 31/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.7206 - mean_squared_error: 7410.8638
# Epoch 32/88
# 4/4 [==============================] - 0s 3ms/step - loss: 72.1151 - mean_squared_error: 7310.8618
# Epoch 33/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.9164 - mean_squared_error: 7300.9165
# Epoch 34/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.3696 - mean_squared_error: 7209.9360
# Epoch 35/88
# 4/4 [==============================] - 0s 3ms/step - loss: 71.2141 - mean_squared_error: 7220.7441
# Epoch 36/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.6964 - mean_squared_error: 7143.5859
# Epoch 37/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.3453 - mean_squared_error: 7081.5010
# Epoch 38/88
# 4/4 [==============================] - 0s 3ms/step - loss: 70.4333 - mean_squared_error: 7048.9990
# Epoch 39/88
# 4/4 [==============================] - 0s 2ms/step - loss: 70.0275 - mean_squared_error: 7042.8696
# Epoch 40/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.5353 - mean_squared_error: 6949.4878
# Epoch 41/88
# 4/4 [==============================] - 0s 3ms/step - loss: 69.2746 - mean_squared_error: 6917.5879
# Epoch 42/88
# 4/4 [==============================] - 0s 3ms/step - loss: 68.9023 - mean_squared_error: 6872.9668
# Epoch 43/88
# 4/4 [==============================] - 0s 3ms/step - loss: 68.2825 - mean_squared_error: 6778.3281
# Epoch 44/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.9412 - mean_squared_error: 6711.2017
# Epoch 45/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.7399 - mean_squared_error: 6682.1968
# Epoch 46/88
# 4/4 [==============================] - 0s 3ms/step - loss: 67.2676 - mean_squared_error: 6646.8145
# Epoch 47/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.8438 - mean_squared_error: 6560.3413
# Epoch 48/88
# 4/4 [==============================] - 0s 2ms/step - loss: 66.3344 - mean_squared_error: 6491.6040
# Epoch 49/88
# 4/4 [==============================] - 0s 3ms/step - loss: 66.1773 - mean_squared_error: 6542.7930
# Epoch 50/88
# 4/4 [==============================] - 0s 3ms/step - loss: 65.6872 - mean_squared_error: 6440.2554
# Epoch 51/88
# 4/4 [==============================] - 0s 2ms/step - loss: 64.9214 - mean_squared_error: 6351.3389
# Epoch 52/88
# 4/4 [==============================] - 0s 3ms/step - loss: 64.7316 - mean_squared_error: 6347.4971
# Epoch 53/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.9422 - mean_squared_error: 6195.6621
# Epoch 54/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.7573 - mean_squared_error: 6200.2163
# Epoch 55/88
# 4/4 [==============================] - 0s 3ms/step - loss: 63.5723 - mean_squared_error: 6183.4712
# Epoch 56/88
# 4/4 [==============================] - 0s 2ms/step - loss: 63.4290 - mean_squared_error: 6071.7461
# Epoch 57/88
# 4/4 [==============================] - 0s 2ms/step - loss: 62.3795 - mean_squared_error: 6003.9463
# Epoch 58/88
# 4/4 [==============================] - 0s 3ms/step - loss: 62.1857 - mean_squared_error: 5991.7041
# Epoch 59/88
# 4/4 [==============================] - 0s 3ms/step - loss: 61.1594 - mean_squared_error: 5805.2017
# Epoch 60/88
# 4/4 [==============================] - 0s 3ms/step - loss: 61.0029 - mean_squared_error: 5823.3428
# Epoch 61/88
# 4/4 [==============================] - 0s 2ms/step - loss: 60.7850 - mean_squared_error: 5836.2192
# Epoch 62/88
# 4/4 [==============================] - 0s 3ms/step - loss: 60.3407 - mean_squared_error: 5702.8945
# Epoch 63/88
# 4/4 [==============================] - 0s 3ms/step - loss: 59.4168 - mean_squared_error: 5642.4990
# Epoch 64/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.8602 - mean_squared_error: 5544.5674
# Epoch 65/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.4102 - mean_squared_error: 5472.5679
# Epoch 66/88
# 4/4 [==============================] - 0s 3ms/step - loss: 58.0517 - mean_squared_error: 5426.0679
# Epoch 67/88
# 4/4 [==============================] - 0s 2ms/step - loss: 57.0874 - mean_squared_error: 5325.9126
# Epoch 68/88
# 4/4 [==============================] - 0s 2ms/step - loss: 57.2254 - mean_squared_error: 5300.1113
# Epoch 69/88
# 4/4 [==============================] - 0s 2ms/step - loss: 56.5337 - mean_squared_error: 5233.6670
# Epoch 70/88
# 4/4 [==============================] - 0s 3ms/step - loss: 56.3999 - mean_squared_error: 5284.2788
# Epoch 71/88
# 4/4 [==============================] - 0s 3ms/step - loss: 55.2531 - mean_squared_error: 5120.2231
# Epoch 72/88
# 4/4 [==============================] - 0s 3ms/step - loss: 55.2513 - mean_squared_error: 5093.0347
# Epoch 73/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.3330 - mean_squared_error: 4956.5386
# Epoch 74/88
# 4/4 [==============================] - 0s 3ms/step - loss: 54.3024 - mean_squared_error: 5017.3306
# Epoch 75/88
# 4/4 [==============================] - 0s 2ms/step - loss: 53.2353 - mean_squared_error: 4883.5132
# Epoch 76/88
# 4/4 [==============================] - 0s 3ms/step - loss: 53.3870 - mean_squared_error: 4845.8096
# Epoch 77/88
# 4/4 [==============================] - 0s 3ms/step - loss: 52.5665 - mean_squared_error: 4772.4409
# Epoch 78/88
# 4/4 [==============================] - 0s 3ms/step - loss: 51.9290 - mean_squared_error: 4716.7241
# Epoch 79/88
# 4/4 [==============================] - 0s 2ms/step - loss: 51.5392 - mean_squared_error: 4682.0298
# Epoch 80/88
# 4/4 [==============================] - 0s 3ms/step - loss: 50.8376 - mean_squared_error: 4505.7822
# Epoch 81/88
# 4/4 [==============================] - 0s 3ms/step - loss: 49.4346 - mean_squared_error: 4344.0078
# Epoch 82/88
# 4/4 [==============================] - 0s 3ms/step - loss: 50.1894 - mean_squared_error: 4470.3511
# Epoch 83/88
# 4/4 [==============================] - 0s 3ms/step - loss: 48.5663 - mean_squared_error: 4304.7905
# Epoch 84/88
# 4/4 [==============================] - 0s 3ms/step - loss: 49.0601 - mean_squared_error: 4373.5884
# Epoch 85/88
# 4/4 [==============================] - 0s 3ms/step - loss: 48.6225 - mean_squared_error: 4316.9766
# Epoch 86/88
# 4/4 [==============================] - 0s 3ms/step - loss: 48.5897 - mean_squared_error: 4243.9302
# Epoch 87/88
# 4/4 [==============================] - 0s 3ms/step - loss: 47.7116 - mean_squared_error: 4193.3892
# Epoch 88/88
# 4/4 [==============================] - 0s 3ms/step - loss: 46.4127 - mean_squared_error: 3931.6931
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 5/5 [==============================] - 1s 3ms/step - loss: 79.0024 - mean_squared_error: 8208.1299
# Epoch 2/88
# 5/5 [==============================] - 0s 3ms/step - loss: 78.6903 - mean_squared_error: 8167.0562
# Epoch 3/88
# 5/5 [==============================] - 0s 3ms/step - loss: 78.3605 - mean_squared_error: 8108.6108
# Epoch 4/88
# 5/5 [==============================] - 0s 3ms/step - loss: 78.1038 - mean_squared_error: 8085.2646
# Epoch 5/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.8660 - mean_squared_error: 8037.9521
# Epoch 6/88
# 5/5 [==============================] - 0s 2ms/step - loss: 77.6630 - mean_squared_error: 8016.7134
# Epoch 7/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.3765 - mean_squared_error: 7954.5078
# Epoch 8/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.9192 - mean_squared_error: 7898.6001
# Epoch 9/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.8139 - mean_squared_error: 7872.6299
# Epoch 10/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.5287 - mean_squared_error: 7823.1494
# Epoch 11/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.3104 - mean_squared_error: 7796.5044
# Epoch 12/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.9897 - mean_squared_error: 7751.9639
# Epoch 13/88
# 5/5 [==============================] - 0s 2ms/step - loss: 75.8268 - mean_squared_error: 7714.2935
# Epoch 14/88
# 5/5 [==============================] - 0s 2ms/step - loss: 75.4752 - mean_squared_error: 7654.1484
# Epoch 15/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.1900 - mean_squared_error: 7621.4199
# Epoch 16/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.9775 - mean_squared_error: 7591.6509
# Epoch 17/88
# 5/5 [==============================] - 0s 3ms/step - loss: 74.7701 - mean_squared_error: 7557.0869
# Epoch 18/88
# 5/5 [==============================] - 0s 3ms/step - loss: 74.3713 - mean_squared_error: 7504.7417
# Epoch 19/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.8478 - mean_squared_error: 7420.9961
# Epoch 20/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.8274 - mean_squared_error: 7417.2583
# Epoch 21/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.3718 - mean_squared_error: 7352.7397
# Epoch 22/88
# 5/5 [==============================] - 0s 3ms/step - loss: 73.3106 - mean_squared_error: 7354.6880
# Epoch 23/88
# 5/5 [==============================] - 0s 2ms/step - loss: 72.5883 - mean_squared_error: 7248.8794
# Epoch 24/88
# 5/5 [==============================] - 0s 3ms/step - loss: 72.5484 - mean_squared_error: 7228.5728
# Epoch 25/88
# 5/5 [==============================] - 0s 3ms/step - loss: 72.2714 - mean_squared_error: 7179.9556
# Epoch 26/88
# 5/5 [==============================] - 0s 3ms/step - loss: 71.9493 - mean_squared_error: 7163.8042
# Epoch 27/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.4649 - mean_squared_error: 7100.2856
# Epoch 28/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.1974 - mean_squared_error: 7030.9692
# Epoch 29/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.8007 - mean_squared_error: 6996.0728
# Epoch 30/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.4431 - mean_squared_error: 6935.5181
# Epoch 31/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.0625 - mean_squared_error: 6910.0293
# Epoch 32/88
# 5/5 [==============================] - 0s 3ms/step - loss: 69.9912 - mean_squared_error: 6885.0933
# Epoch 33/88
# 5/5 [==============================] - 0s 3ms/step - loss: 69.5068 - mean_squared_error: 6812.5938
# Epoch 34/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.1676 - mean_squared_error: 6734.4443
# Epoch 35/88
# 5/5 [==============================] - 0s 2ms/step - loss: 68.3914 - mean_squared_error: 6675.4844
# Epoch 36/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.9762 - mean_squared_error: 6576.0005
# Epoch 37/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.8257 - mean_squared_error: 6613.1855
# Epoch 38/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.2317 - mean_squared_error: 6465.5845
# Epoch 39/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.3097 - mean_squared_error: 6513.9556
# Epoch 40/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.6318 - mean_squared_error: 6437.4058
# Epoch 41/88
# 5/5 [==============================] - 0s 2ms/step - loss: 66.2848 - mean_squared_error: 6370.0801
# Epoch 42/88
# 5/5 [==============================] - 0s 3ms/step - loss: 65.6163 - mean_squared_error: 6264.8857
# Epoch 43/88
# 5/5 [==============================] - 0s 3ms/step - loss: 65.0739 - mean_squared_error: 6230.3911
# Epoch 44/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.8375 - mean_squared_error: 6207.3164
# Epoch 45/88
# 5/5 [==============================] - 0s 3ms/step - loss: 64.2255 - mean_squared_error: 6090.9360
# Epoch 46/88
# 5/5 [==============================] - 0s 3ms/step - loss: 63.9144 - mean_squared_error: 6078.7441
# Epoch 47/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.8539 - mean_squared_error: 6114.1245
# Epoch 48/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.4586 - mean_squared_error: 5961.4048
# Epoch 49/88
# 5/5 [==============================] - 0s 2ms/step - loss: 62.7375 - mean_squared_error: 5930.5034
# Epoch 50/88
# 5/5 [==============================] - 0s 2ms/step - loss: 62.2863 - mean_squared_error: 5882.2246
# Epoch 51/88
# 5/5 [==============================] - 0s 3ms/step - loss: 61.5467 - mean_squared_error: 5717.9106
# Epoch 52/88
# 5/5 [==============================] - 0s 3ms/step - loss: 61.1593 - mean_squared_error: 5734.0215
# Epoch 53/88
# 5/5 [==============================] - 0s 3ms/step - loss: 59.8930 - mean_squared_error: 5544.2129
# Epoch 54/88
# 5/5 [==============================] - 0s 2ms/step - loss: 59.5159 - mean_squared_error: 5473.6675
# Epoch 55/88
# 5/5 [==============================] - 0s 3ms/step - loss: 58.9191 - mean_squared_error: 5472.3511
# Epoch 56/88
# 5/5 [==============================] - 0s 2ms/step - loss: 59.5935 - mean_squared_error: 5524.4346
# Epoch 57/88
# 5/5 [==============================] - 0s 2ms/step - loss: 58.3922 - mean_squared_error: 5374.3984
# Epoch 58/88
# 5/5 [==============================] - 0s 3ms/step - loss: 58.0794 - mean_squared_error: 5340.0566
# Epoch 59/88
# 5/5 [==============================] - 0s 2ms/step - loss: 57.1648 - mean_squared_error: 5246.0610
# Epoch 60/88
# 5/5 [==============================] - 0s 2ms/step - loss: 56.2143 - mean_squared_error: 5138.2305
# Epoch 61/88
# 5/5 [==============================] - 0s 2ms/step - loss: 56.6860 - mean_squared_error: 5160.4609
# Epoch 62/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.4648 - mean_squared_error: 4966.0942
# Epoch 63/88
# 5/5 [==============================] - 0s 2ms/step - loss: 55.0220 - mean_squared_error: 5005.3306
# Epoch 64/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.0952 - mean_squared_error: 4970.7222
# Epoch 65/88
# 5/5 [==============================] - 0s 2ms/step - loss: 54.0933 - mean_squared_error: 4828.8560
# Epoch 66/88
# 5/5 [==============================] - 0s 2ms/step - loss: 53.2492 - mean_squared_error: 4826.4663
# Epoch 67/88
# 5/5 [==============================] - 0s 2ms/step - loss: 53.0618 - mean_squared_error: 4758.7319
# Epoch 68/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.0125 - mean_squared_error: 4579.0552
# Epoch 69/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.8817 - mean_squared_error: 4526.6777
# Epoch 70/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.0407 - mean_squared_error: 4509.4902
# Epoch 71/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.1473 - mean_squared_error: 4477.7368
# Epoch 72/88
# 5/5 [==============================] - 0s 2ms/step - loss: 50.3212 - mean_squared_error: 4477.3452
# Epoch 73/88
# 5/5 [==============================] - 0s 3ms/step - loss: 50.6646 - mean_squared_error: 4483.0566
# Epoch 74/88
# 5/5 [==============================] - 0s 3ms/step - loss: 49.5952 - mean_squared_error: 4306.3193
# Epoch 75/88
# 5/5 [==============================] - 0s 3ms/step - loss: 49.4597 - mean_squared_error: 4338.8677
# Epoch 76/88
# 5/5 [==============================] - 0s 2ms/step - loss: 49.6506 - mean_squared_error: 4349.1807
# Epoch 77/88
# 5/5 [==============================] - 0s 3ms/step - loss: 48.8316 - mean_squared_error: 4159.8726
# Epoch 78/88
# 5/5 [==============================] - 0s 2ms/step - loss: 47.8242 - mean_squared_error: 4162.9883
# Epoch 79/88
# 5/5 [==============================] - 0s 3ms/step - loss: 48.3255 - mean_squared_error: 4149.2173
# Epoch 80/88
# 5/5 [==============================] - 0s 2ms/step - loss: 47.1256 - mean_squared_error: 4030.3525
# Epoch 81/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.0137 - mean_squared_error: 3942.4585
# Epoch 82/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.8831 - mean_squared_error: 3983.5447
# Epoch 83/88
# 5/5 [==============================] - 0s 2ms/step - loss: 45.4800 - mean_squared_error: 3867.2241
# Epoch 84/88
# 5/5 [==============================] - 0s 3ms/step - loss: 45.8613 - mean_squared_error: 3877.4265
# Epoch 85/88
# 5/5 [==============================] - 0s 2ms/step - loss: 45.5445 - mean_squared_error: 3860.7156
# Epoch 86/88
# 5/5 [==============================] - 0s 3ms/step - loss: 45.7453 - mean_squared_error: 3895.5864
# Epoch 87/88
# 5/5 [==============================] - 0s 3ms/step - loss: 44.7852 - mean_squared_error: 3738.8862
# Epoch 88/88
# 5/5 [==============================] - 0s 3ms/step - loss: 44.3586 - mean_squared_error: 3658.8516
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 5/5 [==============================] - 1s 3ms/step - loss: 77.6475 - mean_squared_error: 8105.6558
# Epoch 2/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.3657 - mean_squared_error: 8060.0815
# Epoch 3/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.0318 - mean_squared_error: 8023.9883
# Epoch 4/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.6959 - mean_squared_error: 7982.8506
# Epoch 5/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.4623 - mean_squared_error: 7926.6655
# Epoch 6/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.2023 - mean_squared_error: 7890.3926
# Epoch 7/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.0045 - mean_squared_error: 7848.8521
# Epoch 8/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.6417 - mean_squared_error: 7814.6216
# Epoch 9/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.4785 - mean_squared_error: 7790.4302
# Epoch 10/88
# 5/5 [==============================] - 0s 2ms/step - loss: 75.1578 - mean_squared_error: 7726.9727
# Epoch 11/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.7304 - mean_squared_error: 7678.1943
# Epoch 12/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.6738 - mean_squared_error: 7658.7544
# Epoch 13/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.4072 - mean_squared_error: 7626.0923
# Epoch 14/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.1969 - mean_squared_error: 7591.7974
# Epoch 15/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.9233 - mean_squared_error: 7553.4561
# Epoch 16/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.4527 - mean_squared_error: 7477.3018
# Epoch 17/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.2902 - mean_squared_error: 7464.2188
# Epoch 18/88
# 5/5 [==============================] - 0s 2ms/step - loss: 72.9234 - mean_squared_error: 7414.8970
# Epoch 19/88
# 5/5 [==============================] - 0s 2ms/step - loss: 72.6901 - mean_squared_error: 7367.2998
# Epoch 20/88
# 5/5 [==============================] - 0s 2ms/step - loss: 72.2897 - mean_squared_error: 7295.1035
# Epoch 21/88
# 5/5 [==============================] - 0s 2ms/step - loss: 72.3423 - mean_squared_error: 7322.5308
# Epoch 22/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.9156 - mean_squared_error: 7252.2070
# Epoch 23/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.4914 - mean_squared_error: 7193.1299
# Epoch 24/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.2880 - mean_squared_error: 7164.9414
# Epoch 25/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.0414 - mean_squared_error: 7145.0332
# Epoch 26/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.5582 - mean_squared_error: 7064.7227
# Epoch 27/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.1784 - mean_squared_error: 7006.6914
# Epoch 28/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.9997 - mean_squared_error: 6985.4937
# Epoch 29/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.6369 - mean_squared_error: 6926.3633
# Epoch 30/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.1810 - mean_squared_error: 6893.2935
# Epoch 31/88
# 5/5 [==============================] - 0s 2ms/step - loss: 68.6728 - mean_squared_error: 6782.0420
# Epoch 32/88
# 5/5 [==============================] - 0s 2ms/step - loss: 68.5417 - mean_squared_error: 6742.6069
# Epoch 33/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.8056 - mean_squared_error: 6708.1807
# Epoch 34/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.6243 - mean_squared_error: 6634.0938
# Epoch 35/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.9293 - mean_squared_error: 6547.5015
# Epoch 36/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.0376 - mean_squared_error: 6610.8477
# Epoch 37/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.6668 - mean_squared_error: 6514.3145
# Epoch 38/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.0366 - mean_squared_error: 6473.3350
# Epoch 39/88
# 5/5 [==============================] - 0s 3ms/step - loss: 65.5316 - mean_squared_error: 6369.6035
# Epoch 40/88
# 5/5 [==============================] - 0s 2ms/step - loss: 65.1907 - mean_squared_error: 6326.1206
# Epoch 41/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.6189 - mean_squared_error: 6310.4814
# Epoch 42/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.9670 - mean_squared_error: 6164.4438
# Epoch 43/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.8047 - mean_squared_error: 6199.6436
# Epoch 44/88
# 5/5 [==============================] - 0s 3ms/step - loss: 63.9043 - mean_squared_error: 6150.0576
# Epoch 45/88
# 5/5 [==============================] - 0s 3ms/step - loss: 62.5579 - mean_squared_error: 5962.5444
# Epoch 46/88
# 5/5 [==============================] - 0s 2ms/step - loss: 62.4453 - mean_squared_error: 5963.4473
# Epoch 47/88
# 5/5 [==============================] - 0s 2ms/step - loss: 61.6947 - mean_squared_error: 5926.9688
# Epoch 48/88
# 5/5 [==============================] - 0s 2ms/step - loss: 61.7681 - mean_squared_error: 5904.8306
# Epoch 49/88
# 5/5 [==============================] - 0s 3ms/step - loss: 60.8776 - mean_squared_error: 5818.3887
# Epoch 50/88
# 5/5 [==============================] - 0s 2ms/step - loss: 60.8069 - mean_squared_error: 5783.7993
# Epoch 51/88
# 5/5 [==============================] - 0s 3ms/step - loss: 59.8275 - mean_squared_error: 5673.7100
# Epoch 52/88
# 5/5 [==============================] - 0s 2ms/step - loss: 59.3568 - mean_squared_error: 5622.0410
# Epoch 53/88
# 5/5 [==============================] - 0s 3ms/step - loss: 58.7719 - mean_squared_error: 5584.3784
# Epoch 54/88
# 5/5 [==============================] - 0s 3ms/step - loss: 58.1445 - mean_squared_error: 5456.0112
# Epoch 55/88
# 5/5 [==============================] - 0s 3ms/step - loss: 57.6154 - mean_squared_error: 5398.5776
# Epoch 56/88
# 5/5 [==============================] - 0s 2ms/step - loss: 56.8514 - mean_squared_error: 5366.8677
# Epoch 57/88
# 5/5 [==============================] - 0s 3ms/step - loss: 56.6722 - mean_squared_error: 5263.8682
# Epoch 58/88
# 5/5 [==============================] - 0s 2ms/step - loss: 55.7831 - mean_squared_error: 5141.0352
# Epoch 59/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.6733 - mean_squared_error: 5146.6538
# Epoch 60/88
# 5/5 [==============================] - 0s 2ms/step - loss: 55.0054 - mean_squared_error: 5061.6206
# Epoch 61/88
# 5/5 [==============================] - 0s 2ms/step - loss: 54.3883 - mean_squared_error: 4986.6963
# Epoch 62/88
# 5/5 [==============================] - 0s 2ms/step - loss: 53.1378 - mean_squared_error: 4870.0879
# Epoch 63/88
# 5/5 [==============================] - 0s 3ms/step - loss: 53.0803 - mean_squared_error: 4857.1235
# Epoch 64/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.9981 - mean_squared_error: 4871.2612
# Epoch 65/88
# 5/5 [==============================] - 0s 3ms/step - loss: 52.9053 - mean_squared_error: 4838.4502
# Epoch 66/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.2291 - mean_squared_error: 4730.6372
# Epoch 67/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.1800 - mean_squared_error: 4715.5596
# Epoch 68/88
# 5/5 [==============================] - 0s 2ms/step - loss: 50.6449 - mean_squared_error: 4601.5938
# Epoch 69/88
# ...
# Epoch 37/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.7735 - mean_squared_error: 6163.5718
# Epoch 38/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.4397 - mean_squared_error: 6108.4419
# Epoch 39/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.3264 - mean_squared_error: 6155.9351
# Epoch 40/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.6149 - mean_squared_error: 6041.5659
# Epoch 41/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.0036 - mean_squared_error: 5945.3516
# Epoch 42/88
# 5/5 [==============================] - 0s 3ms/step - loss: 62.8329 - mean_squared_error: 5926.0952
# Epoch 43/88
# 5/5 [==============================] - 0s 2ms/step - loss: 62.5243 - mean_squared_error: 5867.9780
# Epoch 44/88
# 5/5 [==============================] - 0s 2ms/step - loss: 61.7705 - mean_squared_error: 5801.7720
# Epoch 45/88
# 5/5 [==============================] - 0s 2ms/step - loss: 61.4000 - mean_squared_error: 5716.3320
# Epoch 46/88
# 5/5 [==============================] - 0s 2ms/step - loss: 60.5434 - mean_squared_error: 5622.5835
# Epoch 47/88
# 5/5 [==============================] - 0s 2ms/step - loss: 60.3325 - mean_squared_error: 5598.5845
# Epoch 48/88
# 5/5 [==============================] - 0s 2ms/step - loss: 59.5986 - mean_squared_error: 5544.4956
# Epoch 49/88
# 5/5 [==============================] - 0s 2ms/step - loss: 59.1036 - mean_squared_error: 5462.3076
# Epoch 50/88
# 5/5 [==============================] - 0s 3ms/step - loss: 58.7372 - mean_squared_error: 5385.6943
# Epoch 51/88
# 5/5 [==============================] - 0s 2ms/step - loss: 58.2458 - mean_squared_error: 5350.2959
# Epoch 52/88
# 5/5 [==============================] - 0s 3ms/step - loss: 57.9047 - mean_squared_error: 5324.2246
# Epoch 53/88
# 5/5 [==============================] - 0s 2ms/step - loss: 57.2751 - mean_squared_error: 5236.1162
# Epoch 54/88
# 5/5 [==============================] - 0s 3ms/step - loss: 56.3422 - mean_squared_error: 5116.0640
# Epoch 55/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.8521 - mean_squared_error: 5070.2031
# Epoch 56/88
# 5/5 [==============================] - 0s 2ms/step - loss: 55.8015 - mean_squared_error: 5066.5176
# Epoch 57/88
# 5/5 [==============================] - 0s 2ms/step - loss: 54.5238 - mean_squared_error: 4961.6377
# Epoch 58/88
# 5/5 [==============================] - 0s 2ms/step - loss: 54.3378 - mean_squared_error: 4896.9922
# Epoch 59/88
# 5/5 [==============================] - 0s 3ms/step - loss: 54.3013 - mean_squared_error: 4876.1318
# Epoch 60/88
# 5/5 [==============================] - 0s 2ms/step - loss: 54.0971 - mean_squared_error: 4824.7490
# Epoch 61/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.1998 - mean_squared_error: 4649.7720
# Epoch 62/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.5674 - mean_squared_error: 4691.0210
# Epoch 63/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.1517 - mean_squared_error: 4622.1304
# Epoch 64/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.1756 - mean_squared_error: 4582.7173
# Epoch 65/88
# 5/5 [==============================] - 0s 3ms/step - loss: 51.2698 - mean_squared_error: 4526.9995
# Epoch 66/88
# 5/5 [==============================] - 0s 2ms/step - loss: 50.5565 - mean_squared_error: 4477.7568
# Epoch 67/88
# 5/5 [==============================] - 0s 2ms/step - loss: 49.8201 - mean_squared_error: 4296.9736
# Epoch 68/88
# 5/5 [==============================] - 0s 3ms/step - loss: 49.3263 - mean_squared_error: 4242.5259
# Epoch 69/88
# 5/5 [==============================] - 0s 2ms/step - loss: 49.9951 - mean_squared_error: 4345.2017
# Epoch 70/88
# 5/5 [==============================] - 0s 2ms/step - loss: 48.3641 - mean_squared_error: 4209.4087
# Epoch 71/88
# 5/5 [==============================] - 0s 2ms/step - loss: 48.2620 - mean_squared_error: 4170.4692
# Epoch 72/88
# 5/5 [==============================] - 0s 2ms/step - loss: 48.6513 - mean_squared_error: 4128.4385
# Epoch 73/88
# 5/5 [==============================] - 0s 2ms/step - loss: 47.6975 - mean_squared_error: 4116.9873
# Epoch 74/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.4104 - mean_squared_error: 3903.7588
# Epoch 75/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.4577 - mean_squared_error: 3877.5654
# Epoch 76/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.5265 - mean_squared_error: 3948.6323
# Epoch 77/88
# 5/5 [==============================] - 0s 3ms/step - loss: 45.9391 - mean_squared_error: 3967.1157
# Epoch 78/88
# 5/5 [==============================] - 0s 2ms/step - loss: 45.3418 - mean_squared_error: 3798.9158
# Epoch 79/88
# 5/5 [==============================] - 0s 2ms/step - loss: 45.3411 - mean_squared_error: 3745.0684
# Epoch 80/88
# 5/5 [==============================] - 0s 3ms/step - loss: 45.0506 - mean_squared_error: 3814.1814
# Epoch 81/88
# 5/5 [==============================] - 0s 3ms/step - loss: 44.3211 - mean_squared_error: 3792.8394
# Epoch 82/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.3766 - mean_squared_error: 3593.5405
# Epoch 83/88
# 5/5 [==============================] - 0s 3ms/step - loss: 44.2545 - mean_squared_error: 3722.5066
# Epoch 84/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.5538 - mean_squared_error: 3594.6567
# Epoch 85/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.4880 - mean_squared_error: 3689.6526
# Epoch 86/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.4125 - mean_squared_error: 3554.0901
# Epoch 87/88
# 5/5 [==============================] - 0s 2ms/step - loss: 43.2171 - mean_squared_error: 3591.6113
# Epoch 88/88
# 5/5 [==============================] - 0s 2ms/step - loss: 41.1784 - mean_squared_error: 3432.7388
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 5/5 [==============================] - 1s 4ms/step - loss: 79.0284 - mean_squared_error: 8204.1377
# Epoch 2/88
# 5/5 [==============================] - 0s 3ms/step - loss: 78.9410 - mean_squared_error: 8198.0088
# Epoch 3/88
# 5/5 [==============================] - 0s 3ms/step - loss: 78.3884 - mean_squared_error: 8108.6323
# Epoch 4/88
# 5/5 [==============================] - 0s 2ms/step - loss: 78.2006 - mean_squared_error: 8074.0337
# Epoch 5/88
# 5/5 [==============================] - 0s 2ms/step - loss: 77.9437 - mean_squared_error: 8031.2617
# Epoch 6/88
# 5/5 [==============================] - 0s 2ms/step - loss: 77.7307 - mean_squared_error: 7988.9517
# Epoch 7/88
# 5/5 [==============================] - 0s 2ms/step - loss: 77.2752 - mean_squared_error: 7927.0698
# Epoch 8/88
# 5/5 [==============================] - 0s 2ms/step - loss: 77.2150 - mean_squared_error: 7925.3403
# Epoch 9/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.8853 - mean_squared_error: 7861.4961
# Epoch 10/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.6293 - mean_squared_error: 7814.5703
# Epoch 11/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.2509 - mean_squared_error: 7760.3755
# Epoch 12/88
# 5/5 [==============================] - 0s 2ms/step - loss: 76.1331 - mean_squared_error: 7752.6616
# Epoch 13/88
# 5/5 [==============================] - 0s 2ms/step - loss: 75.8459 - mean_squared_error: 7679.3447
# Epoch 14/88
# 5/5 [==============================] - 0s 2ms/step - loss: 75.4532 - mean_squared_error: 7643.1396
# Epoch 15/88
# 5/5 [==============================] - 0s 2ms/step - loss: 75.2590 - mean_squared_error: 7605.3716
# Epoch 16/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.0861 - mean_squared_error: 7593.3848
# Epoch 17/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.7752 - mean_squared_error: 7530.7554
# Epoch 18/88
# 5/5 [==============================] - 0s 2ms/step - loss: 74.3069 - mean_squared_error: 7488.0000
# Epoch 19/88
# 5/5 [==============================] - 0s 3ms/step - loss: 74.0254 - mean_squared_error: 7405.0205
# Epoch 20/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.6071 - mean_squared_error: 7373.0200
# Epoch 21/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.2422 - mean_squared_error: 7336.6636
# Epoch 22/88
# 5/5 [==============================] - 0s 2ms/step - loss: 73.3179 - mean_squared_error: 7322.6992
# Epoch 23/88
# 5/5 [==============================] - 0s 3ms/step - loss: 72.5722 - mean_squared_error: 7187.2261
# Epoch 24/88
# 5/5 [==============================] - 0s 3ms/step - loss: 72.1379 - mean_squared_error: 7162.9917
# Epoch 25/88
# 5/5 [==============================] - 0s 2ms/step - loss: 72.1388 - mean_squared_error: 7160.0420
# Epoch 26/88
# 5/5 [==============================] - 0s 2ms/step - loss: 71.7243 - mean_squared_error: 7074.6069
# Epoch 27/88
# 5/5 [==============================] - 0s 3ms/step - loss: 71.6252 - mean_squared_error: 7051.7124
# Epoch 28/88
# 5/5 [==============================] - 0s 3ms/step - loss: 70.9724 - mean_squared_error: 6985.7915
# Epoch 29/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.8089 - mean_squared_error: 6956.5640
# Epoch 30/88
# 5/5 [==============================] - 0s 2ms/step - loss: 70.2275 - mean_squared_error: 6839.9468
# Epoch 31/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.8329 - mean_squared_error: 6821.6582
# Epoch 32/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.3773 - mean_squared_error: 6761.2715
# Epoch 33/88
# 5/5 [==============================] - 0s 2ms/step - loss: 69.3993 - mean_squared_error: 6794.1680
# Epoch 34/88
# 5/5 [==============================] - 0s 3ms/step - loss: 68.0329 - mean_squared_error: 6571.1914
# Epoch 35/88
# 5/5 [==============================] - 0s 2ms/step - loss: 68.1311 - mean_squared_error: 6601.0498
# Epoch 36/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.6207 - mean_squared_error: 6527.0557
# Epoch 37/88
# 5/5 [==============================] - 0s 2ms/step - loss: 67.4686 - mean_squared_error: 6509.2612
# Epoch 38/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.3131 - mean_squared_error: 6339.8779
# Epoch 39/88
# 5/5 [==============================] - 0s 2ms/step - loss: 66.6006 - mean_squared_error: 6416.5894
# Epoch 40/88
# 5/5 [==============================] - 0s 2ms/step - loss: 65.9819 - mean_squared_error: 6289.4692
# Epoch 41/88
# 5/5 [==============================] - 0s 2ms/step - loss: 65.2934 - mean_squared_error: 6187.2886
# Epoch 42/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.7894 - mean_squared_error: 6175.2402
# Epoch 43/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.4276 - mean_squared_error: 6118.0366
# Epoch 44/88
# 5/5 [==============================] - 0s 2ms/step - loss: 64.1719 - mean_squared_error: 6052.5308
# Epoch 45/88
# 5/5 [==============================] - 0s 2ms/step - loss: 63.3827 - mean_squared_error: 5919.5405
# Epoch 46/88
# 5/5 [==============================] - 0s 3ms/step - loss: 62.8561 - mean_squared_error: 5908.9219
# Epoch 47/88
# 5/5 [==============================] - 0s 2ms/step - loss: 62.3315 - mean_squared_error: 5842.2720
# Epoch 48/88
# 5/5 [==============================] - 0s 2ms/step - loss: 61.4986 - mean_squared_error: 5761.4082
# Epoch 49/88
# 5/5 [==============================] - 0s 2ms/step - loss: 61.3891 - mean_squared_error: 5726.8662
# Epoch 50/88
# 5/5 [==============================] - 0s 2ms/step - loss: 60.4369 - mean_squared_error: 5580.7446
# Epoch 51/88
# 5/5 [==============================] - 0s 2ms/step - loss: 59.7716 - mean_squared_error: 5554.2993
# Epoch 52/88
# 5/5 [==============================] - 0s 2ms/step - loss: 60.0074 - mean_squared_error: 5543.6021
# Epoch 53/88
# 5/5 [==============================] - 0s 2ms/step - loss: 58.9568 - mean_squared_error: 5431.6685
# Epoch 54/88
# 5/5 [==============================] - 0s 2ms/step - loss: 58.0532 - mean_squared_error: 5284.2373
# Epoch 55/88
# 5/5 [==============================] - 0s 2ms/step - loss: 57.8103 - mean_squared_error: 5259.4785
# Epoch 56/88
# 5/5 [==============================] - 0s 2ms/step - loss: 58.1829 - mean_squared_error: 5287.5811
# Epoch 57/88
# 5/5 [==============================] - 0s 2ms/step - loss: 56.5779 - mean_squared_error: 5142.3091
# Epoch 58/88
# 5/5 [==============================] - 0s 2ms/step - loss: 56.2280 - mean_squared_error: 5047.8218
# Epoch 59/88
# 5/5 [==============================] - 0s 2ms/step - loss: 56.2892 - mean_squared_error: 5107.2056
# Epoch 60/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.1496 - mean_squared_error: 4955.0410
# Epoch 61/88
# 5/5 [==============================] - 0s 3ms/step - loss: 54.2499 - mean_squared_error: 4871.7861
# Epoch 62/88
# 5/5 [==============================] - 0s 2ms/step - loss: 54.2070 - mean_squared_error: 4808.7837
# Epoch 63/88
# 5/5 [==============================] - 0s 3ms/step - loss: 53.6275 - mean_squared_error: 4804.8535
# Epoch 64/88
# 5/5 [==============================] - 0s 2ms/step - loss: 53.1477 - mean_squared_error: 4693.5498
# Epoch 65/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.8991 - mean_squared_error: 4655.7710
# Epoch 66/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.7130 - mean_squared_error: 4521.2085
# Epoch 67/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.3468 - mean_squared_error: 4477.3081
# Epoch 68/88
# 5/5 [==============================] - 0s 2ms/step - loss: 52.4672 - mean_squared_error: 4615.6279
# Epoch 69/88
# 5/5 [==============================] - 0s 2ms/step - loss: 51.3538 - mean_squared_error: 4548.9399
# Epoch 70/88
# 5/5 [==============================] - 0s 2ms/step - loss: 50.8767 - mean_squared_error: 4432.1982
# Epoch 71/88
# 5/5 [==============================] - 0s 3ms/step - loss: 49.9532 - mean_squared_error: 4460.1875
# Epoch 72/88
# 5/5 [==============================] - 0s 2ms/step - loss: 49.5834 - mean_squared_error: 4303.0923
# Epoch 73/88
# 5/5 [==============================] - 0s 2ms/step - loss: 49.6261 - mean_squared_error: 4303.2544
# Epoch 74/88
# 5/5 [==============================] - 0s 2ms/step - loss: 49.3282 - mean_squared_error: 4202.0195
# Epoch 75/88
# 5/5 [==============================] - 0s 2ms/step - loss: 48.9834 - mean_squared_error: 4253.4268
# Epoch 76/88
# 5/5 [==============================] - 0s 2ms/step - loss: 48.1428 - mean_squared_error: 4192.5630
# Epoch 77/88
# 5/5 [==============================] - 0s 2ms/step - loss: 48.3252 - mean_squared_error: 4099.1660
# Epoch 78/88
# 5/5 [==============================] - 0s 3ms/step - loss: 47.5084 - mean_squared_error: 4037.1709
# Epoch 79/88
# 5/5 [==============================] - 0s 2ms/step - loss: 47.5483 - mean_squared_error: 4045.2661
# Epoch 80/88
# 5/5 [==============================] - 0s 3ms/step - loss: 46.2737 - mean_squared_error: 4035.7195
# Epoch 81/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.4317 - mean_squared_error: 3927.6758
# Epoch 82/88
# 5/5 [==============================] - 0s 2ms/step - loss: 46.3014 - mean_squared_error: 3902.4866
# Epoch 83/88
# 5/5 [==============================] - 0s 2ms/step - loss: 45.2152 - mean_squared_error: 3773.3279
# Epoch 84/88
# 5/5 [==============================] - 0s 2ms/step - loss: 44.8888 - mean_squared_error: 3761.3035
# Epoch 85/88
# 5/5 [==============================] - 0s 2ms/step - loss: 44.7419 - mean_squared_error: 3784.6636
# Epoch 86/88
# 5/5 [==============================] - 0s 2ms/step - loss: 45.1428 - mean_squared_error: 3748.0322
# Epoch 87/88
# 5/5 [==============================] - 0s 2ms/step - loss: 44.2507 - mean_squared_error: 3677.0527
# Epoch 88/88
# 5/5 [==============================] - 0s 2ms/step - loss: 44.4081 - mean_squared_error: 3664.7302
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets

# %%
print('Train:',
      '-lr more features:',round(train_lr_positive_corr_loss/n),
      '-auto ml: ', round(train_auto_ml_loss/n)
      )

print('Test:',
      '-lr more features:',round(test_lr_positive_corr_loss/n),
      '-auto ml: ', round(test_auto_ml_loss/n)
      )
# Out:
# Train: -lr more features: 59 -auto ml:  53
# Test: -lr more features: 90 -auto ml:  53

# %% [markdown]
# ## Conclusion
# -auto ml performs consistenty, i.e., similiar performance across both test and train data and no overfitting.
# <br>
# moreover it is  better than -lr more features model

# %%
# Retrain a StructuredDataRegressor with all but outlir datapoints and apply it to test data.
data_train = pd.read_csv(data_train_path)
data_train = clean_data(data_train,'train')
data_train = data_train[data_train.Revenue<300]
data_test = pd.read_csv(data_test_path)
data_test = clean_data(data_test,'test')

# use only numeric features as above.
numeric_features = numeric_colunms
str_features = set([])
train_data = fill_missing_value(data_train,numeric_features,str_features)
test_data = fill_missing_value(data_test,numeric_features-label_col_name,str_features)

X_train = train_data[numeric_features-label_col_name]
y_train = train_data[label_col_name]
X_test = test_data[numeric_features-label_col_name]

search = StructuredDataRegressor(max_trials=15, loss='mean_absolute_error')
search.fit(x=X_train, y=y_train, verbose=0)
test_predict = search.predict(X_test)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\structured_data_regressor\oracle.json
# INFO:tensorflow:Reloading Tuner from .\structured_data_regressor\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/88
# 5/5 [==============================] - 1s 3ms/step - loss: 78.6184 - mean_squared_error: 8232.1035
# Epoch 2/88
# 5/5 [==============================] - 0s 4ms/step - loss: 78.4380 - mean_squared_error: 8223.1396
# Epoch 3/88
# 5/5 [==============================] - 0s 3ms/step - loss: 78.0269 - mean_squared_error: 8142.1011
# Epoch 4/88
# 5/5 [==============================] - 0s 4ms/step - loss: 77.7534 - mean_squared_error: 8109.7188
# Epoch 5/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.5181 - mean_squared_error: 8078.2671
# Epoch 6/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.1730 - mean_squared_error: 8026.8740
# Epoch 7/88
# 5/5 [==============================] - 0s 3ms/step - loss: 77.0258 - mean_squared_error: 7997.0674
# Epoch 8/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.5546 - mean_squared_error: 7931.4492
# Epoch 9/88
# 5/5 [==============================] - 0s 3ms/step - loss: 76.3517 - mean_squared_error: 7892.5708
# Epoch 10/88
# 5/5 [==============================] - 0s 4ms/step - loss: 75.9106 - mean_squared_error: 7830.4917
# Epoch 11/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.6050 - mean_squared_error: 7777.1660
# Epoch 12/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.4389 - mean_squared_error: 7744.8076
# Epoch 13/88
# 5/5 [==============================] - 0s 3ms/step - loss: 75.1058 - mean_squared_error: 7690.3140
# Epoch 14/88
# 5/5 [==============================] - 0s 3ms/step - loss: 74.5908 - mean_squared_error: 7618.6294
# Epoch 15/88
# 5/5 [==============================] - 0s 3ms/step - loss: 74.4773 - mean_squared_error: 7589.5869
# Epoch 16/88
# 5/5 [==============================] - 0s 3ms/step - loss: 73.8479 - mean_squared_error: 7512.2544
# Epoch 17/88
# 5/5 [==============================] - 0s 3ms/step - loss: 73.5768 - mean_squared_error: 7434.4785
# Epoch 18/88
# 5/5 [==============================] - 0s 3ms/step - loss: 73.1109 - mean_squared_error: 7420.0938
# Epoch 19/88
# 5/5 [==============================] - 0s 3ms/step - loss: 72.9770 - mean_squared_error: 7380.8564
# Epoch 20/88
# 5/5 [==============================] - 0s 4ms/step - loss: 72.4174 - mean_squared_error: 7312.0146
# Epoch 21/88
# 5/5 [==============================] - 0s 3ms/step - loss: 72.1807 - mean_squared_error: 7262.7959
# Epoch 22/88
# 5/5 [==============================] - 0s 3ms/step - loss: 71.7394 - mean_squared_error: 7227.9814
# Epoch 23/88
# 5/5 [==============================] - 0s 3ms/step - loss: 71.3845 - mean_squared_error: 7169.2866
# Epoch 24/88
# 5/5 [==============================] - 0s 3ms/step - loss: 71.1631 - mean_squared_error: 7142.1284
# Epoch 25/88
# 5/5 [==============================] - 0s 3ms/step - loss: 70.4937 - mean_squared_error: 6992.0347
# Epoch 26/88
# 5/5 [==============================] - 0s 3ms/step - loss: 70.3914 - mean_squared_error: 7035.3896
# Epoch 27/88
# 5/5 [==============================] - 0s 3ms/step - loss: 69.8014 - mean_squared_error: 6949.2583
# Epoch 28/88
# 5/5 [==============================] - 0s 3ms/step - loss: 69.5388 - mean_squared_error: 6899.9385
# Epoch 29/88
# 5/5 [==============================] - 0s 3ms/step - loss: 69.0215 - mean_squared_error: 6838.6797
# Epoch 30/88
# 5/5 [==============================] - 0s 3ms/step - loss: 68.3847 - mean_squared_error: 6761.6367
# Epoch 31/88
# 5/5 [==============================] - 0s 4ms/step - loss: 68.0648 - mean_squared_error: 6712.6216
# Epoch 32/88
# 5/5 [==============================] - 0s 3ms/step - loss: 67.8219 - mean_squared_error: 6665.3867
# Epoch 33/88
# 5/5 [==============================] - 0s 3ms/step - loss: 67.4941 - mean_squared_error: 6606.5679
# Epoch 34/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.7198 - mean_squared_error: 6485.8125
# Epoch 35/88
# 5/5 [==============================] - 0s 3ms/step - loss: 66.0828 - mean_squared_error: 6429.4751
# Epoch 36/88
# 5/5 [==============================] - 0s 3ms/step - loss: 65.7569 - mean_squared_error: 6455.9912
# Epoch 37/88
# 5/5 [==============================] - 0s 3ms/step - loss: 65.1715 - mean_squared_error: 6327.6396
# Epoch 38/88
# 5/5 [==============================] - 0s 3ms/step - loss: 64.8425 - mean_squared_error: 6292.4751
# Epoch 39/88
# 5/5 [==============================] - 0s 3ms/step - loss: 64.2247 - mean_squared_error: 6184.5181
# Epoch 40/88
# 5/5 [==============================] - 0s 3ms/step - loss: 64.0832 - mean_squared_error: 6202.4380
# Epoch 41/88
# 5/5 [==============================] - 0s 3ms/step - loss: 62.9958 - mean_squared_error: 6045.6377
# Epoch 42/88
# 5/5 [==============================] - 0s 3ms/step - loss: 63.0749 - mean_squared_error: 6010.6577
# Epoch 43/88
# 5/5 [==============================] - 0s 3ms/step - loss: 62.2796 - mean_squared_error: 5937.2085
# Epoch 44/88
# 5/5 [==============================] - 0s 3ms/step - loss: 60.9013 - mean_squared_error: 5719.7354
# Epoch 45/88
# 5/5 [==============================] - 0s 4ms/step - loss: 61.1980 - mean_squared_error: 5814.1470
# Epoch 46/88
# 5/5 [==============================] - 0s 3ms/step - loss: 60.1257 - mean_squared_error: 5667.7021
# Epoch 47/88
# 5/5 [==============================] - 0s 3ms/step - loss: 59.7713 - mean_squared_error: 5682.3706
# Epoch 48/88
# 5/5 [==============================] - 0s 3ms/step - loss: 59.0241 - mean_squared_error: 5502.6411
# Epoch 49/88
# 5/5 [==============================] - 0s 4ms/step - loss: 58.8199 - mean_squared_error: 5495.2070
# Epoch 50/88
# 5/5 [==============================] - 0s 3ms/step - loss: 58.4964 - mean_squared_error: 5447.9683
# Epoch 51/88
# 5/5 [==============================] - 0s 3ms/step - loss: 57.6411 - mean_squared_error: 5353.1450
# Epoch 52/88
# 5/5 [==============================] - 0s 3ms/step - loss: 57.1268 - mean_squared_error: 5326.5332
# Epoch 53/88
# 5/5 [==============================] - 0s 4ms/step - loss: 56.6581 - mean_squared_error: 5238.3213
# Epoch 54/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.7517 - mean_squared_error: 5235.1729
# Epoch 55/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.9271 - mean_squared_error: 5097.5752
# Epoch 56/88
# 5/5 [==============================] - 0s 3ms/step - loss: 55.0259 - mean_squared_error: 5059.8262
# Epoch 57/88
# 5/5 [==============================] - 0s 3ms/step - loss: 54.3431 - mean_squared_error: 4941.0415
# Epoch 58/88
# 5/5 [==============================] - 0s 3ms/step - loss: 53.6051 - mean_squared_error: 4838.7783
# Epoch 59/88
# 5/5 [==============================] - 0s 3ms/step - loss: 53.3846 - mean_squared_error: 4832.3042
# Epoch 60/88
# 5/5 [==============================] - 0s 3ms/step - loss: 52.5345 - mean_squared_error: 4693.0767
# Epoch 61/88
# 5/5 [==============================] - 0s 3ms/step - loss: 52.1518 - mean_squared_error: 4700.7104
# Epoch 62/88
# 5/5 [==============================] - 0s 3ms/step - loss: 51.9159 - mean_squared_error: 4647.0713
# Epoch 63/88
# 5/5 [==============================] - 0s 3ms/step - loss: 51.4261 - mean_squared_error: 4631.5278
# Epoch 64/88
# 5/5 [==============================] - 0s 3ms/step - loss: 50.6746 - mean_squared_error: 4518.8271
# Epoch 65/88
# 5/5 [==============================] - 0s 3ms/step - loss: 50.7384 - mean_squared_error: 4511.1528
# Epoch 66/88
# 5/5 [==============================] - 0s 3ms/step - loss: 50.2914 - mean_squared_error: 4469.9717
# Epoch 67/88
# 5/5 [==============================] - 0s 3ms/step - loss: 49.9641 - mean_squared_error: 4437.7812
# Epoch 68/88
# 5/5 [==============================] - 0s 3ms/step - loss: 48.5245 - mean_squared_error: 4186.9121
# Epoch 69/88
# 5/5 [==============================] - 0s 3ms/step - loss: 48.0961 - mean_squared_error: 4212.4233
# Epoch 70/88
# 5/5 [==============================] - 0s 3ms/step - loss: 48.2747 - mean_squared_error: 4183.7949
# Epoch 71/88
# 5/5 [==============================] - 0s 3ms/step - loss: 48.2903 - mean_squared_error: 4198.5200
# Epoch 72/88
# 5/5 [==============================] - 0s 3ms/step - loss: 47.4521 - mean_squared_error: 4098.3975
# Epoch 73/88
# 5/5 [==============================] - 0s 3ms/step - loss: 46.9205 - mean_squared_error: 4057.8779
# Epoch 74/88
# 5/5 [==============================] - 0s 3ms/step - loss: 46.3497 - mean_squared_error: 3949.1394
# Epoch 75/88
# 5/5 [==============================] - 0s 3ms/step - loss: 46.4122 - mean_squared_error: 3978.1123
# Epoch 76/88
# 5/5 [==============================] - 0s 3ms/step - loss: 45.8300 - mean_squared_error: 3882.5774
# Epoch 77/88
# 5/5 [==============================] - 0s 3ms/step - loss: 44.8667 - mean_squared_error: 3734.1309
# Epoch 78/88
# 5/5 [==============================] - 0s 3ms/step - loss: 44.5926 - mean_squared_error: 3800.8384
# Epoch 79/88
# 5/5 [==============================] - 0s 3ms/step - loss: 45.7904 - mean_squared_error: 3842.5996
# Epoch 80/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.5724 - mean_squared_error: 3704.3101
# Epoch 81/88
# 5/5 [==============================] - 0s 4ms/step - loss: 44.2421 - mean_squared_error: 3690.7024
# Epoch 82/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.2578 - mean_squared_error: 3571.3660
# Epoch 83/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.5856 - mean_squared_error: 3623.3665
# Epoch 84/88
# 5/5 [==============================] - 0s 3ms/step - loss: 42.8685 - mean_squared_error: 3537.6116
# Epoch 85/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.0279 - mean_squared_error: 3576.9431
# Epoch 86/88
# 5/5 [==============================] - 0s 3ms/step - loss: 42.8845 - mean_squared_error: 3560.3745
# Epoch 87/88
# 5/5 [==============================] - 0s 3ms/step - loss: 41.5185 - mean_squared_error: 3306.9956
# Epoch 88/88
# 5/5 [==============================] - 0s 3ms/step - loss: 43.1939 - mean_squared_error: 3633.3682
# INFO:tensorflow:Assets written to: .\structured_data_regressor\best_model\assets
# 1/1 [==============================] - 0s 11ms/step

# %%
# Fridge ID is the unique key for each smart fridge, therefore we only present it aling side the predicted revenue
data_train['Fridge ID'].nunique() == data_train.shape[0]
# Out:
# True

# %%
data_test['revenue_prediction'] = test_predict.flatten()
data_test[clean_int_columns+['revenue_prediction']]
# Out:
#     Fridge ID  Year Founded  Office Size  revenue_prediction
# 0       30035          2001          350           28.791920
# 1        5425          2008          800           34.935783
# 2        5628          2010          500           31.659060
# 3        5656          1916          200           34.392124
# 4        5710          1987          950           31.777559
# 5        5483          2008         1000           31.154694
# 6       30018          1955          350           27.942024
# 7        5623          2000          150           34.900177
# 8       10002          2011          400           25.613485
# 9       20002          1940          200           26.140108
# 10      30029          1924          100           22.606091
# 11      30007          1999          350           31.594685
# 12      30026          1998         1200           31.004951
# 13       5619          1997          400           31.550945
# 14      30005          1991          120           29.347912
# 15       5653          2010          100           26.341005
# 16      10017          2007          263           25.626944

# %%
data_test.to_csv('test_data_revenue_prediction.csv')
